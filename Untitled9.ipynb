# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict, Counter

goal_set = pickle.load(open('synthetic_dataset/goal_set.p', 'rb'))

# %%
train_data = goal_set['train']
train_data
# Out:
# [{'consult_id': 1059,
#   'disease_tag': 'Central retinal artery or vein occlusion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Spots or clouds in vision': True},
#    'implicit_inform_slots': {'Diminished vision': True,
#     'Symptoms of eye': True,
#     'Pain in eye': True}}},
#  {'consult_id': 19510,
#   'disease_tag': 'Degenerative disc disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Back pain': True,
#     'Low back pain': True,
#     'Neck pain': True,
#     'Hip pain': True,
#     'Ache all over': True}}},
#  {'consult_id': 25630,
#   'disease_tag': 'Diabetic retinopathy',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Foreign body sensation in eye': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 1467,
#   'disease_tag': 'Chronic back pain',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Low back pain': True},
#    'implicit_inform_slots': {'Back pain': True, 'Side pain': True}}},
#  {'consult_id': 5780,
#   'disease_tag': 'Air embolism',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Wrist pain': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Shoulder cramps or spasms': True,
#     'Facial pain': True,
#     'Ankle pain': True,
#     'Pain during pregnancy': True,
#     'Joint stiffness or tightness': True,
#     'Pain or soreness of breast': True,
#     'Knee lump or mass': True,
#     'Excessive urination at night': True}}},
#  {'consult_id': 26258,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Skin dryness, peeling, scaliness, or roughness': True}}},
#  {'consult_id': 16096,
#   'disease_tag': 'Diaper rash',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Diarrhea': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 6580,
#   'disease_tag': 'Air embolism',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Facial pain': True},
#    'implicit_inform_slots': {'Shoulder cramps or spasms': True,
#     'Ankle pain': True,
#     'Wrist pain': True,
#     'Excessive anger': True,
#     'Joint stiffness or tightness': True,
#     'Pain or soreness of breast': True,
#     'Knee lump or mass': True,
#     'Fatigue': True,
#     'Excessive urination at night': True}}},
#  {'consult_id': 22733,
#   'disease_tag': 'Conversion disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Sweating': True,
#     'Abnormal involuntary movements': True,
#     'Fatigue': True,
#     'Cough': True}}},
#  {'consult_id': 17308,
#   'disease_tag': 'Air embolism',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain or soreness of breast': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Shoulder cramps or spasms': True,
#     'Facial pain': True,
#     'Ankle pain': True,
#     'Pain during pregnancy': True,
#     'Excessive anger': True,
#     'Joint stiffness or tightness': True,
#     'Knee lump or mass': True,
#     'Fatigue': True,
#     'Excessive urination at night': True}}},
#  {'consult_id': 1564,
#   'disease_tag': 'Anxiety',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Abnormal involuntary movements': True}}},
#  {'consult_id': 29211,
#   'disease_tag': 'Conductive hearing loss',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Plugged feeling in ear': True},
#    'implicit_inform_slots': {'Diminished hearing': True,
#     'Ear pain': True,
#     'Redness in ear': True,
#     'Dizziness': True}}},
#  {'consult_id': 26235,
#   'disease_tag': 'Alcohol intoxication',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Anxiety and nervousness': True},
#    'implicit_inform_slots': {'Abusing alcohol': True,
#     'Sharp abdominal pain': True}}},
#  {'consult_id': 8094,
#   'disease_tag': 'Conjunctivitis due to allergy',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Eye redness': True},
#    'implicit_inform_slots': {'Lacrimation': True,
#     'Swollen eye': True,
#     'Symptoms of eye': True,
#     'Diminished vision': True,
#     'Cough': True}}},
#  {'consult_id': 16427,
#   'disease_tag': 'Conductive hearing loss',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Diminished hearing': True,
#     'Ringing in ear': True,
#     'Swollen or red tonsils': True}}},
#  {'consult_id': 16512,
#   'disease_tag': 'Drug reaction',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Allergic reaction': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Dizziness': True,
#     'Nausea': True,
#     'Shortness of breath': True}}},
#  {'consult_id': 25014,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hot flashes': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 16360,
#   'disease_tag': 'Granuloma inguinale',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Vaginal pain': True},
#    'implicit_inform_slots': {'Nausea': True, 'Sharp chest pain': True}}},
#  {'consult_id': 15081,
#   'disease_tag': 'Extrapyramidal effect of drugs',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Restlessness': True},
#    'implicit_inform_slots': {'Nausea': True,
#     'Neck stiffness or tightness': True}}},
#  {'consult_id': 15386,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in eye': True},
#    'implicit_inform_slots': {'Diminished vision': True,
#     'Eye redness': True,
#     'Symptoms of eye': True,
#     'White discharge from eye': True,
#     'Swollen eye': True}}},
#  {'consult_id': 18363,
#   'disease_tag': 'Encephalitis',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Disturbance of memory': True},
#    'implicit_inform_slots': {'Loss of sensation': True, 'Seizures': True}}},
#  {'consult_id': 27441,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Allergic reaction': True}}},
#  {'consult_id': 9641,
#   'disease_tag': 'Extrapyramidal effect of drugs',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Arm stiffness or tightness': True},
#    'implicit_inform_slots': {'Cramps and spasms': True}}},
#  {'consult_id': 27768,
#   'disease_tag': 'Actinic keratosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin growth': True},
#    'implicit_inform_slots': {'Abnormal appearing skin': True,
#     'Skin lesion': True,
#     'Skin dryness, peeling, scaliness, or roughness': True,
#     'Skin swelling': True,
#     'Itching of skin': True}}},
#  {'consult_id': 21778,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hot flashes': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 18706,
#   'disease_tag': 'Adjustment reaction',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Depression': True,
#     'Excessive anger': True,
#     'Insomnia': True}}},
#  {'consult_id': 7857,
#   'disease_tag': 'Drug abuse cocaine',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Abusing alcohol': True},
#    'implicit_inform_slots': {'Drug abuse': True}}},
#  {'consult_id': 29589,
#   'disease_tag': 'Chondromalacia of the patella',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg pain': True},
#    'implicit_inform_slots': {'Knee pain': True,
#     'Problems with movement': True,
#     'Knee weakness': True}}},
#  {'consult_id': 15191,
#   'disease_tag': 'Chalazion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Eye redness': True},
#    'implicit_inform_slots': {'Mass on eyelid': True,
#     'Swollen eye': True,
#     'Eyelid swelling': True,
#     'Eyelid lesion or rash': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 22535,
#   'disease_tag': 'Central retinal artery or vein occlusion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Blindness': True},
#    'implicit_inform_slots': {'Diminished vision': True,
#     'Symptoms of eye': True}}},
#  {'consult_id': 6047,
#   'disease_tag': 'Alzheimer disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Disturbance of memory': True}}},
#  {'consult_id': 20116,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp abdominal pain': True},
#    'implicit_inform_slots': {'Heavy menstrual flow': True}}},
#  {'consult_id': 26439,
#   'disease_tag': 'Acariasis',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Swelling of scrotum': True}}},
#  {'consult_id': 11928,
#   'disease_tag': 'Epidural hemorrhage',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 20634,
#   'disease_tag': 'Guillain Barre syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hand or finger pain': True},
#    'implicit_inform_slots': {'Leg pain': True,
#     'Loss of sensation': True,
#     'Ache all over': True,
#     'Dizziness': True}}},
#  {'consult_id': 3590,
#   'disease_tag': 'Acute kidney injury',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Retention of urine': True},
#    'implicit_inform_slots': {'Shortness of breath': True, 'Weakness': True}}},
#  {'consult_id': 3726,
#   'disease_tag': 'Cerebral edema',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Neck pain': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Vomiting': True,
#     'Loss of sensation': True}}},
#  {'consult_id': 7899,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Double vision': True},
#    'implicit_inform_slots': {'Eye redness': True,
#     'White discharge from eye': True}}},
#  {'consult_id': 9125,
#   'disease_tag': 'Drug reaction',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Lip swelling': True,
#     'Shortness of breath': True,
#     'Throat swelling': True}}},
#  {'consult_id': 16230,
#   'disease_tag': 'Diabetic peripheral neuropathy',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Foot or toe pain': True},
#    'implicit_inform_slots': {'Skin lesion': True}}},
#  {'consult_id': 27079,
#   'disease_tag': 'Cushing syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Weight gain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 7995,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Abnormal appearing skin': True},
#    'implicit_inform_slots': {'Itching of skin': True, 'Skin lesion': True}}},
#  {'consult_id': 21990,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Warts': True},
#    'implicit_inform_slots': {'Itching of skin': True,
#     'Skin dryness, peeling, scaliness, or roughness': True,
#     'Cough': True}}},
#  {'consult_id': 12775,
#   'disease_tag': 'Epididymitis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in testicles': True},
#    'implicit_inform_slots': {'Swelling of scrotum': True,
#     'Groin pain': True,
#     'Side pain': True,
#     'Painful urination': True}}},
#  {'consult_id': 86,
#   'disease_tag': 'Chickenpox',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fever': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Skin lesion': True}}},
#  {'consult_id': 19263,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin swelling': True},
#    'implicit_inform_slots': {'Knee pain': True}}},
#  {'consult_id': 19699,
#   'disease_tag': 'Dissociative disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 19386,
#   'disease_tag': 'Chickenpox',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Itching of skin': True}}},
#  {'consult_id': 23606,
#   'disease_tag': 'Chondromalacia of the patella',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Knee pain': True},
#    'implicit_inform_slots': {'Knee weakness': True,
#     'Elbow pain': True,
#     'Bones are painful': True}}},
#  {'consult_id': 14382,
#   'disease_tag': 'Cerebral edema',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Neck pain': True,
#     'Diminished vision': True,
#     'Loss of sensation': True,
#     'Nausea': True}}},
#  {'consult_id': 14328,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Intermenstrual bleeding': True},
#    'implicit_inform_slots': {'Vaginal bleeding after menopause': True}}},
#  {'consult_id': 27516,
#   'disease_tag': 'Decubitus ulcer',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 17279,
#   'disease_tag': 'Amyotrophic lateral sclerosis ALS',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fatigue': True},
#    'implicit_inform_slots': {'Problems with movement': True,
#     'Muscle weakness': True,
#     'Leg cramps or spasms': True}}},
#  {'consult_id': 1769,
#   'disease_tag': 'Adjustment reaction',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Anxiety and nervousness': True,
#     'Excessive anger': True}}},
#  {'consult_id': 20111,
#   'disease_tag': 'Chronic back pain',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {'Leg pain': True, 'Hip pain': True}}},
#  {'consult_id': 19480,
#   'disease_tag': 'Endometrial hyperplasia',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pelvic pain': True},
#    'implicit_inform_slots': {'Vaginal bleeding after menopause': True,
#     'Unpredictable menstruation': True,
#     'Involuntary urination': True,
#     'Vaginal discharge': True}}},
#  {'consult_id': 28758,
#   'disease_tag': 'Carbon monoxide poisoning',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fainting': True},
#    'implicit_inform_slots': {'Headache': True, 'Nausea': True}}},
#  {'consult_id': 7769,
#   'disease_tag': 'Chagas disease',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Excessive anger': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 5013,
#   'disease_tag': 'Carpal tunnel syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hand or finger pain': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Wrist pain': True,
#     'Neck pain': True}}},
#  {'consult_id': 26904,
#   'disease_tag': 'Endometrial hyperplasia',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Involuntary urination': True},
#    'implicit_inform_slots': {'Unpredictable menstruation': True}}},
#  {'consult_id': 19940,
#   'disease_tag': 'Dissociative disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Anxiety and nervousness': True,
#     'Excessive anger': True}}},
#  {'consult_id': 3996,
#   'disease_tag': 'Diabetes insipidus',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {'Difficulty in swallowing': True,
#     'Dizziness': True}}},
#  {'consult_id': 12006,
#   'disease_tag': 'Chronic pain disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Low back pain': True},
#    'implicit_inform_slots': {'Back pain': True,
#     'Leg pain': True,
#     'Headache': True,
#     'Sharp abdominal pain': True,
#     'Shoulder pain': True}}},
#  {'consult_id': 6762,
#   'disease_tag': 'Fracture of the pelvis',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hip pain': True},
#    'implicit_inform_slots': {'Groin pain': True, 'Ache all over': True}}},
#  {'consult_id': 2874,
#   'disease_tag': 'Concussion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Facial pain': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Dizziness': True,
#     'Nausea': True}}},
#  {'consult_id': 9180,
#   'disease_tag': 'Gonorrhea',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp abdominal pain': True},
#    'implicit_inform_slots': {'Penile discharge': True}}},
#  {'consult_id': 18054,
#   'disease_tag': 'Gout',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Wrist swelling': True},
#    'implicit_inform_slots': {'Foot or toe pain': True,
#     'Foot or toe swelling': True,
#     'Ankle pain': True}}},
#  {'consult_id': 12207,
#   'disease_tag': 'Extrapyramidal effect of drugs',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Delusions or hallucinations': True},
#    'implicit_inform_slots': {'Abnormal involuntary movements': True,
#     'Disturbance of memory': True,
#     'Problems with movement': True}}},
#  {'consult_id': 17117,
#   'disease_tag': 'Chancroid',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder cramps or spasms': True},
#    'implicit_inform_slots': {'Ankle pain': True,
#     'Pain or soreness of breast': True}}},
#  {'consult_id': 20286,
#   'disease_tag': 'Amyloidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Congestion in chest': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Anxiety and nervousness': True,
#     'Fever': True,
#     'Weakness': True}}},
#  {'consult_id': 13025,
#   'disease_tag': 'Conductive hearing loss',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Diminished hearing': True},
#    'implicit_inform_slots': {'Ear pain': True,
#     'Redness in ear': True,
#     'Ringing in ear': True,
#     'Difficulty speaking': True}}},
#  {'consult_id': 21650,
#   'disease_tag': 'Cystitis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lower abdominal pain': True},
#    'implicit_inform_slots': {'Blood in urine': True, 'Back pain': True}}},
#  {'consult_id': 1749,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Foot or toe pain': True},
#    'implicit_inform_slots': {'Knee pain': True,
#     'Cramps and spasms': True,
#     'Symptoms of eye': True,
#     'Weight gain': True}}},
#  {'consult_id': 791,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Loss of sensation': True},
#    'implicit_inform_slots': {'Hand or finger pain': True,
#     'Low back pain': True}}},
#  {'consult_id': 24033,
#   'disease_tag': 'Encephalitis',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg weakness': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Loss of sensation': True,
#     'Seizures': True,
#     'Dizziness': True,
#     'Leg pain': True,
#     'Problems with movement': True}}},
#  {'consult_id': 10394,
#   'disease_tag': 'Encephalitis',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Leg pain': True,
#     'Fatigue': True}}},
#  {'consult_id': 23176,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Itching of skin': True,
#     'Abnormal appearing skin': True}}},
#  {'consult_id': 26863,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lower abdominal pain': True},
#    'implicit_inform_slots': {'Pelvic pain': True,
#     'Sharp abdominal pain': True}}},
#  {'consult_id': 11005,
#   'disease_tag': 'Essential tremor',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Abnormal involuntary movements': True},
#    'implicit_inform_slots': {'Problems with movement': True}}},
#  {'consult_id': 9671,
#   'disease_tag': 'Drug abuse cocaine',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Drug abuse': True,
#     'Abusing alcohol': True,
#     'Depressive or psychotic symptoms': True}}},
#  {'consult_id': 11134,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Skin rash': True}}},
#  {'consult_id': 15276,
#   'disease_tag': 'Diaper rash',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Itching of skin': True},
#    'implicit_inform_slots': {'Diarrhea': True,
#     'Skin rash': True,
#     'Irritable infant': True}}},
#  {'consult_id': 16094,
#   'disease_tag': 'Adjustment reaction',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Hostile behavior': True}}},
#  {'consult_id': 6624,
#   'disease_tag': 'Gonorrhea',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Penile discharge': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 6097,
#   'disease_tag': 'Acute kidney injury',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 16311,
#   'disease_tag': 'Amyotrophic lateral sclerosis ALS',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Weakness': True},
#    'implicit_inform_slots': {'Hand or finger weakness': True}}},
#  {'consult_id': 339,
#   'disease_tag': 'Amyloidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fever': True},
#    'implicit_inform_slots': {'Weakness': True,
#     'Abnormal appearing skin': True}}},
#  {'consult_id': 16364,
#   'disease_tag': 'Actinic keratosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Abnormal appearing skin': True,
#     'Skin dryness, peeling, scaliness, or roughness': True,
#     'Skin moles': True}}},
#  {'consult_id': 19563,
#   'disease_tag': 'Gas gangrene',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Wrist pain': True},
#    'implicit_inform_slots': {'Sharp abdominal pain': True,
#     'Knee lump or mass': True,
#     'Pain in eye': True,
#     'Fatigue': True}}},
#  {'consult_id': 4346,
#   'disease_tag': 'Cat scratch disease',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Arm lump or mass': True},
#    'implicit_inform_slots': {'Neck swelling': True,
#     'Skin swelling': True,
#     'Groin mass': True,
#     'Skin rash': True,
#     'Loss of sensation': True,
#     'Arm swelling': True,
#     'Headache': True}}},
#  {'consult_id': 27942,
#   'disease_tag': 'Fibrocystic breast disease',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lump or mass of breast': True},
#    'implicit_inform_slots': {'Pain or soreness of breast': True,
#     'Bleeding or discharge from nipple': True}}},
#  {'consult_id': 7828,
#   'disease_tag': 'Diabetes insipidus',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {'Excessive appetite': True,
#     'Difficulty in swallowing': True,
#     'Frequent urination': True,
#     'Dizziness': True}}},
#  {'consult_id': 13246,
#   'disease_tag': 'Acariasis',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cross-eyed': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Itching of skin': True}}},
#  {'consult_id': 16560,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pelvic pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 19534,
#   'disease_tag': 'Factitious disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Disturbance of memory': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Depression': True,
#     'Paresthesia': True,
#     'Lip swelling': True}}},
#  {'consult_id': 120,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder stiffness or tightness': True},
#    'implicit_inform_slots': {'Shoulder pain': True}}},
#  {'consult_id': 8868,
#   'disease_tag': 'Carcinoid syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Excessive growth': True},
#    'implicit_inform_slots': {'Vulvar sore': True,
#     'Joint stiffness or tightness': True,
#     'Itchy eyelid': True}}},
#  {'consult_id': 1947,
#   'disease_tag': 'Degenerative disc disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {'Low back pain': True,
#     'Leg pain': True,
#     'Neck pain': True,
#     'Shoulder pain': True,
#     'Ache all over': True}}},
#  {'consult_id': 28436,
#   'disease_tag': 'Chickenpox',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Irritable infant': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Itching of skin': True,
#     'Ache all over': True,
#     'Skin lesion': True}}},
#  {'consult_id': 5509,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Shoulder stiffness or tightness': True,
#     'Ache all over': True}}},
#  {'consult_id': 24423,
#   'disease_tag': 'Ectropion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Symptoms of eye': True},
#    'implicit_inform_slots': {'Lacrimation': True,
#     'Eyelid lesion or rash': True,
#     'Swollen eye': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 14480,
#   'disease_tag': 'Endophthalmitis',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Itchiness of eye': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Eye redness': True,
#     'Swollen eye': True,
#     'Painful sinuses': True}}},
#  {'consult_id': 8488,
#   'disease_tag': 'Amyloidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fatigue': True},
#    'implicit_inform_slots': {'Symptoms of the kidneys': True,
#     'Weakness': True,
#     'Abnormal appearing skin': True}}},
#  {'consult_id': 29060,
#   'disease_tag': 'Chlamydia',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Penile discharge': True},
#    'implicit_inform_slots': {'Vaginal discharge': True,
#     'Sharp abdominal pain': True,
#     'Painful urination': True,
#     'Vaginal itching': True,
#     'Lower abdominal pain': True}}},
#  {'consult_id': 20625,
#   'disease_tag': 'Amyloidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shortness of breath': True},
#    'implicit_inform_slots': {'Fatigue': True,
#     'Anxiety and nervousness': True,
#     'Symptoms of the kidneys': True,
#     'Feeling hot and cold': True}}},
#  {'consult_id': 13768,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Abnormal appearing skin': True,
#     'Skin dryness, peeling, scaliness, or roughness': True,
#     'Cough': True}}},
#  {'consult_id': 22417,
#   'disease_tag': 'Eating disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Anxiety and nervousness': True},
#    'implicit_inform_slots': {'Depression': True,
#     'Depressive or psychotic symptoms': True,
#     'Decreased appetite': True}}},
#  {'consult_id': 21493,
#   'disease_tag': 'Concussion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 15194,
#   'disease_tag': 'Guillain Barre syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg weakness': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Hand or finger pain': True,
#     'Weakness': True,
#     'Problems with movement': True,
#     'Facial pain': True}}},
#  {'consult_id': 23450,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lacrimation': True},
#    'implicit_inform_slots': {'Eye redness': True}}},
#  {'consult_id': 23404,
#   'disease_tag': 'Fluid overload',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Hand or finger swelling': True}}},
#  {'consult_id': 22550,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Intermenstrual bleeding': True},
#    'implicit_inform_slots': {'Vaginal bleeding after menopause': True}}},
#  {'consult_id': 20582,
#   'disease_tag': 'Fibromyalgia',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Muscle pain': True},
#    'implicit_inform_slots': {'Back pain': True}}},
#  {'consult_id': 11716,
#   'disease_tag': 'Alzheimer disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Delusions or hallucinations': True},
#    'implicit_inform_slots': {'Depression': True}}},
#  {'consult_id': 18034,
#   'disease_tag': 'Fibromyalgia',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Ache all over': True,
#     'Neck pain': True,
#     'Muscle pain': True,
#     'Leg pain': True}}},
#  {'consult_id': 5402,
#   'disease_tag': 'Drug reaction',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Throat swelling': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Dizziness': True}}},
#  {'consult_id': 4711,
#   'disease_tag': 'De Quervain disease',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Wrist pain': True,
#     'Hand or finger pain': True}}},
#  {'consult_id': 20581,
#   'disease_tag': 'Fracture of the rib',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Back pain': True}}},
#  {'consult_id': 7456,
#   'disease_tag': 'Conjunctivitis due to allergy',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Eye redness': True},
#    'implicit_inform_slots': {'Itchiness of eye': True,
#     'Pain in eye': True,
#     'Nasal congestion': True}}},
#  {'consult_id': 750,
#   'disease_tag': 'Ganglion cyst',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Knee swelling': True},
#    'implicit_inform_slots': {'Leg pain': True, 'Wrist lump or mass': True}}},
#  {'consult_id': 29975,
#   'disease_tag': 'Dermatitis due to sun exposure',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin moles': True},
#    'implicit_inform_slots': {'Abnormal appearing skin': True,
#     'Skin rash': True}}},
#  {'consult_id': 28051,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pelvic pain': True},
#    'implicit_inform_slots': {'Sharp abdominal pain': True}}},
#  {'consult_id': 15254,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Problems with movement': True},
#    'implicit_inform_slots': {'Foot or toe pain': True}}},
#  {'consult_id': 25468,
#   'disease_tag': 'Degenerative disc disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {'Leg pain': True,
#     'Neck pain': True,
#     'Shoulder pain': True,
#     'Arm pain': True}}},
#  {'consult_id': 26528,
#   'disease_tag': 'Female infertility of unknown cause',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Infertility': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 275,
#   'disease_tag': 'Chronic kidney disease',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shortness of breath': True},
#    'implicit_inform_slots': {'Fatigue': True}}},
#  {'consult_id': 10852,
#   'disease_tag': 'Gas gangrene',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Ankle pain': True},
#    'implicit_inform_slots': {'Sharp abdominal pain': True,
#     'Pain in eye': True,
#     'Fatigue': True}}},
#  {'consult_id': 6183,
#   'disease_tag': 'Dermatitis due to sun exposure',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Abnormal appearing skin': True},
#    'implicit_inform_slots': {'Skin lesion': True,
#     'Irregular appearing scalp': True,
#     'Skin swelling': True}}},
#  {'consult_id': 23318,
#   'disease_tag': 'Cystic Fibrosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 29262,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Itching of skin': True,
#     'Acne or pimples': True}}},
#  {'consult_id': 14475,
#   'disease_tag': 'Acne',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Acne or pimples': True},
#    'implicit_inform_slots': {'Skin moles': True}}},
#  {'consult_id': 28630,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Acne or pimples': True,
#     'Frequent urination': True,
#     'Ankle pain': True}}},
#  {'consult_id': 621,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg pain': True},
#    'implicit_inform_slots': {'Loss of sensation': True}}},
#  {'consult_id': 18230,
#   'disease_tag': 'Corneal abrasion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lacrimation': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Swollen eye': True,
#     'Diminished vision': True,
#     'Foreign body sensation in eye': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 19696,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Ankle pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 15869,
#   'disease_tag': 'Fluid overload',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fluid retention': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Peripheral edema': True}}},
#  {'consult_id': 18797,
#   'disease_tag': 'De Quervain disease',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Wrist swelling': True},
#    'implicit_inform_slots': {'Wrist pain': True, 'Shoulder pain': True}}},
#  {'consult_id': 880,
#   'disease_tag': 'Diabetic ketoacidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Vomiting': True},
#    'implicit_inform_slots': {'Nausea': True, 'Sharp abdominal pain': True}}},
#  {'consult_id': 17314,
#   'disease_tag': 'Fracture of the pelvis',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Groin pain': True},
#    'implicit_inform_slots': {'Hip pain': True,
#     'Problems with movement': True,
#     'Delusions or hallucinations': True,
#     'Focal weakness': True}}},
#  {'consult_id': 11154,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Low back pain': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Foot or toe pain': True,
#     'Paresthesia': True,
#     'Arm pain': True,
#     'Hand or finger pain': True}}},
#  {'consult_id': 10795,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Spots or clouds in vision': True},
#    'implicit_inform_slots': {'Diminished vision': True,
#     'Symptoms of eye': True,
#     'Foreign body sensation in eye': True,
#     'White discharge from eye': True}}},
#  {'consult_id': 6953,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Infertility': True},
#    'implicit_inform_slots': {'Pelvic pain': True,
#     'Heavy menstrual flow': True,
#     'Burning abdominal pain': True}}},
#  {'consult_id': 29134,
#   'disease_tag': 'Anxiety',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Anxiety and nervousness': True,
#     'Depression': True,
#     'Irregular heartbeat': True}}},
#  {'consult_id': 11948,
#   'disease_tag': 'Allergy',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin swelling': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Itching of skin': True,
#     'Swollen eye': True}}},
#  {'consult_id': 28164,
#   'disease_tag': 'Cystitis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp abdominal pain': True},
#    'implicit_inform_slots': {'Painful urination': True,
#     'Blood in urine': True}}},
#  {'consult_id': 13969,
#   'disease_tag': 'Granuloma inguinale',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Nausea': True},
#    'implicit_inform_slots': {'Sharp chest pain': True,
#     'Groin pain': True,
#     'Vaginal pain': True,
#     'Neck cramps or spasms': True}}},
#  {'consult_id': 14715,
#   'disease_tag': 'Carcinoid syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Involuntary urination': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 2474,
#   'disease_tag': 'Diabetic retinopathy',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lacrimation': True},
#    'implicit_inform_slots': {'Diminished vision': True, 'Pain in eye': True}}},
#  {'consult_id': 27217,
#   'disease_tag': 'Endophthalmitis',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Eye redness': True,
#     'Swollen eye': True,
#     'Lacrimation': True}}},
#  {'consult_id': 1217,
#   'disease_tag': 'Encephalitis',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Headache': True},
#    'implicit_inform_slots': {'Loss of sensation': True}}},
#  {'consult_id': 7130,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Symptoms of eye': True},
#    'implicit_inform_slots': {'Pain in eye': True}}},
#  {'consult_id': 3402,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Skin lesion': True, 'Allergic reaction': True}}},
#  {'consult_id': 14617,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder stiffness or tightness': True},
#    'implicit_inform_slots': {'Shoulder pain': True, 'Ache all over': True}}},
#  {'consult_id': 1722,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin dryness, peeling, scaliness, or roughness': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Itching of skin': True,
#     'Abnormal appearing skin': True,
#     'Cough': True}}},
#  {'consult_id': 5518,
#   'disease_tag': 'Granuloma inguinale',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Groin pain': True},
#    'implicit_inform_slots': {'Nausea': True,
#     'Sharp chest pain': True,
#     'Vaginal pain': True}}},
#  {'consult_id': 852,
#   'disease_tag': 'Guillain Barre syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg weakness': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Fever': True,
#     'Hand or finger pain': True}}},
#  {'consult_id': 16858,
#   'disease_tag': 'Carpal tunnel syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Arm pain': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Paresthesia': True,
#     'Hand or finger weakness': True}}},
#  {'consult_id': 23064,
#   'disease_tag': 'Dissociative disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Anxiety and nervousness': True,
#     'Low self-esteem': True}}},
#  {'consult_id': 13618,
#   'disease_tag': 'Erectile dysfunction',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Premature ejaculation': True},
#    'implicit_inform_slots': {'Impotence': True, 'Pain in testicles': True}}},
#  {'consult_id': 24809,
#   'disease_tag': 'Cystic Fibrosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Feeling ill': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 14703,
#   'disease_tag': 'Concussion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Neck pain': True},
#    'implicit_inform_slots': {'Headache': True}}},
#  {'consult_id': 8096,
#   'disease_tag': 'Ectropion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in eye': True},
#    'implicit_inform_slots': {'Lacrimation': True,
#     'Abnormal movement of eyelid': True,
#     'Eyelid lesion or rash': True}}},
#  {'consult_id': 24946,
#   'disease_tag': 'Epidural hemorrhage',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Side pain': True,
#     'Dizziness': True,
#     'Leg pain': True}}},
#  {'consult_id': 16546,
#   'disease_tag': 'De Quervain disease',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Wrist pain': True,
#     'Wrist swelling': True,
#     'Arm pain': True,
#     'Peripheral edema': True}}},
#  {'consult_id': 8741,
#   'disease_tag': 'Diabetic retinopathy',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lacrimation': True},
#    'implicit_inform_slots': {'Itchiness of eye': True}}},
#  {'consult_id': 5732,
#   'disease_tag': 'Cyst of the eyelid',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Symptoms of eye': True},
#    'implicit_inform_slots': {'Mass on eyelid': True, 'Pain in eye': True}}},
#  {'consult_id': 19349,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Allergic reaction': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Skin dryness, peeling, scaliness, or roughness': True}}},
#  {'consult_id': 1282,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Foot or toe lump or mass': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Skin lesion': True,
#     'Itching of skin': True,
#     'Abnormal appearing skin': True}}},
#  {'consult_id': 28431,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
# ...
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Side pain': True}}},
#  {'consult_id': 27922,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Loss of sensation': True},
#    'implicit_inform_slots': {'Foot or toe pain': True, 'Arm pain': True}}},
#  {'consult_id': 1716,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder stiffness or tightness': True},
#    'implicit_inform_slots': {'Shoulder pain': True, 'Neck pain': True}}},
#  {'consult_id': 21088,
#   'disease_tag': 'Concussion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sleepiness': True},
#    'implicit_inform_slots': {'Headache': True, 'Neck pain': True}}},
#  {'consult_id': 6093,
#   'disease_tag': 'Conductive hearing loss',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Diminished hearing': True},
#    'implicit_inform_slots': {'Ear pain': True,
#     'Plugged feeling in ear': True,
#     'Ringing in ear': True}}},
#  {'consult_id': 15762,
#   'disease_tag': 'Gout',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hand or finger pain': True},
#    'implicit_inform_slots': {'Foot or toe pain': True, 'Knee pain': True}}},
#  {'consult_id': 14330,
#   'disease_tag': 'Acute kidney injury',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Kidney mass': True},
#    'implicit_inform_slots': {'Blood in urine': True}}},
#  {'consult_id': 27297,
#   'disease_tag': 'Allergy',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Allergic reaction': True}}},
#  {'consult_id': 1325,
#   'disease_tag': 'Allergy',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Swollen tongue': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Cough': True}}},
#  {'consult_id': 16941,
#   'disease_tag': 'Essential tremor',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Abnormal involuntary movements': True,
#     'Loss of sensation': True}}},
#  {'consult_id': 20996,
#   'disease_tag': 'Female infertility of unknown cause',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Infertility': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 17320,
#   'disease_tag': 'Drug abuse cocaine',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Drug abuse': True}}},
#  {'consult_id': 16357,
#   'disease_tag': 'Eating disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Difficulty eating': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True}}},
#  {'consult_id': 5615,
#   'disease_tag': 'De Quervain disease',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Arm pain': True},
#    'implicit_inform_slots': {'Wrist pain': True,
#     'Hand or finger swelling': True}}},
#  {'consult_id': 21682,
#   'disease_tag': 'Cerebral edema',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Focal weakness': True},
#    'implicit_inform_slots': {'Neck pain': True, 'Vomiting': True}}},
#  {'consult_id': 27134,
#   'disease_tag': 'Ectropion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in eye': True},
#    'implicit_inform_slots': {'Symptoms of eye': True,
#     'Eye redness': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 6067,
#   'disease_tag': 'Carbon monoxide poisoning',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 28521,
#   'disease_tag': 'Acute glaucoma',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Eye redness': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Spots or clouds in vision': True}}},
#  {'consult_id': 28451,
#   'disease_tag': 'Acne',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Acne or pimples': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 23360,
#   'disease_tag': 'Acanthosis nigricans',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Weight gain': True},
#    'implicit_inform_slots': {'Pain or soreness of breast': True,
#     'Warts': True}}},
#  {'consult_id': 28520,
#   'disease_tag': 'Conjunctivitis due to allergy',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Symptoms of eye': True},
#    'implicit_inform_slots': {'Itchiness of eye': True,
#     'Pain in eye': True,
#     'Nasal congestion': True,
#     'Swollen eye': True,
#     'Allergic reaction': True}}},
#  {'consult_id': 13700,
#   'disease_tag': 'Decubitus ulcer',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Disturbance of smell or taste': True},
#    'implicit_inform_slots': {'Skin on leg or foot looks infected': True}}},
#  {'consult_id': 21789,
#   'disease_tag': 'Dengue fever',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in eye': True},
#    'implicit_inform_slots': {'Sore throat': True,
#     'Fever': True,
#     'Wrist pain': True,
#     'Joint stiffness or tightness': True,
#     'Facial pain': True}}},
#  {'consult_id': 16564,
#   'disease_tag': 'Carcinoid syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Excessive growth': True},
#    'implicit_inform_slots': {'Involuntary urination': True,
#     'Shoulder swelling': True}}},
#  {'consult_id': 7352,
#   'disease_tag': 'Amyotrophic lateral sclerosis ALS',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Weakness': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 2362,
#   'disease_tag': 'Fat embolism',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder cramps or spasms': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Facial pain': True,
#     'Pain during pregnancy': True,
#     'Joint stiffness or tightness': True,
#     'Pain or soreness of breast': True,
#     'Knee lump or mass': True,
#     'Excessive urination at night': True}}},
#  {'consult_id': 14405,
#   'disease_tag': 'Gout',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Ankle pain': True},
#    'implicit_inform_slots': {'Knee pain': True}}},
#  {'consult_id': 13185,
#   'disease_tag': 'Epidural hemorrhage',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Leg pain': True,
#     'Feeling hot and cold': True}}},
#  {'consult_id': 11448,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Vaginal bleeding after menopause': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 22805,
#   'disease_tag': 'Epididymitis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Swelling of scrotum': True},
#    'implicit_inform_slots': {'Pain in testicles': True}}},
#  {'consult_id': 20060,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg pain': True},
#    'implicit_inform_slots': {'Foot or toe pain': True,
#     'Low back pain': True,
#     'Neck pain': True,
#     'Abnormal involuntary movements': True,
#     'Problems with movement': True}}},
#  {'consult_id': 25994,
#   'disease_tag': 'Decubitus ulcer',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Difficulty speaking': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 12982,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Vaginal bleeding after menopause': True},
#    'implicit_inform_slots': {'Absence of menstruation': True}}},
#  {'consult_id': 14515,
#   'disease_tag': 'Eating disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Anxiety and nervousness': True,
#     'Depressive or psychotic symptoms': True}}},
#  {'consult_id': 21591,
#   'disease_tag': 'Fluid overload',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp abdominal pain': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Peripheral edema': True,
#     'Difficulty breathing': True,
#     'Vomiting': True}}},
#  {'consult_id': 675,
#   'disease_tag': 'Conversion disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Seizures': True,
#     'Allergic reaction': True,
#     'Fainting': True}}},
#  {'consult_id': 7465,
#   'disease_tag': 'Endometrial hyperplasia',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Unpredictable menstruation': True},
#    'implicit_inform_slots': {'Vaginal bleeding after menopause': True,
#     'Heavy menstrual flow': True}}},
#  {'consult_id': 12807,
#   'disease_tag': 'Dermatitis due to sun exposure',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Abnormal appearing skin': True,
#     'Irregular appearing scalp': True,
#     'Lack of growth': True}}},
#  {'consult_id': 859,
#   'disease_tag': 'Dissociative disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Anxiety and nervousness': True},
#    'implicit_inform_slots': {'Low self-esteem': True,
#     'Excessive anger': True}}},
#  {'consult_id': 11444,
#   'disease_tag': 'Graves disease',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fatigue': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 17837,
#   'disease_tag': 'Erectile dysfunction',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Retention of urine': True},
#    'implicit_inform_slots': {'Impotence': True}}},
#  {'consult_id': 27930,
#   'disease_tag': 'Dengue fever',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fever': True},
#    'implicit_inform_slots': {'Sore throat': True, 'Excessive anger': True}}},
#  {'consult_id': 692,
#   'disease_tag': 'Ankylosing spondylitis',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Low back pain': True},
#    'implicit_inform_slots': {'Back pain': True,
#     'Leg pain': True,
#     'Knee pain': True,
#     'Elbow pain': True}}},
#  {'consult_id': 28413,
#   'disease_tag': 'Drug abuse cocaine',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Drug abuse': True},
#    'implicit_inform_slots': {'Depression': True}}},
#  {'consult_id': 14003,
#   'disease_tag': 'Cyst of the eyelid',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Diminished vision': True},
#    'implicit_inform_slots': {'Mass on eyelid': True,
#     'Symptoms of eye': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 28328,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Acne or pimples': True}}},
#  {'consult_id': 5579,
#   'disease_tag': 'Graves disease',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Palpitations': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 21023,
#   'disease_tag': 'Female infertility of unknown cause',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Infertility': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 12171,
#   'disease_tag': 'Female infertility of unknown cause',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Long menstrual periods': True},
#    'implicit_inform_slots': {'Infertility': True}}},
#  {'consult_id': 20921,
#   'disease_tag': 'Conversion disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Seizures': True,
#     'Allergic reaction': True,
#     'Weakness': True,
#     'Abnormal involuntary movements': True,
#     'Fatigue': True,
#     'Focal weakness': True}}},
#  {'consult_id': 8437,
#   'disease_tag': 'Acne',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin moles': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 14738,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Knee pain': True},
#    'implicit_inform_slots': {'Problems with movement': True}}},
#  {'consult_id': 25422,
#   'disease_tag': 'Fracture of the rib',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Rib pain': True,
#     'Side pain': True,
#     'Ache all over': True}}},
#  {'consult_id': 7582,
#   'disease_tag': 'Ankylosing spondylitis',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hip pain': True},
#    'implicit_inform_slots': {'Back pain': True}}},
#  {'consult_id': 22789,
#   'disease_tag': 'Conversion disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Seizures': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 1443,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pelvic pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 17011,
#   'disease_tag': 'Cystic Fibrosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 21668,
#   'disease_tag': 'Carcinoid syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Loss of sex drive': True},
#    'implicit_inform_slots': {'Involuntary urination': True,
#     'Itchy eyelid': True}}},
#  {'consult_id': 1909,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Shoulder stiffness or tightness': True,
#     'Neck pain': True,
#     'Elbow pain': True}}},
#  {'consult_id': 13732,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Skin lesion': True,
#     'Acne or pimples': True,
#     'Foot or toe lump or mass': True}}},
#  ...]

# %%
test_data = goal_set['test']

# %%
def merge_slots(explicit_slots, implicit_slots):
    merged_slots = explicit_slots.copy() if isinstance(explicit_slots, dict) else {}  # explicit_inform_slots 복사
    # implicit_inform_slots의 각 항목을 merged_slots에 추가
    for key, value in implicit_slots.items():
        # 이미 merged_slots에 있는 경우에는 무시하고 추가
        if key not in merged_slots:
            merged_slots[key] = value
    return merged_slots

def merge_slots_for_disease(data):
    merged_slots_list = []
    for item in train_data:
        disease_tag = item['disease_tag']
        explicit_slots = item['goal']['explicit_inform_slots']
        implicit_slots = item['goal']['implicit_inform_slots']
        merged_slots = merge_slots(explicit_slots, implicit_slots)
        merged_slots_list.append({'disease_tag': disease_tag, 'merged_slots': merged_slots})
    return merged_slots_list

# 데이터에 대해 함수를 적용하여 결과 생성
merged_data = merge_slots_for_disease(train_data)

# %%
symptom_counts = {}

# merged_data를 순회하면서 각 질병에 대해 등장한 증상들의 등장 횟수 계산
for data in merged_data:
    disease_tag = data['disease_tag']
    symptoms = data['merged_slots']
    if disease_tag not in symptom_counts:
        symptom_counts[disease_tag] = {}
    for symptom, count in symptoms.items():
        if symptom not in symptom_counts[disease_tag]:
            symptom_counts[disease_tag][symptom] = 0
        symptom_counts[disease_tag][symptom] += 1

sorted_symptom_counts = dict(sorted(symptom_counts.items()))

total_symptom_diseases = {}
total_symptom_diseases_count = {}

# 주어진 데이터를 반복하면서 각 증상이 어떤 질병들에 속하는지 기록
for disease, symptoms in sorted_symptom_counts.items():
    for symptom in symptoms:
        if symptom not in total_symptom_diseases:
            total_symptom_diseases[symptom] = []
            total_symptom_diseases_count[symptom] = 0
        total_symptom_diseases[symptom].append(disease)
        total_symptom_diseases_count[symptom] += 1
        
total_sorted_symptom_diseases_count = sorted(total_symptom_diseases_count.items(), key=lambda x: x[1], reverse=True)

# %%
def assign_weights(total_sorted_symptom_diseases_count):
    # 각 증상별 질병 개수 추출
    counts = [count for _, count in total_sorted_symptom_diseases_count]

    # 가중치 부여
    weights = pd.cut(counts, bins=[0, 1, 2, 3, float('inf')], labels=[100, 50, 30, 10])

    # 결과 반환
    weighted_counts = [(symptom, weight) for (symptom, _), weight in zip(total_sorted_symptom_diseases_count, weights)]
    return weighted_counts

weighted_counts = assign_weights(total_sorted_symptom_diseases_count)

weighted_counts
# Out:
# [('Pain in eye', 10),
#  ('Skin rash', 10),
#  ('Fatigue', 10),
#  ('Problems with movement', 10),
#  ('Leg pain', 10),
#  ('Skin lesion', 10),
#  ('Dizziness', 10),
#  ('Headache', 10),
#  ('Back pain', 10),
#  ('Itching of skin', 10),
#  ('Diminished vision', 10),
#  ('Depressive or psychotic symptoms', 10),
#  ('Itchiness of eye', 10),
#  ('Symptoms of eye', 10),
#  ('Sharp abdominal pain', 10),
#  ('Ache all over', 10),
#  ('Paresthesia', 10),
#  ('Loss of sensation', 10),
#  ('Vomiting', 10),
#  ('Abnormal appearing skin', 10),
#  ('Skin swelling', 10),
#  ('Eye redness', 10),
#  ('Sharp chest pain', 10),
#  ('Nausea', 10),
#  ('Abnormal involuntary movements', 10),
#  ('Depression', 10),
#  ('Excessive anger', 10),
#  ('Wrist pain', 10),
#  ('Anxiety and nervousness', 10),
#  ('Neck pain', 10),
#  ('Arm pain', 10),
#  ('Ankle pain', 10),
#  ('Knee lump or mass', 10),
#  ('Swollen eye', 10),
#  ('Cough', 10),
#  ('Pain or soreness of breast', 10),
#  ('Skin growth', 10),
#  ('Allergic reaction', 10),
#  ('Lacrimation', 10),
#  ('Shortness of breath', 10),
#  ('Facial pain', 10),
#  ('Difficulty speaking', 10),
#  ('Fever', 10),
#  ('Acne or pimples', 10),
#  ('Wrist weakness', 10),
#  ('Foreign body sensation in eye', 10),
#  ('Spots or clouds in vision', 10),
#  ('Weakness', 10),
#  ('Shoulder pain', 10),
#  ('Delusions or hallucinations', 10),
#  ('Joint stiffness or tightness', 10),
#  ('Disturbance of memory', 10),
#  ('Knee pain', 10),
#  ('Hip pain', 10),
#  ('Foot or toe pain', 10),
#  ('Skin dryness, peeling, scaliness, or roughness', 10),
#  ('Peripheral edema', 10),
#  ('Shoulder cramps or spasms', 10),
#  ('Pain during pregnancy', 10),
#  ('Nailbiting', 10),
#  ('Low back pain', 10),
#  ('Lower body pain', 10),
#  ('Joint pain', 10),
#  ('Elbow cramps or spasms', 10),
#  ('Hand or finger pain', 10),
#  ('Frequent urination', 10),
#  ('Pelvic pain', 10),
#  ('Side pain', 10),
#  ('Weight gain', 10),
#  ('Fluid retention', 10),
#  ('Skin moles', 10),
#  ('Elbow weakness', 10),
#  ('Emotional symptoms', 10),
#  ('Excessive growth', 10),
#  ('Irregular appearing scalp', 10),
#  ('Skin irritation', 10),
#  ('Eye burns or stings', 10),
#  ('Double vision', 10),
#  ('Retention of urine', 10),
#  ('Insomnia', 10),
#  ('Elbow pain', 10),
#  ('Fears and phobias', 10),
#  ('Excessive urination at night', 10),
#  ('Low back weakness', 10),
#  ('Involuntary urination', 10),
#  ('Eyelid lesion or rash', 10),
#  ('Painful urination', 10),
#  ('Groin pain', 10),
#  ('Warts', 10),
#  ('Long menstrual periods', 10),
#  ('Blood in urine', 10),
#  ('Muscle pain', 10),
#  ('Difficulty in swallowing', 10),
#  ('Leg weakness', 10),
#  ('Mass on eyelid', 10),
#  ('Itchy eyelid', 10),
#  ('Loss of sex drive', 10),
#  ('Wrist swelling', 10),
#  ('Hand or finger swelling', 10),
#  ('Vaginal discharge', 10),
#  ('Lower abdominal pain', 10),
#  ('Vaginal pain', 10),
#  ('Seizures', 10),
#  ('Muscle swelling', 10),
#  ('Intermenstrual bleeding', 10),
#  ('Cramps and spasms', 10),
#  ('Absence of menstruation', 10),
#  ('Infertility', 30),
#  ('Feeling hot and cold', 30),
#  ('Blindness', 30),
#  ('Symptoms of the kidneys', 30),
#  ('Shoulder swelling', 30),
#  ('Hostile behavior', 30),
#  ('Low self-esteem', 30),
#  ('Restlessness', 30),
#  ('Abusing alcohol', 30),
#  ('Fainting', 30),
#  ('Lip swelling', 30),
#  ('Leg cramps or spasms', 30),
#  ('Rib pain', 30),
#  ('Irregular heartbeat', 30),
#  ('Diarrhea', 30),
#  ('Focal weakness', 30),
#  ('Pain in testicles', 30),
#  ('Vaginal itching', 30),
#  ('Bones are painful', 30),
#  ('Knee swelling', 30),
#  ('White discharge from eye', 30),
#  ('Abnormal movement of eyelid', 30),
#  ('Decreased appetite', 30),
#  ('Skin on leg or foot looks infected', 30),
#  ('Foot or toe swelling', 30),
#  ('Unpredictable menstruation', 30),
#  ('Leg swelling', 30),
#  ('Unwanted hair', 50),
#  ('Swelling of scrotum', 50),
#  ('Symptoms of the face', 50),
#  ('Burning abdominal pain', 50),
#  ('Stiffness all over', 50),
#  ('Nightmares', 50),
#  ('Muscle cramps, contractures, or spasms', 50),
#  ('Eye strain', 50),
#  ('Hand or finger weakness', 50),
#  ('Palpitations', 50),
#  ('Sleepiness', 50),
#  ('Vulvar sore', 50),
#  ('Neck cramps or spasms', 50),
#  ('Eyelid swelling', 50),
#  ('Irritable infant', 50),
#  ('Penile discharge', 50),
#  ('Penis pain', 50),
#  ('Diminished hearing', 50),
#  ('Lack of growth', 50),
#  ('Hoarse voice', 50),
#  ('Nasal congestion', 50),
#  ('Lymphedema', 50),
#  ('Feeling ill', 50),
#  ('Sweating', 50),
#  ('Sore throat', 50),
#  ('Infrequent menstruation', 50),
#  ('Hemoptysis', 50),
#  ('Suprapubic pain', 50),
#  ('Penis redness', 50),
#  ('Skin pain', 50),
#  ('Excessive appetite', 50),
#  ('Foot or toe stiffness or tightness', 50),
#  ('Back weakness', 50),
#  ('Hot flashes', 50),
#  ('Vaginal bleeding after menopause', 50),
#  ('Heavy menstrual flow', 50),
#  ('Painful sinuses', 50),
#  ('Pain during intercourse', 50),
#  ('Arm stiffness or tightness', 50),
#  ('Bleeding or discharge from nipple', 50),
#  ('Apnea', 100),
#  ('Cross-eyed', 100),
#  ('Bowlegged or knock-kneed', 100),
#  ('Too little hair', 100),
#  ('Nose deformity', 100),
#  ('Kidney mass', 100),
#  ('Chest tightness', 100),
#  ('Shoulder stiffness or tightness', 100),
#  ('Ankle stiffness or tightness', 100),
#  ('Skin on arm or hand looks infected', 100),
#  ('Temper problems', 100),
#  ('Swollen tongue', 100),
#  ('Congestion in chest', 100),
#  ('Muscle weakness', 100),
#  ('Increased heart rate', 100),
#  ('Frontal headache', 100),
#  ('Hand or finger stiffness or tightness', 100),
#  ('Arm weakness', 100),
#  ('Arm lump or mass', 100),
#  ('Neck swelling', 100),
#  ('Groin mass', 100),
#  ('Arm swelling', 100),
#  ('Eye deviation', 100),
#  ('Muscle stiffness or tightness', 100),
#  ('Problems during pregnancy', 100),
#  ('Knee weakness', 100),
#  ('Knee stiffness or tightness', 100),
#  ('Back stiffness or tightness', 100),
#  ('Back cramps or spasms', 100),
#  ('Unusual color or odor to urine', 100),
#  ('Feeling cold', 100),
#  ('Plugged feeling in ear', 100),
#  ('Ear pain', 100),
#  ('Redness in ear', 100),
#  ('Ringing in ear', 100),
#  ('Swollen or red tonsils', 100),
#  ('Fluid in ear', 100),
#  ('Sneezing', 100),
#  ('Diaper rash', 100),
#  ('Decreased heart rate', 100),
#  ('Bladder mass', 100),
#  ('Itching of scrotum', 100),
#  ('Wrinkles on skin', 100),
#  ('Drainage in throat', 100),
#  ('Sinus congestion', 100),
#  ('Bleeding gums', 100),
#  ('Symptoms of bladder', 100),
#  ('Wrist stiffness or tightness', 100),
#  ('Disturbance of smell or taste', 100),
#  ('Incontinence of stool', 100),
#  ('Itchy scalp', 100),
#  ('Hip stiffness or tightness', 100),
#  ('Polyuria', 100),
#  ('Thirst', 100),
#  ('Poor circulation', 100),
#  ('Hand or finger cramps or spasms', 100),
#  ('Bleeding from eye', 100),
#  ('Pulling at ears', 100),
#  ('Infant spitting up', 100),
#  ('Pus in urine', 100),
#  ('Drug abuse', 100),
#  ('Hysterical behavior', 100),
#  ('Throat swelling', 100),
#  ('Foot or toe lump or mass', 100),
#  ('Dry or flaky scalp', 100),
#  ('Difficulty eating', 100),
#  ('Vomiting blood', 100),
#  ('Mass on vulva', 100),
#  ('Abnormal size or shape of ear', 100),
#  ('Pus in sputum', 100),
#  ('Painful menstruation', 100),
#  ('Chills', 100),
#  ('Mass in scrotum', 100),
#  ('Swollen abdomen', 100),
#  ('Premature ejaculation', 100),
#  ('Impotence', 100),
#  ('Symptoms of prostate', 100),
#  ('Mouth ulcer', 100),
#  ('Coryza', 100),
#  ('Neck stiffness or tightness', 100),
#  ('Scanty menstrual flow', 100),
#  ('Irregular belly button', 100),
#  ('Lump or mass of breast', 100),
#  ('Frequent menstruation', 100),
#  ('Feet turned in', 100),
#  ('Difficulty breathing', 100),
#  ('Hurts to breath', 100),
#  ('Back mass or lump', 100),
#  ('Wrist lump or mass', 100),
#  ('Hand or finger lump or mass', 100),
#  ('Spotting or bleeding during pregnancy', 100),
#  ('Ankle swelling', 100)]

# %%
df_train = pd.DataFrame(train_data)

# explicit_inform_slots와 implicit_inform_slots에서 얻은 질병들을 결합하여 리스트로 만듦
disease_list = []
for index, row in df_train.iterrows():
    explicit_diseases = list(row['goal']['explicit_inform_slots'].keys())
    implicit_diseases = list(row['goal']['implicit_inform_slots'].keys())
    combined_diseases = explicit_diseases + implicit_diseases
    disease_list.extend(combined_diseases)

# disease_list에서 중복 제거
disease_list = list(set(disease_list))

# disease_list를 disease_tag에 매핑하는 데이터프레임 생성
rows = []
for disease in disease_list:
    related_tags = df_train[df_train.apply(lambda x: disease in x['goal']['explicit_inform_slots'] or disease in x['goal']['implicit_inform_slots'], axis=1)]['disease_tag'].tolist()
    rows.append({'Disease': disease, 'Disease_Tag': related_tags})

# 데이터프레임 생성
df_mapping = pd.DataFrame(rows)

print(df_mapping)
# Out:
#                                    Disease  \
# 0                                   Coryza
# 1                           Ringing in ear
# 2                                 Headache
# 3               Hip stiffness or tightness
# 4          Hand or finger cramps or spasms
# ..                                     ...
# 261  Hand or finger stiffness or tightness
# 262                 Elbow cramps or spasms
# 263                                  Apnea
# 264                   Painful menstruation
# 265                     Wrist lump or mass
#
#                                            Disease_Tag
# 0    [Erythema multiforme, Erythema multiforme, Ery...
# 1    [Conductive hearing loss, Conductive hearing l...
# 2    [Cerebral edema, Cerebral edema, Carbon monoxi...
# 3    [Diabetes insipidus, Diabetes insipidus, Diabe...
# 4    [Diabetic peripheral neuropathy, Diabetic peri...
# ..                                                 ...
# 261  [Carpal tunnel syndrome, Carpal tunnel syndrom...
# 262  [Carbon monoxide poisoning, Endometrial hyperp...
# 263  [Acanthosis nigricans, Acanthosis nigricans, A...
# 264  [Endometriosis, Endometriosis, Endometriosis, ...
# 265  [Ganglion cyst, Ganglion cyst, Ganglion cyst, ...
#
# [266 rows x 2 columns]

# %%
def calculate_symptom_prob(data, total_sorted_symptom_diseases_count):
    # 데이터프레임으로 변환
    df_train = pd.DataFrame(data)

    # explicit_inform_slots와 implicit_inform_slots에서 얻은 질병들을 결합하여 리스트로 만듦
    slots_list = []
    for index, row in df_train.iterrows():
        explicit_diseases = list(row['goal']['explicit_inform_slots'].keys())
        implicit_diseases = list(row['goal']['implicit_inform_slots'].keys())
        combined_slots = explicit_diseases + implicit_diseases
        slots_list.extend(combined_slots)

    # 각 항목이 등장하는 횟수를 세고 확률 계산
    total_slots = len(slots_list)
    slots_occurrences = pd.Series(slots_list).value_counts(normalize=True)

    # 질병과 증상에 대한 확률 분포를 DataFrame으로 만듦
    disease_symptom_prob = pd.DataFrame(index=df_train['disease_tag'].unique(), columns=slots_occurrences.index)

    # 질병과 증상에 대한 확률 계산하여 DataFrame에 채움
    for disease_tag in disease_symptom_prob.index:
        for symptom in disease_symptom_prob.columns:
            explicit_symptom = df_train[df_train['disease_tag'] == disease_tag]['goal'].apply(lambda x: symptom in x['explicit_inform_slots']).sum()
            implicit_symptom = df_train[df_train['disease_tag'] == disease_tag]['goal'].apply(lambda x: symptom in x['implicit_inform_slots']).sum()
            total_occurrences = len(df_train[df_train['disease_tag'] == disease_tag])
            occurrence_count = explicit_symptom + implicit_symptom
            disease_symptom_prob.loc[disease_tag, symptom] = occurrence_count / total_occurrences

    # 각 증상별 질병 수에 따라 가중치를 부여
    counts = [count for _, count in total_sorted_symptom_diseases_count]

    # 가중치 부여
    weights = pd.cut(counts, bins=[0, 2, 4, 8, 12, float('inf')], labels=[100, 50, 30, 20, 10])

    # 가중치를 적용하여 최종 확률 계산
    weighted_prob = disease_symptom_prob.copy()
    for (symptom, _), weight in zip(total_sorted_symptom_diseases_count, weights):
        if symptom in weighted_prob.columns:
            weighted_prob[symptom] *= float(weight)

    return weighted_prob

result = calculate_symptom_prob(train_data, total_sorted_symptom_diseases_count)
test_set = calculate_symptom_prob(test_data,total_sorted_symptom_diseases_count)

# %%
result.loc["Fibrocystic breast disease","Frequent menstruation"]
# Out:
# 1.9455252918287937

# %%
common_columns = result.columns.intersection(test_set.columns)
train_common = result[common_columns]
test_common = test_set[common_columns]

# %%
X_train = train_common.values  
y_train = train_common.index  # 질병
X_test = test_common.values
y_test = test_common.index

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
# 랜덤 포레스트 모델 생성
rf_model = RandomForestClassifier(n_estimators=30, random_state=42)  # 트리 개수는 100으로 설정하고, 난수 초기값을 고정합니다.

# 학습 데이터로 모델 학습
rf_model.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred_rf = rf_model.predict(X_test)

# 정확도 평가
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print("Random Forest Accuracy:", accuracy_rf)

# F1-score 계산
f1_score_rf = f1_score(y_test, y_pred_rf, average='weighted')
print("Random Forest F1-score:", f1_score_rf)

# AUC 계산
y_prob_rf = rf_model.predict_proba(X_test)
auc_rf = roc_auc_score(y_test, y_prob_rf, multi_class='ovr')
print("Random Forest AUC:", auc_rf)
# Out:
# Random Forest Accuracy: 0.9666666666666667
# Random Forest F1-score: 0.9555555555555556
# Random Forest AUC: 0.9993133583021224

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, roc_curve, roc_auc_score

# 로지스틱 회귀 모델 생성
logistic_model = LogisticRegression()

# 데이터 학습
logistic_model.fit(X_train, y_train)

# 테스트 데이터 예측
y_pred_logistic = logistic_model.predict(X_test)

# 정확도 평가
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
print("Logistic Regression Accuracy:", accuracy_logistic)

# f1-score 계산
f1_score_logistic = f1_score(y_test, y_pred_logistic, average='weighted')
print("Logistic Regression F1-score:", f1_score_logistic)

# ROC curve 및 AUC 계산
y_prob_logistic = logistic_model.predict_proba(X_test)
auc_logistic = roc_auc_score(y_test, y_prob_logistic, multi_class='ovr')
print("Logistic Regression AUC:", auc_logistic)
# Out:
# Logistic Regression Accuracy: 0.9666666666666667
# Logistic Regression F1-score: 0.9629629629629629
# Logistic Regression AUC: 0.9995006242197254
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.neighbors import KNeighborsClassifier

# KNN 모델 생성
knn_model = KNeighborsClassifier()

# 학습 데이터로 모델 학습
knn_model.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred_knn = knn_model.predict(X_test)

# 정확도 평가
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print("KNN Accuracy:", accuracy_knn)

# F1-score 계산
f1_score_knn = f1_score(y_test, y_pred_knn, average='weighted')
print("KNN F1-score:", f1_score_knn)
# Out:
# KNN Accuracy: 0.24444444444444444
# KNN F1-score: 0.160036075036075

# %%
from sklearn.naive_bayes import MultinomialNB

# 나이브 베이즈 모델 생성
nb_model = MultinomialNB()

# 학습 데이터로 모델 학습
nb_model.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred_nb = nb_model.predict(X_test)

# 정확도 평가
accuracy_nb = accuracy_score(y_test, y_pred_nb)
print("Naive Bayes Accuracy:", accuracy_nb)

# F1-score 계산
f1_score_nb = f1_score(y_test, y_pred_nb, average='weighted')
print("Naive Bayes F1-score:", f1_score_nb)
# Out:
# Naive Bayes Accuracy: 0.9666666666666667
# Naive Bayes F1-score: 0.9611111111111111

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, roc_curve

# SVM 모델 생성
svm_model = SVC(kernel='linear')

# 학습 데이터로 모델 학습
svm_model.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred_svm = svm_model.predict(X_test)

# 정확도 평가
accuracy_svm = accuracy_score(y_test, y_pred_svm)
print("SVM Accuracy:", accuracy_svm)

# f1-score 계산
f1_score_svm = f1_score(y_test, y_pred_svm, average='weighted')
print("SVM F1-score:", f1_score_svm)
# Out:
# SVM Accuracy: 0.9666666666666667
# SVM F1-score: 0.9629629629629629

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\user\anaconda3\lib\site-packages (1.2.5)
# Requirement already satisfied: graphviz in c:\users\user\anaconda3\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from catboost) (3.7.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\user\anaconda3\lib\site-packages (from catboost) (1.24.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\user\anaconda3\lib\site-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from catboost) (1.11.1)
# Requirement already satisfied: plotly in c:\users\user\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from plotly->catboost) (8.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from catboost import CatBoostClassifier

# 캣부스트 모델 생성
catboost_model = CatBoostClassifier()
catboost_model.fit(X_train, y_train.values)
y_pred_catboost = catboost_model.predict(X_test)

# 정확도 평가
accuracy_catboost = accuracy_score(y_test, y_pred_catboost)
print("CatBoost Accuracy:", accuracy_catboost)

# F1-score 계산
f1_score_catboost = f1_score(y_test, y_pred_catboost, average='weighted')
print("CatBoost F1-score:", f1_score_catboost)

# AUC 계산
y_prob_catboost = catboost_model.predict_proba(X_test)
auc_catboost = roc_auc_score(y_test, y_prob_catboost, multi_class='ovr')
print("CatBoost AUC:", auc_catboost)
# Out:
# Learning rate set to 0.069983
# 0:	learn: 4.4913897	total: 111ms	remaining: 1m 50s
# 1:	learn: 4.4816698	total: 221ms	remaining: 1m 50s
# 2:	learn: 4.4717090	total: 335ms	remaining: 1m 51s
# 3:	learn: 4.4606164	total: 460ms	remaining: 1m 54s
# 4:	learn: 4.4493282	total: 586ms	remaining: 1m 56s
# 5:	learn: 4.4389115	total: 722ms	remaining: 1m 59s
# 6:	learn: 4.4323649	total: 839ms	remaining: 1m 59s
# 7:	learn: 4.4229813	total: 960ms	remaining: 1m 59s
# 8:	learn: 4.4139066	total: 1.09s	remaining: 1m 59s
# 9:	learn: 4.4031800	total: 1.21s	remaining: 2m
# 10:	learn: 4.3914502	total: 1.34s	remaining: 2m
# 11:	learn: 4.3795090	total: 1.48s	remaining: 2m 1s
# 12:	learn: 4.3709279	total: 1.64s	remaining: 2m 4s
# 13:	learn: 4.3621863	total: 1.77s	remaining: 2m 4s
    max_prob_value = weighted_prob.loc[max_prob_disease, symptom]
    
    # 초기 confidence 값 설정
    confidence = {disease: 0 for disease in weighted_prob.index}
    
    # 초기 질병 설정
    current_disease = max_prob_disease

    # 진단에 사용된 증상들을 저장할 리스트
    diagnosed_symptoms = []
    
    while True:
        # 질병에 대한 confidence 값 누적
        confidence[current_disease] += max_prob_value

        # confidence가 threshold 이상인 질병 확인
        candidate_diseases = {disease: conf for disease, conf in confidence.items() if conf >= threshold}

        # threshold 이상인 질병이 존재하는 경우
        if candidate_diseases:
            # confidence가 threshold 이상인 질병 중 가장 높은 값을 가지는 질병 선택
            diagnosed_disease = max(candidate_diseases, key=candidate_diseases.get)
            return diagnosed_disease, confidence[diagnosed_disease], diagnosed_symptoms
        
        # threshold 이상인 질병이 없는 경우
        else:
            # 질병과 관련된 증상 중 가장 높은 증상 확인
            max_symptom = weighted_prob.loc[current_disease].idxmax()
        
            # 증상을 가지고 있는지 물어보고 증상이 있으면 해당 질병으로 이동
            if max_symptom == symptom:
                return current_disease, confidence[current_disease], diagnosed_symptoms
            else:
                # 해당 질병과 증상에 대한 확률값 가져오기
                max_prob_value = weighted_prob.loc[current_disease, max_symptom]
                diagnosed_symptoms.append(max_symptom)

                # 질의한 증상을 제외한 다른 증상들 중에서 질의할 수 있도록 설정
                available_symptoms = weighted_prob.loc[current_disease].index.difference([symptom])
                max_symptom = weighted_prob.loc[current_disease, available_symptoms].idxmax()

                # 다음 증상을 질의
                symptom = max_symptom

weighted_prob = result.astype(float)
# 초기 증상 입력
initial_symptom = 'Skin swelling'
diagnosed_disease, confidence, diagnosed_symptoms = diagnose_disease(initial_symptom, weighted_prob)

print(f"진단된 질병: {diagnosed_disease}, Confidence: {confidence}")
print("진단에 사용된 증상들:")
for symptom in diagnosed_symptoms:
    print(symptom)
# Out:
# 진단된 질병: Cat scratch disease, Confidence: 90.11494252873564
# 진단에 사용된 증상들:
# Neck swelling

# %%
given_symptoms = ['Diminished vision']  # 주어진 증상

# 각 질병에 대한 중요도(증상 확률 값 합산)
disease_scores = result[given_symptoms].sum(axis=1)

# 중요도가 0이 아닌 질병만 선택하여 정렬
non_zero_disease_scores = disease_scores[disease_scores > 0]

# 중요도를 기준으로 질병들을 정렬하여 순위를 매김
ranked_diseases = non_zero_disease_scores.sort_values(ascending=False)

# 결과 출력
print("질병 순위:")
for rank, (disease, score) in enumerate(ranked_diseases.items(), start=1):
    print(f"{rank}. {disease}: {score}")
# Out:
# 질병 순위:
# 1. Central retinal artery or vein occlusion: 17.36111111111111
# 2. Corneal disorder: 15.09433962264151
# 3. Diabetic retinopathy: 15.017543859649123
# 4. Aphakia: 14.921875
# 5. Acute glaucoma: 13.846153846153847
# 6. Endophthalmitis: 10.606060606060606
# 7. Cerebral edema: 9.003984063745019
# 8. Cyst of the eyelid: 8.841201716738198
# 9. Conjunctivitis due to allergy: 7.039999999999999
# 10. Chalazion: 6.1946902654867255
# 11. Ectropion: 5.735294117647058
# 12. Corneal abrasion: 5.503355704697986
