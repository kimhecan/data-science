# %%
import pandas as pd
import pickle
# %config Completer.use_jedi = False

goal_set = pickle.load(open('synthetic_dataset/goal_set.p', 'rb'))
slot_set = pickle.load(open('synthetic_dataset/slot_set.p', 'rb'))

# %%
lengths = {key: len(value) for key, value in goal_set.items()}
lengths
# Out:
# {'train': 24000, 'test': 6000, 'validate': 0}

# %%
train_data = goal_set['train']
test_data = goal_set['test']
train_data
# Out:
# [{'consult_id': 1059,
#   'disease_tag': 'Central retinal artery or vein occlusion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Spots or clouds in vision': True},
#    'implicit_inform_slots': {'Diminished vision': True,
#     'Symptoms of eye': True,
#     'Pain in eye': True}}},
#  {'consult_id': 19510,
#   'disease_tag': 'Degenerative disc disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Back pain': True,
#     'Low back pain': True,
#     'Neck pain': True,
#     'Hip pain': True,
#     'Ache all over': True}}},
#  {'consult_id': 25630,
#   'disease_tag': 'Diabetic retinopathy',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Foreign body sensation in eye': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 1467,
#   'disease_tag': 'Chronic back pain',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Low back pain': True},
#    'implicit_inform_slots': {'Back pain': True, 'Side pain': True}}},
#  {'consult_id': 5780,
#   'disease_tag': 'Air embolism',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Wrist pain': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Shoulder cramps or spasms': True,
#     'Facial pain': True,
#     'Ankle pain': True,
#     'Pain during pregnancy': True,
#     'Joint stiffness or tightness': True,
#     'Pain or soreness of breast': True,
#     'Knee lump or mass': True,
#     'Excessive urination at night': True}}},
#  {'consult_id': 26258,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Skin dryness, peeling, scaliness, or roughness': True}}},
#  {'consult_id': 16096,
#   'disease_tag': 'Diaper rash',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Diarrhea': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 6580,
#   'disease_tag': 'Air embolism',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Facial pain': True},
#    'implicit_inform_slots': {'Shoulder cramps or spasms': True,
#     'Ankle pain': True,
#     'Wrist pain': True,
#     'Excessive anger': True,
#     'Joint stiffness or tightness': True,
#     'Pain or soreness of breast': True,
#     'Knee lump or mass': True,
#     'Fatigue': True,
#     'Excessive urination at night': True}}},
#  {'consult_id': 22733,
#   'disease_tag': 'Conversion disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Sweating': True,
#     'Abnormal involuntary movements': True,
#     'Fatigue': True,
#     'Cough': True}}},
#  {'consult_id': 17308,
#   'disease_tag': 'Air embolism',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain or soreness of breast': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Shoulder cramps or spasms': True,
#     'Facial pain': True,
#     'Ankle pain': True,
#     'Pain during pregnancy': True,
#     'Excessive anger': True,
#     'Joint stiffness or tightness': True,
#     'Knee lump or mass': True,
#     'Fatigue': True,
#     'Excessive urination at night': True}}},
#  {'consult_id': 1564,
#   'disease_tag': 'Anxiety',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Abnormal involuntary movements': True}}},
#  {'consult_id': 29211,
#   'disease_tag': 'Conductive hearing loss',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Plugged feeling in ear': True},
#    'implicit_inform_slots': {'Diminished hearing': True,
#     'Ear pain': True,
#     'Redness in ear': True,
#     'Dizziness': True}}},
#  {'consult_id': 26235,
#   'disease_tag': 'Alcohol intoxication',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Anxiety and nervousness': True},
#    'implicit_inform_slots': {'Abusing alcohol': True,
#     'Sharp abdominal pain': True}}},
#  {'consult_id': 8094,
#   'disease_tag': 'Conjunctivitis due to allergy',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Eye redness': True},
#    'implicit_inform_slots': {'Lacrimation': True,
#     'Swollen eye': True,
#     'Symptoms of eye': True,
#     'Diminished vision': True,
#     'Cough': True}}},
#  {'consult_id': 16427,
#   'disease_tag': 'Conductive hearing loss',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Diminished hearing': True,
#     'Ringing in ear': True,
#     'Swollen or red tonsils': True}}},
#  {'consult_id': 16512,
#   'disease_tag': 'Drug reaction',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Allergic reaction': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Dizziness': True,
#     'Nausea': True,
#     'Shortness of breath': True}}},
#  {'consult_id': 25014,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hot flashes': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 16360,
#   'disease_tag': 'Granuloma inguinale',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Vaginal pain': True},
#    'implicit_inform_slots': {'Nausea': True, 'Sharp chest pain': True}}},
#  {'consult_id': 15081,
#   'disease_tag': 'Extrapyramidal effect of drugs',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Restlessness': True},
#    'implicit_inform_slots': {'Nausea': True,
#     'Neck stiffness or tightness': True}}},
#  {'consult_id': 15386,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in eye': True},
#    'implicit_inform_slots': {'Diminished vision': True,
#     'Eye redness': True,
#     'Symptoms of eye': True,
#     'White discharge from eye': True,
#     'Swollen eye': True}}},
#  {'consult_id': 18363,
#   'disease_tag': 'Encephalitis',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Disturbance of memory': True},
#    'implicit_inform_slots': {'Loss of sensation': True, 'Seizures': True}}},
#  {'consult_id': 27441,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Allergic reaction': True}}},
#  {'consult_id': 9641,
#   'disease_tag': 'Extrapyramidal effect of drugs',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Arm stiffness or tightness': True},
#    'implicit_inform_slots': {'Cramps and spasms': True}}},
#  {'consult_id': 27768,
#   'disease_tag': 'Actinic keratosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin growth': True},
#    'implicit_inform_slots': {'Abnormal appearing skin': True,
#     'Skin lesion': True,
#     'Skin dryness, peeling, scaliness, or roughness': True,
#     'Skin swelling': True,
#     'Itching of skin': True}}},
#  {'consult_id': 21778,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hot flashes': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 18706,
#   'disease_tag': 'Adjustment reaction',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Depression': True,
#     'Excessive anger': True,
#     'Insomnia': True}}},
#  {'consult_id': 7857,
#   'disease_tag': 'Drug abuse cocaine',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Abusing alcohol': True},
#    'implicit_inform_slots': {'Drug abuse': True}}},
#  {'consult_id': 29589,
#   'disease_tag': 'Chondromalacia of the patella',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg pain': True},
#    'implicit_inform_slots': {'Knee pain': True,
#     'Problems with movement': True,
#     'Knee weakness': True}}},
#  {'consult_id': 15191,
#   'disease_tag': 'Chalazion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Eye redness': True},
#    'implicit_inform_slots': {'Mass on eyelid': True,
#     'Swollen eye': True,
#     'Eyelid swelling': True,
#     'Eyelid lesion or rash': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 22535,
#   'disease_tag': 'Central retinal artery or vein occlusion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Blindness': True},
#    'implicit_inform_slots': {'Diminished vision': True,
#     'Symptoms of eye': True}}},
#  {'consult_id': 6047,
#   'disease_tag': 'Alzheimer disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Disturbance of memory': True}}},
#  {'consult_id': 20116,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp abdominal pain': True},
#    'implicit_inform_slots': {'Heavy menstrual flow': True}}},
#  {'consult_id': 26439,
#   'disease_tag': 'Acariasis',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Swelling of scrotum': True}}},
#  {'consult_id': 11928,
#   'disease_tag': 'Epidural hemorrhage',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 20634,
#   'disease_tag': 'Guillain Barre syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hand or finger pain': True},
#    'implicit_inform_slots': {'Leg pain': True,
#     'Loss of sensation': True,
#     'Ache all over': True,
#     'Dizziness': True}}},
#  {'consult_id': 3590,
#   'disease_tag': 'Acute kidney injury',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Retention of urine': True},
#    'implicit_inform_slots': {'Shortness of breath': True, 'Weakness': True}}},
#  {'consult_id': 3726,
#   'disease_tag': 'Cerebral edema',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Neck pain': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Vomiting': True,
#     'Loss of sensation': True}}},
#  {'consult_id': 7899,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Double vision': True},
#    'implicit_inform_slots': {'Eye redness': True,
#     'White discharge from eye': True}}},
#  {'consult_id': 9125,
#   'disease_tag': 'Drug reaction',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Lip swelling': True,
#     'Shortness of breath': True,
#     'Throat swelling': True}}},
#  {'consult_id': 16230,
#   'disease_tag': 'Diabetic peripheral neuropathy',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Foot or toe pain': True},
#    'implicit_inform_slots': {'Skin lesion': True}}},
#  {'consult_id': 27079,
#   'disease_tag': 'Cushing syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Weight gain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 7995,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Abnormal appearing skin': True},
#    'implicit_inform_slots': {'Itching of skin': True, 'Skin lesion': True}}},
#  {'consult_id': 21990,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Warts': True},
#    'implicit_inform_slots': {'Itching of skin': True,
#     'Skin dryness, peeling, scaliness, or roughness': True,
#     'Cough': True}}},
#  {'consult_id': 12775,
#   'disease_tag': 'Epididymitis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in testicles': True},
#    'implicit_inform_slots': {'Swelling of scrotum': True,
#     'Groin pain': True,
#     'Side pain': True,
#     'Painful urination': True}}},
#  {'consult_id': 86,
#   'disease_tag': 'Chickenpox',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fever': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Skin lesion': True}}},
#  {'consult_id': 19263,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin swelling': True},
#    'implicit_inform_slots': {'Knee pain': True}}},
#  {'consult_id': 19699,
#   'disease_tag': 'Dissociative disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 19386,
#   'disease_tag': 'Chickenpox',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Itching of skin': True}}},
#  {'consult_id': 23606,
#   'disease_tag': 'Chondromalacia of the patella',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Knee pain': True},
#    'implicit_inform_slots': {'Knee weakness': True,
#     'Elbow pain': True,
#     'Bones are painful': True}}},
#  {'consult_id': 14382,
#   'disease_tag': 'Cerebral edema',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Neck pain': True,
#     'Diminished vision': True,
#     'Loss of sensation': True,
#     'Nausea': True}}},
#  {'consult_id': 14328,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Intermenstrual bleeding': True},
#    'implicit_inform_slots': {'Vaginal bleeding after menopause': True}}},
#  {'consult_id': 27516,
#   'disease_tag': 'Decubitus ulcer',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 17279,
#   'disease_tag': 'Amyotrophic lateral sclerosis ALS',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fatigue': True},
#    'implicit_inform_slots': {'Problems with movement': True,
#     'Muscle weakness': True,
#     'Leg cramps or spasms': True}}},
#  {'consult_id': 1769,
#   'disease_tag': 'Adjustment reaction',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Anxiety and nervousness': True,
#     'Excessive anger': True}}},
#  {'consult_id': 20111,
#   'disease_tag': 'Chronic back pain',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {'Leg pain': True, 'Hip pain': True}}},
#  {'consult_id': 19480,
#   'disease_tag': 'Endometrial hyperplasia',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pelvic pain': True},
#    'implicit_inform_slots': {'Vaginal bleeding after menopause': True,
#     'Unpredictable menstruation': True,
#     'Involuntary urination': True,
#     'Vaginal discharge': True}}},
#  {'consult_id': 28758,
#   'disease_tag': 'Carbon monoxide poisoning',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fainting': True},
#    'implicit_inform_slots': {'Headache': True, 'Nausea': True}}},
#  {'consult_id': 7769,
#   'disease_tag': 'Chagas disease',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Excessive anger': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 5013,
#   'disease_tag': 'Carpal tunnel syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hand or finger pain': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Wrist pain': True,
#     'Neck pain': True}}},
#  {'consult_id': 26904,
#   'disease_tag': 'Endometrial hyperplasia',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Involuntary urination': True},
#    'implicit_inform_slots': {'Unpredictable menstruation': True}}},
#  {'consult_id': 19940,
#   'disease_tag': 'Dissociative disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Anxiety and nervousness': True,
#     'Excessive anger': True}}},
#  {'consult_id': 3996,
#   'disease_tag': 'Diabetes insipidus',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {'Difficulty in swallowing': True,
#     'Dizziness': True}}},
#  {'consult_id': 12006,
#   'disease_tag': 'Chronic pain disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Low back pain': True},
#    'implicit_inform_slots': {'Back pain': True,
#     'Leg pain': True,
#     'Headache': True,
#     'Sharp abdominal pain': True,
#     'Shoulder pain': True}}},
#  {'consult_id': 6762,
#   'disease_tag': 'Fracture of the pelvis',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hip pain': True},
#    'implicit_inform_slots': {'Groin pain': True, 'Ache all over': True}}},
#  {'consult_id': 2874,
#   'disease_tag': 'Concussion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Facial pain': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Dizziness': True,
#     'Nausea': True}}},
#  {'consult_id': 9180,
#   'disease_tag': 'Gonorrhea',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp abdominal pain': True},
#    'implicit_inform_slots': {'Penile discharge': True}}},
#  {'consult_id': 18054,
#   'disease_tag': 'Gout',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Wrist swelling': True},
#    'implicit_inform_slots': {'Foot or toe pain': True,
#     'Foot or toe swelling': True,
#     'Ankle pain': True}}},
#  {'consult_id': 12207,
#   'disease_tag': 'Extrapyramidal effect of drugs',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Delusions or hallucinations': True},
#    'implicit_inform_slots': {'Abnormal involuntary movements': True,
#     'Disturbance of memory': True,
#     'Problems with movement': True}}},
#  {'consult_id': 17117,
#   'disease_tag': 'Chancroid',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder cramps or spasms': True},
#    'implicit_inform_slots': {'Ankle pain': True,
#     'Pain or soreness of breast': True}}},
#  {'consult_id': 20286,
#   'disease_tag': 'Amyloidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Congestion in chest': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Anxiety and nervousness': True,
#     'Fever': True,
#     'Weakness': True}}},
#  {'consult_id': 13025,
#   'disease_tag': 'Conductive hearing loss',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Diminished hearing': True},
#    'implicit_inform_slots': {'Ear pain': True,
#     'Redness in ear': True,
#     'Ringing in ear': True,
#     'Difficulty speaking': True}}},
#  {'consult_id': 21650,
#   'disease_tag': 'Cystitis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lower abdominal pain': True},
#    'implicit_inform_slots': {'Blood in urine': True, 'Back pain': True}}},
#  {'consult_id': 1749,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Foot or toe pain': True},
#    'implicit_inform_slots': {'Knee pain': True,
#     'Cramps and spasms': True,
#     'Symptoms of eye': True,
#     'Weight gain': True}}},
#  {'consult_id': 791,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Loss of sensation': True},
#    'implicit_inform_slots': {'Hand or finger pain': True,
#     'Low back pain': True}}},
#  {'consult_id': 24033,
#   'disease_tag': 'Encephalitis',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg weakness': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Loss of sensation': True,
#     'Seizures': True,
#     'Dizziness': True,
#     'Leg pain': True,
#     'Problems with movement': True}}},
#  {'consult_id': 10394,
#   'disease_tag': 'Encephalitis',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Headache': True,
#     'Leg pain': True,
#     'Fatigue': True}}},
#  {'consult_id': 23176,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Itching of skin': True,
#     'Abnormal appearing skin': True}}},
#  {'consult_id': 26863,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lower abdominal pain': True},
#    'implicit_inform_slots': {'Pelvic pain': True,
#     'Sharp abdominal pain': True}}},
#  {'consult_id': 11005,
#   'disease_tag': 'Essential tremor',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Abnormal involuntary movements': True},
#    'implicit_inform_slots': {'Problems with movement': True}}},
#  {'consult_id': 9671,
#   'disease_tag': 'Drug abuse cocaine',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Drug abuse': True,
#     'Abusing alcohol': True,
#     'Depressive or psychotic symptoms': True}}},
#  {'consult_id': 11134,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Skin rash': True}}},
#  {'consult_id': 15276,
#   'disease_tag': 'Diaper rash',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Itching of skin': True},
#    'implicit_inform_slots': {'Diarrhea': True,
#     'Skin rash': True,
#     'Irritable infant': True}}},
#  {'consult_id': 16094,
#   'disease_tag': 'Adjustment reaction',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Hostile behavior': True}}},
#  {'consult_id': 6624,
#   'disease_tag': 'Gonorrhea',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Penile discharge': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 6097,
#   'disease_tag': 'Acute kidney injury',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 16311,
#   'disease_tag': 'Amyotrophic lateral sclerosis ALS',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Weakness': True},
#    'implicit_inform_slots': {'Hand or finger weakness': True}}},
#  {'consult_id': 339,
#   'disease_tag': 'Amyloidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fever': True},
#    'implicit_inform_slots': {'Weakness': True,
#     'Abnormal appearing skin': True}}},
#  {'consult_id': 16364,
#   'disease_tag': 'Actinic keratosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Abnormal appearing skin': True,
#     'Skin dryness, peeling, scaliness, or roughness': True,
#     'Skin moles': True}}},
#  {'consult_id': 19563,
#   'disease_tag': 'Gas gangrene',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Wrist pain': True},
#    'implicit_inform_slots': {'Sharp abdominal pain': True,
#     'Knee lump or mass': True,
#     'Pain in eye': True,
#     'Fatigue': True}}},
#  {'consult_id': 4346,
#   'disease_tag': 'Cat scratch disease',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Arm lump or mass': True},
#    'implicit_inform_slots': {'Neck swelling': True,
#     'Skin swelling': True,
#     'Groin mass': True,
#     'Skin rash': True,
#     'Loss of sensation': True,
#     'Arm swelling': True,
#     'Headache': True}}},
#  {'consult_id': 27942,
#   'disease_tag': 'Fibrocystic breast disease',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lump or mass of breast': True},
#    'implicit_inform_slots': {'Pain or soreness of breast': True,
#     'Bleeding or discharge from nipple': True}}},
#  {'consult_id': 7828,
#   'disease_tag': 'Diabetes insipidus',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {'Excessive appetite': True,
#     'Difficulty in swallowing': True,
#     'Frequent urination': True,
#     'Dizziness': True}}},
#  {'consult_id': 13246,
#   'disease_tag': 'Acariasis',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cross-eyed': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Itching of skin': True}}},
#  {'consult_id': 16560,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pelvic pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 19534,
#   'disease_tag': 'Factitious disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Disturbance of memory': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Depression': True,
#     'Paresthesia': True,
#     'Lip swelling': True}}},
#  {'consult_id': 120,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder stiffness or tightness': True},
#    'implicit_inform_slots': {'Shoulder pain': True}}},
#  {'consult_id': 8868,
#   'disease_tag': 'Carcinoid syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Excessive growth': True},
#    'implicit_inform_slots': {'Vulvar sore': True,
#     'Joint stiffness or tightness': True,
#     'Itchy eyelid': True}}},
#  {'consult_id': 1947,
#   'disease_tag': 'Degenerative disc disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {'Low back pain': True,
#     'Leg pain': True,
#     'Neck pain': True,
#     'Shoulder pain': True,
#     'Ache all over': True}}},
#  {'consult_id': 28436,
#   'disease_tag': 'Chickenpox',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Irritable infant': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Itching of skin': True,
#     'Ache all over': True,
#     'Skin lesion': True}}},
#  {'consult_id': 5509,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Shoulder stiffness or tightness': True,
#     'Ache all over': True}}},
#  {'consult_id': 24423,
#   'disease_tag': 'Ectropion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Symptoms of eye': True},
#    'implicit_inform_slots': {'Lacrimation': True,
#     'Eyelid lesion or rash': True,
#     'Swollen eye': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 14480,
#   'disease_tag': 'Endophthalmitis',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Itchiness of eye': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Eye redness': True,
#     'Swollen eye': True,
#     'Painful sinuses': True}}},
#  {'consult_id': 8488,
#   'disease_tag': 'Amyloidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fatigue': True},
#    'implicit_inform_slots': {'Symptoms of the kidneys': True,
#     'Weakness': True,
#     'Abnormal appearing skin': True}}},
#  {'consult_id': 29060,
#   'disease_tag': 'Chlamydia',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Penile discharge': True},
#    'implicit_inform_slots': {'Vaginal discharge': True,
#     'Sharp abdominal pain': True,
#     'Painful urination': True,
#     'Vaginal itching': True,
#     'Lower abdominal pain': True}}},
#  {'consult_id': 20625,
#   'disease_tag': 'Amyloidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shortness of breath': True},
#    'implicit_inform_slots': {'Fatigue': True,
#     'Anxiety and nervousness': True,
#     'Symptoms of the kidneys': True,
#     'Feeling hot and cold': True}}},
#  {'consult_id': 13768,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Abnormal appearing skin': True,
#     'Skin dryness, peeling, scaliness, or roughness': True,
#     'Cough': True}}},
#  {'consult_id': 22417,
#   'disease_tag': 'Eating disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Anxiety and nervousness': True},
#    'implicit_inform_slots': {'Depression': True,
#     'Depressive or psychotic symptoms': True,
#     'Decreased appetite': True}}},
#  {'consult_id': 21493,
#   'disease_tag': 'Concussion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 15194,
#   'disease_tag': 'Guillain Barre syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg weakness': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Hand or finger pain': True,
#     'Weakness': True,
#     'Problems with movement': True,
#     'Facial pain': True}}},
#  {'consult_id': 23450,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lacrimation': True},
#    'implicit_inform_slots': {'Eye redness': True}}},
#  {'consult_id': 23404,
#   'disease_tag': 'Fluid overload',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Hand or finger swelling': True}}},
#  {'consult_id': 22550,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Intermenstrual bleeding': True},
#    'implicit_inform_slots': {'Vaginal bleeding after menopause': True}}},
#  {'consult_id': 20582,
#   'disease_tag': 'Fibromyalgia',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Muscle pain': True},
#    'implicit_inform_slots': {'Back pain': True}}},
#  {'consult_id': 11716,
#   'disease_tag': 'Alzheimer disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Delusions or hallucinations': True},
#    'implicit_inform_slots': {'Depression': True}}},
#  {'consult_id': 18034,
#   'disease_tag': 'Fibromyalgia',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Ache all over': True,
#     'Neck pain': True,
#     'Muscle pain': True,
#     'Leg pain': True}}},
#  {'consult_id': 5402,
#   'disease_tag': 'Drug reaction',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Throat swelling': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Dizziness': True}}},
#  {'consult_id': 4711,
#   'disease_tag': 'De Quervain disease',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Wrist pain': True,
#     'Hand or finger pain': True}}},
#  {'consult_id': 20581,
#   'disease_tag': 'Fracture of the rib',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Back pain': True}}},
#  {'consult_id': 7456,
#   'disease_tag': 'Conjunctivitis due to allergy',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Eye redness': True},
#    'implicit_inform_slots': {'Itchiness of eye': True,
#     'Pain in eye': True,
#     'Nasal congestion': True}}},
#  {'consult_id': 750,
#   'disease_tag': 'Ganglion cyst',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Knee swelling': True},
#    'implicit_inform_slots': {'Leg pain': True, 'Wrist lump or mass': True}}},
#  {'consult_id': 29975,
#   'disease_tag': 'Dermatitis due to sun exposure',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin moles': True},
#    'implicit_inform_slots': {'Abnormal appearing skin': True,
#     'Skin rash': True}}},
#  {'consult_id': 28051,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pelvic pain': True},
#    'implicit_inform_slots': {'Sharp abdominal pain': True}}},
#  {'consult_id': 15254,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Problems with movement': True},
#    'implicit_inform_slots': {'Foot or toe pain': True}}},
#  {'consult_id': 25468,
#   'disease_tag': 'Degenerative disc disease',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {'Leg pain': True,
#     'Neck pain': True,
#     'Shoulder pain': True,
#     'Arm pain': True}}},
#  {'consult_id': 26528,
#   'disease_tag': 'Female infertility of unknown cause',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Infertility': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 275,
#   'disease_tag': 'Chronic kidney disease',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shortness of breath': True},
#    'implicit_inform_slots': {'Fatigue': True}}},
#  {'consult_id': 10852,
#   'disease_tag': 'Gas gangrene',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Ankle pain': True},
#    'implicit_inform_slots': {'Sharp abdominal pain': True,
#     'Pain in eye': True,
#     'Fatigue': True}}},
#  {'consult_id': 6183,
#   'disease_tag': 'Dermatitis due to sun exposure',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Abnormal appearing skin': True},
#    'implicit_inform_slots': {'Skin lesion': True,
#     'Irregular appearing scalp': True,
#     'Skin swelling': True}}},
#  {'consult_id': 23318,
#   'disease_tag': 'Cystic Fibrosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 29262,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Itching of skin': True,
#     'Acne or pimples': True}}},
#  {'consult_id': 14475,
#   'disease_tag': 'Acne',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Acne or pimples': True},
#    'implicit_inform_slots': {'Skin moles': True}}},
#  {'consult_id': 28630,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Acne or pimples': True,
#     'Frequent urination': True,
#     'Ankle pain': True}}},
#  {'consult_id': 621,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg pain': True},
#    'implicit_inform_slots': {'Loss of sensation': True}}},
#  {'consult_id': 18230,
#   'disease_tag': 'Corneal abrasion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lacrimation': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Swollen eye': True,
#     'Diminished vision': True,
#     'Foreign body sensation in eye': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 19696,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Ankle pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 15869,
#   'disease_tag': 'Fluid overload',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fluid retention': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Peripheral edema': True}}},
#  {'consult_id': 18797,
#   'disease_tag': 'De Quervain disease',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Wrist swelling': True},
#    'implicit_inform_slots': {'Wrist pain': True, 'Shoulder pain': True}}},
#  {'consult_id': 880,
#   'disease_tag': 'Diabetic ketoacidosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Vomiting': True},
#    'implicit_inform_slots': {'Nausea': True, 'Sharp abdominal pain': True}}},
#  {'consult_id': 17314,
#   'disease_tag': 'Fracture of the pelvis',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Groin pain': True},
#    'implicit_inform_slots': {'Hip pain': True,
#     'Problems with movement': True,
#     'Delusions or hallucinations': True,
#     'Focal weakness': True}}},
#  {'consult_id': 11154,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Low back pain': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Foot or toe pain': True,
#     'Paresthesia': True,
#     'Arm pain': True,
#     'Hand or finger pain': True}}},
#  {'consult_id': 10795,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Spots or clouds in vision': True},
#    'implicit_inform_slots': {'Diminished vision': True,
#     'Symptoms of eye': True,
#     'Foreign body sensation in eye': True,
#     'White discharge from eye': True}}},
#  {'consult_id': 6953,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Infertility': True},
#    'implicit_inform_slots': {'Pelvic pain': True,
#     'Heavy menstrual flow': True,
#     'Burning abdominal pain': True}}},
#  {'consult_id': 29134,
#   'disease_tag': 'Anxiety',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Anxiety and nervousness': True,
#     'Depression': True,
#     'Irregular heartbeat': True}}},
#  {'consult_id': 11948,
#   'disease_tag': 'Allergy',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin swelling': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Itching of skin': True,
#     'Swollen eye': True}}},
#  {'consult_id': 28164,
#   'disease_tag': 'Cystitis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp abdominal pain': True},
#    'implicit_inform_slots': {'Painful urination': True,
#     'Blood in urine': True}}},
#  {'consult_id': 13969,
#   'disease_tag': 'Granuloma inguinale',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Nausea': True},
#    'implicit_inform_slots': {'Sharp chest pain': True,
#     'Groin pain': True,
#     'Vaginal pain': True,
#     'Neck cramps or spasms': True}}},
#  {'consult_id': 14715,
#   'disease_tag': 'Carcinoid syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Involuntary urination': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 2474,
#   'disease_tag': 'Diabetic retinopathy',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lacrimation': True},
#    'implicit_inform_slots': {'Diminished vision': True, 'Pain in eye': True}}},
#  {'consult_id': 27217,
#   'disease_tag': 'Endophthalmitis',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin lesion': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Eye redness': True,
#     'Swollen eye': True,
#     'Lacrimation': True}}},
#  {'consult_id': 1217,
#   'disease_tag': 'Encephalitis',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Headache': True},
#    'implicit_inform_slots': {'Loss of sensation': True}}},
#  {'consult_id': 7130,
#   'disease_tag': 'Corneal disorder',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Symptoms of eye': True},
#    'implicit_inform_slots': {'Pain in eye': True}}},
#  {'consult_id': 3402,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Skin lesion': True, 'Allergic reaction': True}}},
#  {'consult_id': 14617,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder stiffness or tightness': True},
#    'implicit_inform_slots': {'Shoulder pain': True, 'Ache all over': True}}},
#  {'consult_id': 1722,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin dryness, peeling, scaliness, or roughness': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Itching of skin': True,
#     'Abnormal appearing skin': True,
#     'Cough': True}}},
#  {'consult_id': 5518,
#   'disease_tag': 'Granuloma inguinale',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Groin pain': True},
#    'implicit_inform_slots': {'Nausea': True,
#     'Sharp chest pain': True,
#     'Vaginal pain': True}}},
#  {'consult_id': 852,
#   'disease_tag': 'Guillain Barre syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg weakness': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Fever': True,
#     'Hand or finger pain': True}}},
#  {'consult_id': 16858,
#   'disease_tag': 'Carpal tunnel syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Arm pain': True},
#    'implicit_inform_slots': {'Loss of sensation': True,
#     'Paresthesia': True,
#     'Hand or finger weakness': True}}},
#  {'consult_id': 23064,
#   'disease_tag': 'Dissociative disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Anxiety and nervousness': True,
#     'Low self-esteem': True}}},
#  {'consult_id': 13618,
#   'disease_tag': 'Erectile dysfunction',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Premature ejaculation': True},
#    'implicit_inform_slots': {'Impotence': True, 'Pain in testicles': True}}},
#  {'consult_id': 24809,
#   'disease_tag': 'Cystic Fibrosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Feeling ill': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 14703,
#   'disease_tag': 'Concussion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Neck pain': True},
#    'implicit_inform_slots': {'Headache': True}}},
#  {'consult_id': 8096,
#   'disease_tag': 'Ectropion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in eye': True},
#    'implicit_inform_slots': {'Lacrimation': True,
#     'Abnormal movement of eyelid': True,
#     'Eyelid lesion or rash': True}}},
#  {'consult_id': 24946,
#   'disease_tag': 'Epidural hemorrhage',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depressive or psychotic symptoms': True},
#    'implicit_inform_slots': {'Side pain': True,
#     'Dizziness': True,
#     'Leg pain': True}}},
#  {'consult_id': 16546,
#   'disease_tag': 'De Quervain disease',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Wrist pain': True,
#     'Wrist swelling': True,
#     'Arm pain': True,
#     'Peripheral edema': True}}},
#  {'consult_id': 8741,
#   'disease_tag': 'Diabetic retinopathy',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Lacrimation': True},
#    'implicit_inform_slots': {'Itchiness of eye': True}}},
#  {'consult_id': 5732,
#   'disease_tag': 'Cyst of the eyelid',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Symptoms of eye': True},
#    'implicit_inform_slots': {'Mass on eyelid': True, 'Pain in eye': True}}},
#  {'consult_id': 19349,
#   'disease_tag': 'Eczema',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Allergic reaction': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Skin dryness, peeling, scaliness, or roughness': True}}},
#  {'consult_id': 1282,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Foot or toe lump or mass': True},
#    'implicit_inform_slots': {'Skin rash': True,
#     'Skin lesion': True,
#     'Itching of skin': True,
#     'Abnormal appearing skin': True}}},
#  {'consult_id': 28431,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
# ...
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Back pain': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Side pain': True}}},
#  {'consult_id': 27922,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Loss of sensation': True},
#    'implicit_inform_slots': {'Foot or toe pain': True, 'Arm pain': True}}},
#  {'consult_id': 1716,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder stiffness or tightness': True},
#    'implicit_inform_slots': {'Shoulder pain': True, 'Neck pain': True}}},
#  {'consult_id': 21088,
#   'disease_tag': 'Concussion',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sleepiness': True},
#    'implicit_inform_slots': {'Headache': True, 'Neck pain': True}}},
#  {'consult_id': 6093,
#   'disease_tag': 'Conductive hearing loss',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Diminished hearing': True},
#    'implicit_inform_slots': {'Ear pain': True,
#     'Plugged feeling in ear': True,
#     'Ringing in ear': True}}},
#  {'consult_id': 15762,
#   'disease_tag': 'Gout',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hand or finger pain': True},
#    'implicit_inform_slots': {'Foot or toe pain': True, 'Knee pain': True}}},
#  {'consult_id': 14330,
#   'disease_tag': 'Acute kidney injury',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Kidney mass': True},
#    'implicit_inform_slots': {'Blood in urine': True}}},
#  {'consult_id': 27297,
#   'disease_tag': 'Allergy',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Allergic reaction': True}}},
#  {'consult_id': 1325,
#   'disease_tag': 'Allergy',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Swollen tongue': True},
#    'implicit_inform_slots': {'Skin rash': True, 'Cough': True}}},
#  {'consult_id': 16941,
#   'disease_tag': 'Essential tremor',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Abnormal involuntary movements': True,
#     'Loss of sensation': True}}},
#  {'consult_id': 20996,
#   'disease_tag': 'Female infertility of unknown cause',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Infertility': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 17320,
#   'disease_tag': 'Drug abuse cocaine',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Drug abuse': True}}},
#  {'consult_id': 16357,
#   'disease_tag': 'Eating disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Difficulty eating': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True}}},
#  {'consult_id': 5615,
#   'disease_tag': 'De Quervain disease',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Arm pain': True},
#    'implicit_inform_slots': {'Wrist pain': True,
#     'Hand or finger swelling': True}}},
#  {'consult_id': 21682,
#   'disease_tag': 'Cerebral edema',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Focal weakness': True},
#    'implicit_inform_slots': {'Neck pain': True, 'Vomiting': True}}},
#  {'consult_id': 27134,
#   'disease_tag': 'Ectropion',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in eye': True},
#    'implicit_inform_slots': {'Symptoms of eye': True,
#     'Eye redness': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 6067,
#   'disease_tag': 'Carbon monoxide poisoning',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 28521,
#   'disease_tag': 'Acute glaucoma',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Eye redness': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Spots or clouds in vision': True}}},
#  {'consult_id': 28451,
#   'disease_tag': 'Acne',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Acne or pimples': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 23360,
#   'disease_tag': 'Acanthosis nigricans',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Weight gain': True},
#    'implicit_inform_slots': {'Pain or soreness of breast': True,
#     'Warts': True}}},
#  {'consult_id': 28520,
#   'disease_tag': 'Conjunctivitis due to allergy',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Symptoms of eye': True},
#    'implicit_inform_slots': {'Itchiness of eye': True,
#     'Pain in eye': True,
#     'Nasal congestion': True,
#     'Swollen eye': True,
#     'Allergic reaction': True}}},
#  {'consult_id': 13700,
#   'disease_tag': 'Decubitus ulcer',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Disturbance of smell or taste': True},
#    'implicit_inform_slots': {'Skin on leg or foot looks infected': True}}},
#  {'consult_id': 21789,
#   'disease_tag': 'Dengue fever',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pain in eye': True},
#    'implicit_inform_slots': {'Sore throat': True,
#     'Fever': True,
#     'Wrist pain': True,
#     'Joint stiffness or tightness': True,
#     'Facial pain': True}}},
#  {'consult_id': 16564,
#   'disease_tag': 'Carcinoid syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Excessive growth': True},
#    'implicit_inform_slots': {'Involuntary urination': True,
#     'Shoulder swelling': True}}},
#  {'consult_id': 7352,
#   'disease_tag': 'Amyotrophic lateral sclerosis ALS',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Weakness': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 2362,
#   'disease_tag': 'Fat embolism',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder cramps or spasms': True},
#    'implicit_inform_slots': {'Pain in eye': True,
#     'Facial pain': True,
#     'Pain during pregnancy': True,
#     'Joint stiffness or tightness': True,
#     'Pain or soreness of breast': True,
#     'Knee lump or mass': True,
#     'Excessive urination at night': True}}},
#  {'consult_id': 14405,
#   'disease_tag': 'Gout',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Ankle pain': True},
#    'implicit_inform_slots': {'Knee pain': True}}},
#  {'consult_id': 13185,
#   'disease_tag': 'Epidural hemorrhage',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Dizziness': True},
#    'implicit_inform_slots': {'Depressive or psychotic symptoms': True,
#     'Leg pain': True,
#     'Feeling hot and cold': True}}},
#  {'consult_id': 11448,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Vaginal bleeding after menopause': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 22805,
#   'disease_tag': 'Epididymitis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Swelling of scrotum': True},
#    'implicit_inform_slots': {'Pain in testicles': True}}},
#  {'consult_id': 20060,
#   'disease_tag': 'Complex regional pain syndrome',
#   'group_id': '6',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Leg pain': True},
#    'implicit_inform_slots': {'Foot or toe pain': True,
#     'Low back pain': True,
#     'Neck pain': True,
#     'Abnormal involuntary movements': True,
#     'Problems with movement': True}}},
#  {'consult_id': 25994,
#   'disease_tag': 'Decubitus ulcer',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Difficulty speaking': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 12982,
#   'disease_tag': 'Endometrial cancer',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Vaginal bleeding after menopause': True},
#    'implicit_inform_slots': {'Absence of menstruation': True}}},
#  {'consult_id': 14515,
#   'disease_tag': 'Eating disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Anxiety and nervousness': True,
#     'Depressive or psychotic symptoms': True}}},
#  {'consult_id': 21591,
#   'disease_tag': 'Fluid overload',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp abdominal pain': True},
#    'implicit_inform_slots': {'Shortness of breath': True,
#     'Peripheral edema': True,
#     'Difficulty breathing': True,
#     'Vomiting': True}}},
#  {'consult_id': 675,
#   'disease_tag': 'Conversion disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Seizures': True,
#     'Allergic reaction': True,
#     'Fainting': True}}},
#  {'consult_id': 7465,
#   'disease_tag': 'Endometrial hyperplasia',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Unpredictable menstruation': True},
#    'implicit_inform_slots': {'Vaginal bleeding after menopause': True,
#     'Heavy menstrual flow': True}}},
#  {'consult_id': 12807,
#   'disease_tag': 'Dermatitis due to sun exposure',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Abnormal appearing skin': True,
#     'Irregular appearing scalp': True,
#     'Lack of growth': True}}},
#  {'consult_id': 859,
#   'disease_tag': 'Dissociative disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Anxiety and nervousness': True},
#    'implicit_inform_slots': {'Low self-esteem': True,
#     'Excessive anger': True}}},
#  {'consult_id': 11444,
#   'disease_tag': 'Graves disease',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fatigue': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 17837,
#   'disease_tag': 'Erectile dysfunction',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Retention of urine': True},
#    'implicit_inform_slots': {'Impotence': True}}},
#  {'consult_id': 27930,
#   'disease_tag': 'Dengue fever',
#   'group_id': '1',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Fever': True},
#    'implicit_inform_slots': {'Sore throat': True, 'Excessive anger': True}}},
#  {'consult_id': 692,
#   'disease_tag': 'Ankylosing spondylitis',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Low back pain': True},
#    'implicit_inform_slots': {'Back pain': True,
#     'Leg pain': True,
#     'Knee pain': True,
#     'Elbow pain': True}}},
#  {'consult_id': 28413,
#   'disease_tag': 'Drug abuse cocaine',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Drug abuse': True},
#    'implicit_inform_slots': {'Depression': True}}},
#  {'consult_id': 14003,
#   'disease_tag': 'Cyst of the eyelid',
#   'group_id': '7',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Diminished vision': True},
#    'implicit_inform_slots': {'Mass on eyelid': True,
#     'Symptoms of eye': True,
#     'Itchiness of eye': True}}},
#  {'consult_id': 28328,
#   'disease_tag': 'Contact dermatitis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Acne or pimples': True}}},
#  {'consult_id': 5579,
#   'disease_tag': 'Graves disease',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Palpitations': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 21023,
#   'disease_tag': 'Female infertility of unknown cause',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Infertility': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 12171,
#   'disease_tag': 'Female infertility of unknown cause',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Long menstrual periods': True},
#    'implicit_inform_slots': {'Infertility': True}}},
#  {'consult_id': 20921,
#   'disease_tag': 'Conversion disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Depression': True},
#    'implicit_inform_slots': {'Seizures': True,
#     'Allergic reaction': True,
#     'Weakness': True,
#     'Abnormal involuntary movements': True,
#     'Fatigue': True,
#     'Focal weakness': True}}},
#  {'consult_id': 8437,
#   'disease_tag': 'Acne',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin moles': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 14738,
#   'disease_tag': 'Flat feet',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Knee pain': True},
#    'implicit_inform_slots': {'Problems with movement': True}}},
#  {'consult_id': 25422,
#   'disease_tag': 'Fracture of the rib',
#   'group_id': '19',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Sharp chest pain': True},
#    'implicit_inform_slots': {'Rib pain': True,
#     'Side pain': True,
#     'Ache all over': True}}},
#  {'consult_id': 7582,
#   'disease_tag': 'Ankylosing spondylitis',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Hip pain': True},
#    'implicit_inform_slots': {'Back pain': True}}},
#  {'consult_id': 22789,
#   'disease_tag': 'Conversion disorder',
#   'group_id': '5',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Seizures': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 1443,
#   'disease_tag': 'Endometriosis',
#   'group_id': '14',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Pelvic pain': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 17011,
#   'disease_tag': 'Cystic Fibrosis',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Cough': True},
#    'implicit_inform_slots': {}}},
#  {'consult_id': 21668,
#   'disease_tag': 'Carcinoid syndrome',
#   'group_id': '4',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Loss of sex drive': True},
#    'implicit_inform_slots': {'Involuntary urination': True,
#     'Itchy eyelid': True}}},
#  {'consult_id': 1909,
#   'disease_tag': 'Adhesive capsulitis of the shoulder',
#   'group_id': '13',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Shoulder pain': True},
#    'implicit_inform_slots': {'Shoulder stiffness or tightness': True,
#     'Neck pain': True,
#     'Elbow pain': True}}},
#  {'consult_id': 13732,
#   'disease_tag': 'Dyshidrosis',
#   'group_id': '12',
#   'goal': {'request_slots': {'disease': 'UNK'},
#    'explicit_inform_slots': {'Skin rash': True},
#    'implicit_inform_slots': {'Skin lesion': True,
#     'Acne or pimples': True,
#     'Foot or toe lump or mass': True}}},
#  ...]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
# 데이터 매핑
X_train = [list(item['goal']['explicit_inform_slots'].keys())[0] for item in train_data]
Y_train = [list((item['goal']['implicit_inform_slots'].keys())) for item in train_data]

X_train_expanded = []
Y_train_expanded = []

for x, ys in zip(X_train, Y_train):
    for y in ys:
        X_train_expanded.append(x)
        Y_train_expanded.append(y)

# TF-IDF 변환
vectorizer = TfidfVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train_expanded)

nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_vectorized, Y_train_expanded)

test_input = ['Spots or clouds in vision']
test_input_vectorized = vectorizer.transform(test_input)
predicted_output = nb_classifier.predict(test_input_vectorized)

print("입력 'a'일 때 예측된 레이블:", predicted_output)

# 순위
predicted_probabilities = nb_classifier.predict_proba(test_input_vectorized)


# # 예측된 확률을 내림차순으로 정렬
sorted_indices = predicted_probabilities.argsort()[0][::-1]


print("입력 'Spots or clouds in vision'에 대한 상위 5개")
for i in range(5):
    class_label = nb_classifier.classes_[sorted_indices[i]]
    probability = predicted_probabilities[0, sorted_indices[i]]
    print(f"{i+1}등 - {class_label}: {probability}")
# Out:
# 입력 'a'일 때 예측된 레이블: ['Diminished vision']
# 입력 'Spots or clouds in vision'에 대한 상위 5개
# 1등 - Diminished vision: 0.3002679951997312
# 2등 - Symptoms of eye: 0.16742204448894427
# 3등 - Pain in eye: 0.13072107047882742
# 4등 - Eye redness: 0.09230921387434955
# 5등 - Itchiness of eye: 0.07004288628508877

# %%
from sklearn.metrics import accuracy_score

# 테스트 데이터 준비
X_test = [list(item['goal']['explicit_inform_slots'].keys())[0] for item in test_data]
Y_test = [list((item['goal']['implicit_inform_slots'].keys())) for item in test_data]

X_test_expanded = []
Y_test_expanded = []

for x, ys in zip(X_test, Y_test):
    for y in ys:
        X_test_expanded.append(x)
        Y_test_expanded.append(y)

# TF-IDF 변환
X_test_vectorized = vectorizer.transform(X_test_expanded)

# 모델을 사용하여 테스트 데이터에 대한 예측 수행
predicted_test_output = nb_classifier.predict(X_test_vectorized)

# 정확도 계산
accuracy = accuracy_score(Y_test_expanded, predicted_test_output)
print("모델 정확도:", accuracy)
# Out:
# 모델 정확도: 0.13138075313807532

# %%
X_test = [list(item['goal']['explicit_inform_slots'].keys())[0] for item in test_data]
Y_test = [list(item['goal']['implicit_inform_slots'].keys()) for item in test_data]

X_test_dummy = pd.get_dummies(X_test)
X_test_dummy.reindex(columns=X_train_dummy.columns, fill_value=False)
X_test_dummy
# Y_test_transform = mlb.transform(Y_test)

# predictions = model.predict(X_test_dummy)
# accuracy = accuracy_score(Y_test_transform, predictions)
# print("Accuracy:", accuracy)
# Out:
#       Abnormal appearing skin  Abnormal involuntary movements  \
# 0                       False                           False
# 1                       False                           False
# 2                       False                           False
# 3                       False                           False
# 4                       False                           False
# ...                       ...                             ...
# 5995                    False                           False
# 5996                    False                           False
# 5997                    False                           False
# 5998                    False                           False
# 5999                    False                           False
#
#       Abnormal movement of eyelid  Absence of menstruation  Abusing alcohol  \
# 0                           False                    False            False
# 1                           False                    False            False
# 2                           False                    False            False
# 3                           False                    False            False
# 4                           False                    False            False
# ...                           ...                      ...              ...
# 5995                        False                    False            False
# 5996                        False                    False            False
# 5997                        False                    False            False
# 5998                        False                    False            False
# 5999                        False                    False            False
#
#       Ache all over  Acne or pimples  Allergic reaction  Ankle pain  \
# 0             False            False              False       False
# 1             False            False              False       False
# 2             False            False              False       False
# 3             False            False              False       False
# 4             False            False              False       False
# ...             ...              ...                ...         ...
# 5995          False            False              False       False
# 5996          False            False              False       False
# 5997          False            False              False       False
# 5998          False            False              False       False
# 5999          False            False              False       False
#
#       Ankle stiffness or tightness  ...  Warts  Weakness  Weight gain  \
# 0                            False  ...  False     False        False
# 1                            False  ...  False     False        False
# 2                            False  ...  False     False        False
# 3                            False  ...  False     False        False
# 4                            False  ...  False     False        False
# ...                            ...  ...    ...       ...          ...
# 5995                         False  ...  False     False        False
# 5996                         False  ...  False     False        False
# 5997                         False  ...  False     False        False
# 5998                         False  ...  False     False        False
# 5999                         False  ...  False     False        False
#
#       White discharge from eye  Wrinkles on skin  Wrist lump or mass  \
# 0                        False             False               False
# 1                        False             False               False
# 2                        False             False               False
# 3                        False             False               False
# 4                        False             False               False
# ...                        ...               ...                 ...
# 5995                     False             False               False
# 5996                     False             False               False
# 5997                     False             False               False
# 5998                     False             False               False
# 5999                     False             False               False
#
#       Wrist pain  Wrist stiffness or tightness  Wrist swelling  Wrist weakness
# 0          False                         False           False           False
# 1          False                         False           False           False
# 2          False                         False           False           False
# 3          False                         False           False           False
# 4          False                         False           False           False
# ...          ...                           ...             ...             ...
# 5995       False                         False           False           False
# 5996       False                         False           False           False
# 5997       False                         False           False           False
# 5998       False                         False           False           False
# 5999       False                         False           False           False
#
# [6000 rows x 244 columns]

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
import pandas as pd

X_train = [list(item['goal']['explicit_inform_slots'].keys())[0] for item in train_data]
Y_train = [list((item['goal']['implicit_inform_slots'].keys())) for item in train_data]

X_train_expanded = []
Y_train_expanded = []

for x, ys in zip(X_train, Y_train):
    for y in ys:
        X_train_expanded.append(x)
        Y_train_expanded.append(y)


X_train_dummy = pd.get_dummies(X_train_expanded)
Y_train_tranform = mlb.fit_transform(Y_train_expanded)
Y_train
# Out:
# [['Diminished vision', 'Symptoms of eye', 'Pain in eye'],
#  ['Back pain', 'Low back pain', 'Neck pain', 'Hip pain', 'Ache all over'],
#  [],
#  ['Back pain', 'Side pain'],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Facial pain',
#   'Ankle pain',
#   'Pain during pregnancy',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Excessive urination at night'],
#  ['Skin dryness, peeling, scaliness, or roughness'],
#  [],
#  ['Shoulder cramps or spasms',
#   'Ankle pain',
#   'Wrist pain',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Sweating', 'Abnormal involuntary movements', 'Fatigue', 'Cough'],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Facial pain',
#   'Ankle pain',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Shortness of breath', 'Abnormal involuntary movements'],
#  ['Diminished hearing', 'Ear pain', 'Redness in ear', 'Dizziness'],
#  ['Abusing alcohol', 'Sharp abdominal pain'],
#  ['Lacrimation',
#   'Swollen eye',
#   'Symptoms of eye',
#   'Diminished vision',
#   'Cough'],
#  ['Diminished hearing', 'Ringing in ear', 'Swollen or red tonsils'],
#  ['Skin rash', 'Dizziness', 'Nausea', 'Shortness of breath'],
#  [],
#  ['Nausea', 'Sharp chest pain'],
#  ['Nausea', 'Neck stiffness or tightness'],
#  ['Diminished vision',
#   'Eye redness',
#   'Symptoms of eye',
#   'White discharge from eye',
#   'Swollen eye'],
#  ['Loss of sensation', 'Seizures'],
#  ['Allergic reaction'],
#  ['Cramps and spasms'],
#  ['Abnormal appearing skin',
#   'Skin lesion',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Skin swelling',
#   'Itching of skin'],
#  [],
#  ['Depression', 'Excessive anger', 'Insomnia'],
#  ['Drug abuse'],
#  ['Knee pain', 'Problems with movement', 'Knee weakness'],
#  ['Mass on eyelid',
#   'Swollen eye',
#   'Eyelid swelling',
#   'Eyelid lesion or rash',
#   'Itchiness of eye'],
#  ['Diminished vision', 'Symptoms of eye'],
#  ['Disturbance of memory'],
#  ['Heavy menstrual flow'],
#  ['Skin rash', 'Swelling of scrotum'],
#  [],
#  ['Leg pain', 'Loss of sensation', 'Ache all over', 'Dizziness'],
#  ['Shortness of breath', 'Weakness'],
#  ['Headache', 'Vomiting', 'Loss of sensation'],
#  ['Eye redness', 'White discharge from eye'],
#  ['Lip swelling', 'Shortness of breath', 'Throat swelling'],
#  ['Skin lesion'],
#  [],
#  ['Itching of skin', 'Skin lesion'],
#  ['Itching of skin',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Cough'],
#  ['Swelling of scrotum', 'Groin pain', 'Side pain', 'Painful urination'],
#  ['Skin rash', 'Skin lesion'],
#  ['Knee pain'],
#  [],
#  ['Itching of skin'],
#  ['Knee weakness', 'Elbow pain', 'Bones are painful'],
#  ['Headache', 'Neck pain', 'Diminished vision', 'Loss of sensation', 'Nausea'],
#  ['Vaginal bleeding after menopause'],
#  [],
#  ['Problems with movement', 'Muscle weakness', 'Leg cramps or spasms'],
#  ['Anxiety and nervousness', 'Excessive anger'],
#  ['Leg pain', 'Hip pain'],
#  ['Vaginal bleeding after menopause',
#   'Unpredictable menstruation',
#   'Involuntary urination',
#   'Vaginal discharge'],
#  ['Headache', 'Nausea'],
#  [],
#  ['Loss of sensation', 'Wrist pain', 'Neck pain'],
#  ['Unpredictable menstruation'],
#  ['Depressive or psychotic symptoms',
#   'Anxiety and nervousness',
#   'Excessive anger'],
#  ['Difficulty in swallowing', 'Dizziness'],
#  ['Back pain',
#   'Leg pain',
#   'Headache',
#   'Sharp abdominal pain',
#   'Shoulder pain'],
#  ['Groin pain', 'Ache all over'],
#  ['Headache', 'Dizziness', 'Nausea'],
#  ['Penile discharge'],
#  ['Foot or toe pain', 'Foot or toe swelling', 'Ankle pain'],
#  ['Abnormal involuntary movements',
#   'Disturbance of memory',
#   'Problems with movement'],
#  ['Ankle pain', 'Pain or soreness of breast'],
#  ['Shortness of breath', 'Anxiety and nervousness', 'Fever', 'Weakness'],
#  ['Ear pain', 'Redness in ear', 'Ringing in ear', 'Difficulty speaking'],
#  ['Blood in urine', 'Back pain'],
#  ['Knee pain', 'Cramps and spasms', 'Symptoms of eye', 'Weight gain'],
#  ['Hand or finger pain', 'Low back pain'],
#  ['Headache',
#   'Loss of sensation',
#   'Seizures',
#   'Dizziness',
#   'Leg pain',
#   'Problems with movement'],
#  ['Headache', 'Leg pain', 'Fatigue'],
#  ['Skin rash', 'Itching of skin', 'Abnormal appearing skin'],
#  ['Pelvic pain', 'Sharp abdominal pain'],
#  ['Problems with movement'],
#  ['Drug abuse', 'Abusing alcohol', 'Depressive or psychotic symptoms'],
#  ['Skin rash'],
#  ['Diarrhea', 'Skin rash', 'Irritable infant'],
#  ['Depressive or psychotic symptoms', 'Hostile behavior'],
#  [],
#  [],
#  ['Hand or finger weakness'],
#  ['Weakness', 'Abnormal appearing skin'],
#  ['Abnormal appearing skin',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Skin moles'],
#  ['Sharp abdominal pain', 'Knee lump or mass', 'Pain in eye', 'Fatigue'],
#  ['Neck swelling',
#   'Skin swelling',
#   'Groin mass',
#   'Skin rash',
#   'Loss of sensation',
#   'Arm swelling',
#   'Headache'],
#  ['Pain or soreness of breast', 'Bleeding or discharge from nipple'],
#  ['Excessive appetite',
#   'Difficulty in swallowing',
#   'Frequent urination',
#   'Dizziness'],
#  ['Skin rash', 'Itching of skin'],
#  [],
#  ['Depressive or psychotic symptoms',
#   'Depression',
#   'Paresthesia',
#   'Lip swelling'],
#  ['Shoulder pain'],
#  ['Vulvar sore', 'Joint stiffness or tightness', 'Itchy eyelid'],
#  ['Low back pain', 'Leg pain', 'Neck pain', 'Shoulder pain', 'Ache all over'],
#  ['Skin rash', 'Itching of skin', 'Ache all over', 'Skin lesion'],
#  ['Shoulder stiffness or tightness', 'Ache all over'],
#  ['Lacrimation', 'Eyelid lesion or rash', 'Swollen eye', 'Itchiness of eye'],
#  ['Pain in eye', 'Eye redness', 'Swollen eye', 'Painful sinuses'],
#  ['Symptoms of the kidneys', 'Weakness', 'Abnormal appearing skin'],
#  ['Vaginal discharge',
#   'Sharp abdominal pain',
#   'Painful urination',
#   'Vaginal itching',
#   'Lower abdominal pain'],
#  ['Fatigue',
#   'Anxiety and nervousness',
#   'Symptoms of the kidneys',
#   'Feeling hot and cold'],
#  ['Skin rash',
#   'Abnormal appearing skin',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Cough'],
#  ['Depression', 'Depressive or psychotic symptoms', 'Decreased appetite'],
#  [],
#  ['Loss of sensation',
#   'Hand or finger pain',
#   'Weakness',
#   'Problems with movement',
#   'Facial pain'],
#  ['Eye redness'],
#  ['Shortness of breath', 'Hand or finger swelling'],
#  ['Vaginal bleeding after menopause'],
#  ['Back pain'],
#  ['Depression'],
#  ['Ache all over', 'Neck pain', 'Muscle pain', 'Leg pain'],
#  ['Skin rash', 'Dizziness'],
#  ['Wrist pain', 'Hand or finger pain'],
#  ['Back pain'],
#  ['Itchiness of eye', 'Pain in eye', 'Nasal congestion'],
#  ['Leg pain', 'Wrist lump or mass'],
#  ['Abnormal appearing skin', 'Skin rash'],
#  ['Sharp abdominal pain'],
#  ['Foot or toe pain'],
#  ['Leg pain', 'Neck pain', 'Shoulder pain', 'Arm pain'],
#  [],
#  ['Fatigue'],
#  ['Sharp abdominal pain', 'Pain in eye', 'Fatigue'],
#  ['Skin lesion', 'Irregular appearing scalp', 'Skin swelling'],
#  [],
#  ['Itching of skin', 'Acne or pimples'],
#  ['Skin moles'],
#  ['Acne or pimples', 'Frequent urination', 'Ankle pain'],
#  ['Loss of sensation'],
#  ['Pain in eye',
#   'Swollen eye',
#   'Diminished vision',
#   'Foreign body sensation in eye',
#   'Itchiness of eye'],
#  [],
#  ['Shortness of breath', 'Peripheral edema'],
#  ['Wrist pain', 'Shoulder pain'],
#  ['Nausea', 'Sharp abdominal pain'],
#  ['Hip pain',
#   'Problems with movement',
#   'Delusions or hallucinations',
#   'Focal weakness'],
#  ['Loss of sensation',
#   'Foot or toe pain',
#   'Paresthesia',
#   'Arm pain',
#   'Hand or finger pain'],
#  ['Diminished vision',
#   'Symptoms of eye',
#   'Foreign body sensation in eye',
#   'White discharge from eye'],
#  ['Pelvic pain', 'Heavy menstrual flow', 'Burning abdominal pain'],
#  ['Anxiety and nervousness', 'Depression', 'Irregular heartbeat'],
#  ['Skin rash', 'Itching of skin', 'Swollen eye'],
#  ['Painful urination', 'Blood in urine'],
#  ['Sharp chest pain', 'Groin pain', 'Vaginal pain', 'Neck cramps or spasms'],
#  [],
#  ['Diminished vision', 'Pain in eye'],
#  ['Pain in eye', 'Eye redness', 'Swollen eye', 'Lacrimation'],
#  ['Loss of sensation'],
#  ['Pain in eye'],
#  ['Skin lesion', 'Allergic reaction'],
#  ['Shoulder pain', 'Ache all over'],
#  ['Skin rash', 'Itching of skin', 'Abnormal appearing skin', 'Cough'],
#  ['Nausea', 'Sharp chest pain', 'Vaginal pain'],
#  ['Loss of sensation', 'Fever', 'Hand or finger pain'],
#  ['Loss of sensation', 'Paresthesia', 'Hand or finger weakness'],
#  ['Anxiety and nervousness', 'Low self-esteem'],
#  ['Impotence', 'Pain in testicles'],
#  [],
#  ['Headache'],
#  ['Lacrimation', 'Abnormal movement of eyelid', 'Eyelid lesion or rash'],
#  ['Side pain', 'Dizziness', 'Leg pain'],
#  ['Wrist pain', 'Wrist swelling', 'Arm pain', 'Peripheral edema'],
#  ['Itchiness of eye'],
#  ['Mass on eyelid', 'Pain in eye'],
#  ['Skin rash', 'Skin dryness, peeling, scaliness, or roughness'],
#  ['Skin rash', 'Skin lesion', 'Itching of skin', 'Abnormal appearing skin'],
#  ['Shoulder pain', 'Shoulder stiffness or tightness', 'Neck pain', 'Arm pain'],
#  [],
#  ['Back pain', 'Leg pain', 'Headache', 'Sharp abdominal pain'],
#  ['Penile discharge', 'Vaginal discharge', 'Vaginal itching', 'Paresthesia'],
#  ['Shortness of breath', 'Dizziness', 'Retention of urine'],
#  ['Diarrhea', 'Fever', 'Nasal congestion'],
#  ['Itching of skin'],
#  ['Skin swelling', 'Groin mass', 'Skin rash', 'Arm swelling', 'Headache'],
#  ['Infertility'],
#  ['Loss of sex drive'],
#  ['Disturbance of memory',
#   'Depressive or psychotic symptoms',
#   'Paresthesia',
#   'Lip swelling',
#   'Itchy eyelid',
#   'Elbow weakness'],
#  ['Skin rash', 'Fever', 'Mouth ulcer', 'Skin pain'],
#  ['Mass on eyelid',
#   'Skin growth',
#   'Eyelid lesion or rash',
#   'Diminished vision'],
#  ['Nausea', 'Sharp chest pain', 'Vaginal pain'],
#  ['Sore throat', 'Ankle pain', 'Knee lump or mass'],
#  ['Sore throat', 'Fever', 'Ankle pain', 'Wrist pain', 'Facial pain'],
#  ['Skin rash', 'Itching of skin', 'Allergic reaction'],
#  ['Problems with movement',
#   'Difficulty in swallowing',
#   'Hand or finger weakness'],
#  ['Abnormal appearing skin', 'Ankle pain'],
#  ['Eye redness', 'Symptoms of eye', 'Swollen eye'],
#  [],
#  ['Impotence', 'Frequent urination', 'Involuntary urination'],
#  ['Headache', 'Diminished vision', 'Nausea'],
#  ['Dizziness', 'Vomiting'],
#  [],
#  ['Problems with movement'],
#  ['Shoulder cramps or spasms',
#   'Facial pain',
#   'Ankle pain',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Lump or mass of breast'],
#  [],
#  ['Ankle pain', 'Knee lump or mass'],
#  ['Depressive or psychotic symptoms'],
#  ['Depression', 'Weight gain'],
#  ['Lacrimation',
#   'Pain in eye',
#   'Abnormal movement of eyelid',
#   'Eyelid lesion or rash',
#   'Foreign body sensation in eye',
#   'Swollen eye',
#   'Itchiness of eye'],
#  ['Skin rash',
#   'Skin lesion',
#   'Itching of skin',
#   'Abnormal appearing skin',
#   'Ankle pain'],
#  [],
#  ['Ache all over'],
#  ['Neck pain', 'Headache', 'Knee pain', 'Hip pain'],
#  ['Shortness of breath',
#   'Anxiety and nervousness',
#   'Congestion in chest',
#   'Weakness'],
#  [],
#  [],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Facial pain',
#   'Ankle pain',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Drug abuse', 'Sharp chest pain'],
#  [],
#  ['Depression', 'Low self-esteem', 'Excessive anger'],
#  ['Knee lump or mass'],
#  ['Diminished vision', 'Pain in eye', 'Eye redness'],
#  ['Knee pain'],
#  ['Headache', 'Nausea', 'Dizziness'],
#  [],
#  ['Acne or pimples'],
#  [],
#  ['Hip pain', 'Ache all over', 'Difficulty speaking'],
#  ['Sharp abdominal pain',
#   'Vaginal pain',
#   'Frequent urination',
#   'Lower abdominal pain'],
#  ['Skin rash', 'Itching of skin', 'Nausea', 'Throat swelling'],
#  [],
#  ['Vaginal bleeding after menopause'],
#  ['Sharp abdominal pain', 'Facial pain', 'Fatigue'],
#  ['Cough', 'Frequent urination', 'Dizziness'],
#  ['Weight gain', 'Pain or soreness of breast', 'Fluid retention'],
#  ['Ankle stiffness or tightness'],
#  ['Anxiety and nervousness', 'Abnormal involuntary movements'],
#  ['Diminished vision', 'Spots or clouds in vision'],
#  ['Drug abuse', 'Depressive or psychotic symptoms', 'Excessive anger'],
#  ['Nausea', 'Dizziness', 'Diarrhea', 'Frontal headache', 'Fainting'],
#  ['Skin rash', 'Allergic reaction', 'Dizziness', 'Lip swelling', 'Headache'],
#  ['Sharp chest pain', 'Dizziness', 'Chest tightness'],
#  ['Weakness', 'Back pain', 'Leg cramps or spasms'],
#  ['Vomiting', 'Nausea', 'Sharp abdominal pain', 'Sharp chest pain'],
#  ['Back pain', 'Headache', 'Hip pain', 'Fatigue'],
#  ['Wrist pain'],
#  ['Abnormal involuntary movements', 'Difficulty in swallowing'],
#  ['Eye redness', 'Swollen eye'],
#  ['Diminished vision'],
#  ['Sharp abdominal pain', 'Heavy menstrual flow', 'Burning abdominal pain'],
#  ['Wrist pain', 'Arm pain', 'Hand or finger swelling'],
#  ['Drug abuse'],
#  ['Retention of urine', 'Side pain', 'Symptoms of bladder'],
#  ['Nausea'],
#  ['Abusing alcohol',
#   'Depressive or psychotic symptoms',
#   'Vomiting',
#   'Sharp chest pain',
#   'Fainting',
#   'Delusions or hallucinations'],
#  [],
#  ['Sharp abdominal pain', 'Lower abdominal pain'],
#  ['Diminished hearing', 'Ear pain', 'Ringing in ear', 'Dizziness'],
#  ['Vomiting', 'Nausea'],
#  ['Pain during pregnancy', 'Excessive anger', 'Joint stiffness or tightness'],
#  ['Mass on eyelid',
#   'Skin growth',
#   'Eyelid lesion or rash',
#   'Pain in eye',
#   'Symptoms of eye',
#   'Diminished vision'],
#  ['Anxiety and nervousness', 'Sharp chest pain'],
#  [],
#  ['Hip pain', 'Side pain', 'Problems with movement', 'Knee pain'],
#  ['Pain in eye',
#   'Eye redness',
#   'Swollen eye',
#   'Itchiness of eye',
#   'Mass on eyelid',
#   'Paresthesia'],
#  ['Cough', 'Hemoptysis'],
#  ['Vomiting', 'Nausea', 'Sharp abdominal pain', 'Diarrhea'],
#  ['Low back pain'],
#  ['Seizures', 'Disturbance of memory', 'Problems with movement'],
#  ['Pelvic pain', 'Cramps and spasms'],
#  ['Loss of sensation',
#   'Hand or finger pain',
#   'Paresthesia',
#   'Arm pain',
#   'Neck pain',
#   'Elbow pain'],
#  ['Skin lesion'],
#  ['Back pain', 'Low back pain', 'Neck pain'],
#  [],
#  ['Acne or pimples', 'Skin rash', 'Abnormal appearing skin'],
#  ['Skin rash', 'Itching of skin', 'Cough'],
#  ['Skin rash', 'Itching of skin', 'Abnormal appearing skin'],
#  ['Spots or clouds in vision', 'Lacrimation'],
#  [],
#  ['Back pain', 'Leg pain'],
#  ['Cough', 'Skin lesion'],
#  ['Impotence'],
#  ['Back pain', 'Paresthesia'],
#  ['Dizziness'],
#  ['Side pain', 'Leg pain'],
#  [],
#  [],
#  ['Peripheral edema', 'Fluid retention', 'Difficulty breathing', 'Cough'],
#  [],
#  ['Disturbance of memory',
#   'Depressive or psychotic symptoms',
#   'Paresthesia',
#   'Lip swelling',
#   'Excessive growth'],
#  ['Depressive or psychotic symptoms', 'Weight gain'],
#  ['Disturbance of memory'],
#  ['Joint pain', 'Feeling ill', 'Ache all over', 'Arm pain'],
#  ['Rib pain', 'Shortness of breath'],
#  ['Hip pain', 'Back pain', 'Leg pain'],
#  ['Cough', 'Nasal congestion', 'Irritable infant'],
#  ['Rib pain', 'Sharp chest pain', 'Side pain'],
#  ['Skin rash', 'Peripheral edema', 'Vomiting'],
#  ['Acne or pimples'],
#  [],
#  ['Abusing alcohol',
#   'Depressive or psychotic symptoms',
#   'Delusions or hallucinations'],
#  ['Foot or toe pain', 'Hand or finger pain'],
#  ['Weight gain'],
#  ['Wrist pain',
#   'Hand or finger pain',
#   'Arm pain',
#   'Abnormal involuntary movements'],
#  ['Intermenstrual bleeding'],
#  ['Depression',
#   'Depressive or psychotic symptoms',
#   'Excessive anger',
#   'Low self-esteem'],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Facial pain',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Shoulder pain', 'Ache all over', 'Arm pain', 'Muscle pain'],
#  ['Foot or toe pain'],
#  ['Back pain', 'Low back pain', 'Ache all over'],
#  ['Diarrhea', 'Cough', 'Skin swelling'],
#  ['Dizziness', 'Foot or toe swelling'],
#  ['Headache',
#   'Focal weakness',
#   'Loss of sensation',
#   'Nausea',
#   'Problems with movement',
#   'Dizziness'],
#  ['Loss of sensation', 'Fever', 'Ache all over'],
#  ['Neck pain', 'Abnormal involuntary movements', 'Problems with movement'],
#  ['Depression',
#   'Sharp abdominal pain',
#   'Sharp chest pain',
#   'Abnormal involuntary movements'],
#  ['Loss of sensation',
#   'Hand or finger pain',
#   'Arm pain',
#   'Neck pain',
#   'Elbow pain'],
#  [],
#  ['Pain in eye',
#   'Eye redness',
#   'Diminished vision',
#   'Itchiness of eye',
#   'Skin growth',
#   'Foreign body sensation in eye'],
#  ['Skin rash', 'Skin dryness, peeling, scaliness, or roughness', 'Warts'],
#  ['Diminished vision'],
#  ['Skin lesion', 'Apnea'],
#  ['Neck pain', 'Vomiting'],
#  ['Headache', 'Problems with movement', 'Insomnia'],
#  ['Skin rash'],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Ankle pain',
#   'Wrist pain',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Depressive or psychotic symptoms', 'Depression'],
#  ['Pain in eye',
#   'Abnormal movement of eyelid',
#   'Eye redness',
#   'Spots or clouds in vision',
#   'Foreign body sensation in eye',
#   'Swollen eye'],
#  ['Impotence'],
#  [],
#  ['Blindness'],
#  ['Back pain', 'Low back pain', 'Leg pain', 'Neck pain', 'Side pain'],
#  ['Drug abuse',
#   'Depressive or psychotic symptoms',
#   'Depression',
#   'Sharp chest pain'],
#  ['Knee pain', 'Leg pain', 'Hand or finger lump or mass', 'Wrist swelling'],
#  ['Excessive appetite', 'Cough'],
#  ['Pelvic pain'],
#  ['Weakness',
#   'Problems with movement',
#   'Back pain',
#   'Difficulty in swallowing',
#   'Fatigue'],
#  ['Disturbance of memory'],
#  ['Back pain', 'Hip pain'],
#  ['Depression'],
#  [],
#  ['Pain or soreness of breast'],
#  ['Skin rash'],
#  ['Pain in eye', 'Eye redness', 'Swollen eye', 'Painful sinuses'],
#  ['Shoulder cramps or spasms',
#   'Facial pain',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Excessive urination at night'],
#  ['Ache all over', 'Leg pain', 'Headache', 'Arm pain', 'Fatigue'],
#  ['Pain in testicles', 'Side pain', 'Blood in urine'],
#  ['Skin moles',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Skin growth'],
#  ['Cramps and spasms', 'Restlessness'],
#  ['Abnormal involuntary movements', 'Dizziness', 'Loss of sensation'],
#  [],
#  ['Pain in eye', 'Diminished vision', 'Skin lesion'],
#  ['Hand or finger pain', 'Shoulder pain', 'Wrist swelling'],
#  ['Skin rash', 'Itching of skin', 'Swelling of scrotum'],
#  ['Anxiety and nervousness', 'Depression', 'Headache'],
#  ['Lump or mass of breast'],
#  ['Shortness of breath', 'Anxiety and nervousness'],
#  ['Sore throat', 'Fever', 'Knee lump or mass'],
#  ['Pain in eye', 'Eyelid lesion or rash'],
#  ['Symptoms of eye', 'Skin growth'],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Facial pain',
#   'Ankle pain',
#   'Wrist pain',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Shoulder pain'],
#  ['Lump or mass of breast', 'Bleeding or discharge from nipple'],
#  ['Headache', 'Sleepiness'],
#  [],
#  ['Shortness of breath', 'Headache', 'Abnormal appearing skin'],
#  ['Anxiety and nervousness',
#   'Depressive or psychotic symptoms',
#   'Decreased appetite',
#   'Abusing alcohol'],
#  ['Depressive or psychotic symptoms',
#   'Anxiety and nervousness',
#   'Hostile behavior'],
#  ['Skin rash', 'Itching of skin', 'Swollen eye'],
#  [],
#  ['Vaginal bleeding after menopause',
#   'Intermenstrual bleeding',
#   'Unpredictable menstruation',
#   'Mass on vulva'],
#  ['Pain in eye'],
#  ['Seizures',
#   'Depression',
#   'Anxiety and nervousness',
#   'Abnormal involuntary movements',
#   'Fainting'],
#  ['Low back pain', 'Leg pain'],
#  ['Depression', 'Excessive appetite'],
#  ['Diminished vision', 'Spots or clouds in vision', 'Eye burns or stings'],
#  ['Itching of skin'],
#  ['Abnormal appearing skin', 'Cough', 'Irregular appearing scalp'],
#  ['Pain in testicles', 'Lower abdominal pain', 'Blood in urine'],
#  ['Back pain', 'Low back pain', 'Leg pain', 'Ache all over', 'Paresthesia'],
#  ['Pelvic pain'],
#  ['Sharp abdominal pain',
#   'Painful menstruation',
#   'Heavy menstrual flow',
#   'Infertility',
#   'Intermenstrual bleeding'],
#  ['Eye redness',
#   'Swollen eye',
#   'Diminished vision',
#   'Lacrimation',
#   'Itchiness of eye'],
#  ['Loss of sensation'],
#  ['Loss of sensation', 'Arm pain', 'Low back pain'],
#  ['Diminished vision', 'Spots or clouds in vision'],
#  ['Knee pain', 'Leg pain', 'Problems with movement'],
#  ['Intermenstrual bleeding', 'Infrequent menstruation'],
#  [],
#  ['Skin growth',
#   'Eyelid lesion or rash',
#   'Diminished vision',
#   'Abnormal movement of eyelid'],
#  ['Symptoms of eye'],
#  ['Cough'],
#  ['Muscle pain', 'Leg pain', 'Low back pain'],
#  ['Disturbance of memory', 'Depressive or psychotic symptoms', 'Lip swelling'],
#  ['Depression',
#   'Anxiety and nervousness',
#   'Decreased appetite',
#   'Abusing alcohol',
#   'Excessive anger'],
#  ['Skin rash'],
#  ['Penile discharge',
#   'Vaginal discharge',
#   'Paresthesia',
#   'Itching of skin',
#   'Spotting or bleeding during pregnancy'],
#  ['Seizures', 'Allergic reaction', 'Weakness'],
#  ['Headache', 'Dizziness'],
#  ['Leg pain'],
#  ['Knee swelling'],
#  ['Itchiness of eye'],
#  ['Acne or pimples', 'Irregular appearing scalp'],
#  [],
#  ['Loss of sensation',
#   'Leg pain',
#   'Paresthesia',
#   'Hand or finger pain',
#   'Problems with movement'],
#  [],
#  ['Abusing alcohol',
#   'Depressive or psychotic symptoms',
#   'Depression',
#   'Sharp chest pain'],
#  ['Mass on eyelid', 'Diminished vision'],
#  ['Headache'],
#  ['Skin lesion'],
#  ['Ache all over', 'Arm pain', 'Ankle stiffness or tightness'],
#  ['Back pain', 'Leg pain', 'Arm pain'],
#  ['Foot or toe pain'],
#  ['Sharp chest pain', 'Depressive or psychotic symptoms', 'Fatigue'],
#  ['Depression', 'Anxiety and nervousness'],
#  ['Eye redness'],
#  ['Shortness of breath',
#   'Fatigue',
#   'Congestion in chest',
#   'Fever',
#   'Weakness'],
#  ['Foot or toe swelling'],
#  ['Sharp chest pain', 'Groin pain', 'Vaginal pain', 'Excessive growth'],
#  ['Vaginal bleeding after menopause'],
#  ['Abnormal appearing skin', 'Symptoms of the face'],
#  ['Painful urination', 'Blood in urine', 'Sharp abdominal pain'],
#  ['Shoulder pain', 'Ache all over', 'Stiffness all over'],
#  ['Depressive or psychotic symptoms'],
#  ['Cough'],
#  [],
#  ['Sweating'],
#  [],
#  ['Depressive or psychotic symptoms', 'Sharp chest pain'],
#  ['Neck pain', 'Leg pain', 'Headache', 'Fatigue'],
#  ['Difficulty speaking',
#   'Problems with movement',
#   'Hand or finger weakness',
#   'Leg cramps or spasms'],
#  ['Abnormal involuntary movements'],
#  [],
#  ['Painful urination', 'Suprapubic pain'],
#  [],
#  ['Peripheral edema',
#   'Sharp abdominal pain',
#   'Fluid retention',
#   'Nausea',
#   'Difficulty breathing'],
#  ['Depressive or psychotic symptoms'],
#  [],
#  ['Back pain', 'Neck pain', 'Shoulder pain'],
#  ['Anxiety and nervousness'],
#  ['Arm pain'],
#  [],
#  ['Wrist lump or mass', 'Hand or finger lump or mass'],
#  [],
#  ['Abnormal involuntary movements', 'Seizures', 'Disturbance of memory'],
#  ['Pain in eye',
#   'Facial pain',
#   'Ankle pain',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Low self-esteem'],
#  ['Low back pain', 'Leg pain'],
#  [],
#  [],
#  [],
#  ['Peripheral edema'],
#  ['Skin rash', 'Itching of skin', 'Fluid retention', 'Allergic reaction'],
#  ['Depressive or psychotic symptoms'],
#  ['Headache', 'Nausea', 'Vomiting', 'Fainting'],
#  ['Knee pain',
#   'Leg pain',
#   'Wrist pain',
#   'Wrist lump or mass',
#   'Hand or finger pain',
#   'Knee lump or mass'],
#  ['Depression', 'Low self-esteem', 'Excessive anger'],
#  ['Spots or clouds in vision', 'Symptoms of eye'],
#  ['Vaginal bleeding after menopause'],
#  ['Skin rash', 'Fever'],
#  ['Lacrimation', 'Pain in eye', 'Symptoms of eye', 'Swollen eye'],
#  ['Sharp abdominal pain', 'Lower abdominal pain'],
#  ['Diminished vision', 'Pain in eye'],
#  ['Sharp abdominal pain',
#   'Vaginal pain',
#   'Itching of skin',
#   'Frequent urination'],
#  ['Pain in eye'],
#  ['Itching of skin', 'Skin dryness, peeling, scaliness, or roughness'],
#  [],
#  ['Loss of sensation', 'Leg pain'],
#  ['Eyelid lesion or rash',
#   'Pain in eye',
#   'Symptoms of eye',
#   'Diminished vision'],
#  ['Symptoms of prostate', 'Excessive urination at night'],
#  ['Vaginal discharge',
#   'Sharp abdominal pain',
#   'Itching of skin',
#   'Penis pain'],
#  ['Heavy menstrual flow', 'Vaginal discharge'],
#  [],
#  ['Diminished hearing', 'Ear pain'],
#  ['Sore throat', 'Fever', 'Ankle pain', 'Pain or soreness of breast'],
#  ['Dizziness', 'Nausea', 'Peripheral edema'],
#  ['Headache', 'Fears and phobias'],
#  [],
#  ['Skin rash', 'Itching of skin'],
#  ['Acne or pimples', 'Skin dryness, peeling, scaliness, or roughness'],
#  ['Too little hair'],
#  [],
#  ['Sharp chest pain',
#   'Depressive or psychotic symptoms',
#   'Abnormal involuntary movements'],
#  ['Loss of sensation',
#   'Hand or finger pain',
#   'Wrist pain',
#   'Arm pain',
#   'Hand or finger stiffness or tightness'],
#  ['Anxiety and nervousness', 'Insomnia'],
#  ['Lacrimation',
#   'Pain in eye',
#   'Abnormal movement of eyelid',
#   'Foreign body sensation in eye'],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Facial pain',
#   'Ankle pain',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Diminished vision', 'Spots or clouds in vision', 'Symptoms of eye'],
#  ['Diminished vision'],
#  ['Rib pain', 'Sharp chest pain'],
#  [],
#  ['Lump or mass of breast', 'Bleeding or discharge from nipple'],
#  ['Depression', 'Dizziness'],
#  ['Disturbance of memory',
#   'Depressive or psychotic symptoms',
#   'Hostile behavior'],
#  ['Sore throat', 'Ankle pain', 'Wrist pain'],
#  ['Wrist pain', 'Pain or soreness of breast', 'Knee lump or mass'],
#  ['Penis redness'],
#  ['Weight gain'],
#  ['Shoulder cramps or spasms',
#   'Facial pain',
#   'Pain during pregnancy',
#   'Excessive urination at night'],
#  ['Neck swelling',
#   'Skin swelling',
#   'Loss of sensation',
#   'Arm swelling',
#   'Skin lesion',
#   'Swollen eye',
#   'Arm lump or mass'],
#  ['Ankle stiffness or tightness'],
#  ['Side pain', 'Leg pain'],
#  ['Vaginal bleeding after menopause', 'Heavy menstrual flow'],
#  ['Depression',
#   'Anxiety and nervousness',
#   'Depressive or psychotic symptoms',
#   'Abusing alcohol',
#   'Insomnia'],
#  [],
#  ['Rib pain', 'Ache all over', 'Arm pain'],
#  ['Eye redness',
#   'Swollen eye',
#   'Itchiness of eye',
#   'Paresthesia',
#   'Lacrimation'],
#  ['Palpitations'],
#  ['Seizures', 'Problems with movement'],
#  [],
#  ['Weakness',
#   'Vomiting',
#   'Sharp abdominal pain',
#   'Sharp chest pain',
#   'Blood in urine'],
#  [],
#  [],
#  ['Swollen eye'],
#  ['Low back pain', 'Hip pain', 'Arm pain'],
#  ['Abnormal appearing skin',
#   'Skin rash',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Skin growth',
#   'Symptoms of the face'],
#  ['Foot or toe pain', 'Loss of sensation', 'Poor circulation'],
#  [],
#  ['Headache', 'Nausea', 'Vomiting', 'Depressive or psychotic symptoms'],
#  ['Acne or pimples'],
#  ['Skin lesion'],
#  ['Wrist pain', 'Fatigue'],
#  ['Wrist pain'],
#  [],
#  [],
#  ['Peripheral edema'],
#  ['Difficulty in swallowing'],
#  ['Cough'],
#  ['Eye redness',
#   'Pain in eye',
#   'Lacrimation',
#   'Swollen eye',
#   'Symptoms of eye'],
#  ['Disturbance of memory',
#   'Depressive or psychotic symptoms',
#   'Paresthesia',
#   'Lip swelling'],
#  ['Hand or finger pain', 'Paresthesia'],
#  ['Lump or mass of breast', 'Pain or soreness of breast'],
#  ['Back pain', 'Elbow pain', 'Lower body pain'],
#  ['Pain in eye', 'Facial pain', 'Knee lump or mass', 'Fatigue'],
#  ['Facial pain', 'Joint stiffness or tightness'],
#  ['Plugged feeling in ear'],
#  ['Sharp chest pain', 'Fainting'],
#  ['Impotence', 'Retention of urine'],
#  ['Abnormal involuntary movements'],
#  ['Pain in testicles', 'Groin pain', 'Lower abdominal pain'],
#  ['Eye redness',
#   'Itchiness of eye',
#   'Lacrimation',
#   'Nasal congestion',
#   'Diminished vision',
#   'Cough'],
#  ['Vaginal bleeding after menopause'],
#  ['Weakness', 'Problems with movement', 'Leg pain'],
#  ['Difficulty speaking', 'Abnormal involuntary movements'],
#  ['Ankle pain', 'Pain during pregnancy', 'Pain or soreness of breast'],
#  ['Weakness', 'Nausea'],
#  ['Excessive appetite'],
#  ['Penile discharge', 'Sharp abdominal pain', 'Problems with movement'],
#  ['Painful urination',
#   'Suprapubic pain',
#   'Frequent urination',
#   'Retention of urine',
#   'Lower abdominal pain'],
#  ['Back pain', 'Knee pain', 'Rib pain'],
#  ['Arm pain', 'Headache'],
#  ['Headache', 'Nausea', 'Vomiting'],
#  ['Shoulder cramps or spasms',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Joint stiffness or tightness'],
#  ['Skin rash', 'Skin lesion', 'Swollen eye', 'Skin moles'],
#  ['Sharp abdominal pain', 'Wrist pain', 'Joint stiffness or tightness'],
#  ['Hip pain', 'Leg pain'],
#  ['Diminished vision', 'Pain in eye', 'Eye redness', 'Bleeding from eye'],
#  ['Leg weakness', 'Difficulty speaking', 'Leg pain'],
#  ['Vaginal bleeding after menopause', 'Unpredictable menstruation'],
#  ['Itchiness of eye', 'Pain in eye', 'Lacrimation', 'Nasal congestion'],
#  ['Pain in eye', 'Abnormal movement of eyelid', 'White discharge from eye'],
#  ['Pain in eye', 'Eye redness'],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Excessive anger',
#   'Excessive urination at night'],
#  [],
#  ['Wrist pain'],
#  [],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Ankle pain',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Fatigue'],
#  ['Pain in eye',
#   'Facial pain',
#   'Ankle pain',
#   'Wrist pain',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Excessive urination at night'],
#  ['Lump or mass of breast'],
#  ['Skin growth', 'Pain in eye'],
#  ['Cough'],
#  ['Shortness of breath'],
#  ['Penis pain'],
#  ['Seizures',
#   'Dizziness',
#   'Disturbance of memory',
#   'Paresthesia',
#   'Joint pain'],
#  ['Shortness of breath', 'Fatigue', 'Fever', 'Abnormal appearing skin'],
#  ['Sore throat',
#   'Fever',
#   'Shoulder cramps or spasms',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Pain or soreness of breast'],
#  ['Wrist pain',
#   'Hand or finger pain',
#   'Hand or finger swelling',
#   'Peripheral edema',
#   'Lower body pain'],
#  ['Nausea', 'Sharp chest pain', 'Groin pain'],
#  ['Knee pain', 'Knee lump or mass', 'Knee swelling'],
#  ['Skin rash',
#   'Fever',
#   'Coryza',
#   'Skin lesion',
#   'Vomiting',
#   'Mouth ulcer',
#   'Pain in eye'],
#  ['Skin rash', 'Irregular appearing scalp'],
#  [],
#  ['Knee pain'],
#  ['Fatigue', 'Feeling ill', 'Difficulty in swallowing'],
#  ['Abnormal appearing skin', 'Skin moles'],
#  ['Retention of urine'],
#  ['Difficulty in swallowing'],
#  ['Pain in eye'],
#  ['Excessive anger', 'Fatigue'],
#  ['Headache'],
#  ['Diminished vision', 'Eye redness', 'Eye burns or stings'],
#  ['Pain in eye',
#   'Eye redness',
#   'Swollen eye',
#   'Lacrimation',
#   'Itchiness of eye'],
#  ['Pain in eye', 'Eye redness', 'Swollen eye', 'Skin lesion'],
#  ['Shortness of breath',
#   'Anxiety and nervousness',
#   'Congestion in chest',
#   'Weakness'],
#  ['Headache', 'Diminished vision', 'Vomiting', 'Difficulty speaking'],
#  ['Skin rash', 'Vomiting', 'Mouth ulcer', 'Difficulty in swallowing'],
#  ['Acne or pimples'],
#  ['Lacrimation',
#   'Pain in eye',
#   'Abnormal movement of eyelid',
#   'Symptoms of eye',
#   'Eye redness',
#   'Diminished vision'],
#  ['Headache'],
#  ['Mass on eyelid', 'Pain in eye', 'Swollen eye'],
#  ['Sharp chest pain', 'Insomnia', 'Burning abdominal pain'],
#  ['Anxiety and nervousness', 'Depression', 'Palpitations'],
#  ['Back pain', 'Loss of sensation'],
#  ['Frequent urination',
#   'Sharp abdominal pain',
#   'Retention of urine',
#   'Symptoms of bladder'],
#  ['Abusing alcohol', 'Depression', 'Delusions or hallucinations'],
#  ['Focal weakness', 'Diminished vision', 'Vomiting'],
#  [],
#  ['Eye redness'],
#  ['Shortness of breath',
#   'Sharp abdominal pain',
#   'Difficulty breathing',
#   'Vomiting',
#   'Hand or finger swelling'],
#  [],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Facial pain',
#   'Ankle pain',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Fatigue'],
#  ['Abnormal involuntary movements', 'Seizures', 'Arm stiffness or tightness'],
#  ['Vaginal bleeding after menopause'],
#  ['Leg pain', 'Knee stiffness or tightness'],
#  ['Nausea',
#   'Weakness',
#   'Diarrhea',
#   'Depressive or psychotic symptoms',
#   'Polyuria',
#   'Frequent urination'],
#  [],
#  ['Pain in testicles', 'Swelling of scrotum', 'Sharp abdominal pain'],
#  ['Lacrimation',
#   'Pain in eye',
#   'Abnormal movement of eyelid',
#   'Eye redness',
#   'Eyelid lesion or rash'],
#  ['Foot or toe pain', 'Foot or toe swelling', 'Wrist pain'],
#  ['Skin on leg or foot looks infected'],
#  ['Neck pain', 'Difficulty speaking', 'Problems with movement'],
#  ['Leg weakness', 'Leg pain', 'Dizziness'],
#  ['Anxiety and nervousness',
#   'Sharp chest pain',
#   'Depressive or psychotic symptoms',
#   'Dizziness',
#   'Shortness of breath',
#   'Fatigue'],
#  ['Wrist pain',
#   'Hand or finger pain',
#   'Shoulder pain',
#   'Arm pain',
#   'Hand or finger swelling'],
#  [],
#  ['Skin growth',
#   'Eyelid lesion or rash',
#   'Pain in eye',
#   'Diminished vision',
#   'Itchiness of eye'],
#  ['Skin rash', 'Swelling of scrotum', 'Skin lesion'],
#  ['Plugged feeling in ear', 'Difficulty speaking'],
#  ['Nausea'],
#  ['Fever', 'Itching of skin', 'Coryza', 'Skin lesion', 'Mouth ulcer'],
#  ['Dizziness', 'Leg pain'],
#  [],
#  ['Loss of sensation', 'Wrist pain', 'Paresthesia'],
#  ['Itching of skin'],
#  ['Abusing alcohol', 'Depressive or psychotic symptoms', 'Sharp chest pain'],
#  ['Skin rash', 'Swollen eye', 'Skin swelling'],
#  ['Skin rash', 'Mouth ulcer', 'Pain in eye', 'Difficulty in swallowing'],
#  ['Infertility'],
#  ['Sore throat', 'Fever', 'Ankle pain', 'Knee lump or mass'],
#  ['Shoulder cramps or spasms',
#   'Facial pain',
#   'Ankle pain',
#   'Excessive anger',
#   'Excessive urination at night'],
#  ['Disturbance of memory',
#   'Depressive or psychotic symptoms',
#   'Depression',
#   'Loss of sensation',
#   'Elbow cramps or spasms'],
#  ['Itching of skin', 'Swelling of scrotum', 'Skin lesion', 'Vomiting'],
#  ['Depression'],
#  ['Skin growth'],
#  ['Itchiness of eye'],
#  ['Nausea', 'Difficulty breathing', 'Weakness', 'Hand or finger swelling'],
#  ['Lacrimation',
#   'Symptoms of eye',
#   'Spots or clouds in vision',
#   'Swollen eye',
#   'Itchiness of eye'],
#  [],
#  ['Headache'],
#  ['Neck pain', 'Leg pain', 'Low back pain', 'Hip pain', 'Fatigue'],
#  ['Skin rash',
#   'Abnormal appearing skin',
#   'Acne or pimples',
#   'Dry or flaky scalp',
#   'Frequent urination',
#   'Skin on leg or foot looks infected'],
#  ['Skin dryness, peeling, scaliness, or roughness'],
#  ['Excessive appetite'],
#  [],
#  ['Sharp abdominal pain', 'Ankle pain', 'Knee lump or mass'],
#  [],
#  ['Skin swelling', 'Skin rash', 'Skin lesion', 'Headache', 'Arm lump or mass'],
#  ['Problems with movement', 'Headache'],
#  ['Headache', 'Seizures', 'Leg pain', 'Disturbance of memory', 'Insomnia'],
#  ['Skin rash', 'Swelling of scrotum'],
#  ['Ear pain', 'Fluid in ear'],
#  ['Skin rash', 'Fever', 'Problems during pregnancy'],
#  ['Fever', 'Abnormal appearing skin'],
#  ['Vomiting'],
#  ['Pain in testicles',
#   'Swelling of scrotum',
#   'Sharp abdominal pain',
#   'Retention of urine'],
#  ['Abnormal involuntary movements'],
#  ['Depression', 'Paresthesia'],
#  ['Back pain', 'Hip pain'],
#  ['Back pain', 'Leg pain'],
#  ['Headache'],
#  [],
#  ['Back pain', 'Leg pain'],
#  ['Drug abuse'],
#  ['Excessive appetite', 'Dizziness'],
#  ['Sharp chest pain', 'Dizziness', 'Shortness of breath'],
#  ['Skin rash', 'Vomiting'],
#  ['Congestion in chest', 'Weakness'],
#  ['Abusing alcohol'],
#  ['Loss of sensation',
#   'Seizures',
#   'Dizziness',
#   'Leg pain',
#   'Fatigue',
#   'Insomnia'],
#  [],
#  ['Ankle swelling'],
#  ['Dizziness', 'Disturbance of memory'],
#  ['Painful urination',
#   'Suprapubic pain',
#   'Blood in urine',
#   'Lower abdominal pain'],
#  ['Eye redness',
#   'Itchiness of eye',
#   'Pain in eye',
#   'Nasal congestion',
#   'Allergic reaction',
#   'Cough'],
#  ['Vomiting', 'Nausea', 'Weakness', 'Fluid retention'],
#  ['Pain in eye',
#   'Eye redness',
#   'Foreign body sensation in eye',
#   'Itchiness of eye',
#   'Eyelid lesion or rash'],
#  ['Foot or toe pain', 'Problems with movement'],
#  ['Acne or pimples', 'Irregular appearing scalp'],
#  ['Sharp abdominal pain', 'Knee lump or mass'],
#  ['Dizziness', 'Peripheral edema', 'Lip swelling', 'Headache', 'Vomiting'],
#  ['Loss of sex drive'],
#  ['Skin rash',
#   'Skin lesion',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Abnormal appearing skin',
#   'Acne or pimples',
#   'Ankle pain'],
#  ['Skin rash',
#   'Skin moles',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Acne or pimples'],
#  ['Anxiety and nervousness',
#   'Congestion in chest',
#   'Abnormal appearing skin',
#   'Nailbiting'],
#  ['Knee pain'],
#  ['Involuntary urination', 'Eye strain'],
#  ['Back pain', 'Diminished hearing'],
#  ['Sharp abdominal pain', 'Wrist pain', 'Knee lump or mass'],
#  ['Fluid retention', 'Nausea', 'Cough'],
#  ['Diminished vision'],
#  ['Headache', 'Depression', 'Shortness of breath', 'Burning abdominal pain'],
#  ['Acne or pimples', 'Warts'],
#  ['Weight gain', 'Skin lesion'],
#  ['Eye redness', 'Symptoms of eye', 'Eyelid swelling'],
#  ['Depressive or psychotic symptoms',
#   'Depression',
#   'Loss of sensation',
#   'Paresthesia',
#   'Itchy eyelid'],
#  ['Skin rash', 'Peripheral edema', 'Shortness of breath', 'Throat swelling'],
#  ['Diarrhea'],
#  ['Abnormal appearing skin',
#   'Skin lesion',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Irregular appearing scalp',
#   'Skin irritation'],
#  [],
#  ['Wrist pain',
#   'Hand or finger pain',
#   'Hand or finger swelling',
#   'Wrist stiffness or tightness'],
#  ['Weight gain'],
#  ['Shoulder pain', 'Neck pain'],
#  [],
#  ['Abusing alcohol',
#   'Vomiting',
#   'Depression',
#   'Anxiety and nervousness',
#   'Nausea',
#   'Abnormal involuntary movements'],
#  ['Anxiety and nervousness', 'Sharp chest pain', 'Palpitations'],
#  [],
#  [],
#  ['Skin lesion', 'Irregular appearing scalp'],
#  [],
#  ['Skin rash',
#   'Skin lesion',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Abnormal appearing skin',
#   'Back pain',
#   'Skin on leg or foot looks infected'],
#  ['Fatigue'],
#  ['Depression', 'Depressive or psychotic symptoms'],
#  ['Joint stiffness or tightness', 'Fatigue'],
#  ['Skin swelling'],
#  ['Headache', 'Loss of sensation', 'Paresthesia'],
#  ['Skin swelling',
#   'Groin mass',
#   'Skin rash',
#   'Skin lesion',
#   'Headache',
#   'Swollen eye',
#   'Arm lump or mass'],
#  ['Vaginal itching'],
#  [],
#  [],
#  [],
#  [],
#  ['Skin lesion',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Itching of skin',
#   'Dry or flaky scalp'],
#  [],
#  ['Low back pain', 'Joint pain'],
#  ['Depressive or psychotic symptoms', 'Sharp chest pain'],
#  ['Mass on eyelid', 'Skin growth'],
#  ['Skin rash',
#   'Allergic reaction',
#   'Peripheral edema',
#   'Abnormal appearing skin',
#   'Lip swelling',
#   'Fluid retention'],
#  ['Abnormal appearing skin',
#   'Skin lesion',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Skin growth',
#   'Skin swelling'],
#  ['Pain in testicles', 'Swelling of scrotum', 'Side pain'],
#  ['Shoulder pain', 'Neck pain'],
#  ['Weakness', 'Abnormal involuntary movements', 'Leg pain', 'Muscle weakness'],
#  ['Knee pain'],
#  ['Bleeding or discharge from nipple'],
#  [],
#  ['Lower abdominal pain'],
#  ['Sore throat'],
#  ['Anxiety and nervousness', 'Abnormal involuntary movements'],
#  ['Skin rash', 'Abnormal appearing skin', 'Lip swelling'],
#  ['Headache',
#   'Neck pain',
#   'Disturbance of memory',
#   'Nausea',
#   'Back pain',
#   'Facial pain'],
#  ['Shortness of breath', 'Fluid retention', 'Difficulty breathing'],
#  ['Sharp abdominal pain', 'Painful menstruation'],
#  ['Back pain', 'Leg pain'],
#  [],
#  ['Skin rash', 'Abnormal appearing skin', 'Acne or pimples'],
#  ['Loss of sensation', 'Foot or toe pain', 'Back pain'],
#  [],
#  ['Involuntary urination', 'Knee lump or mass'],
#  ['Skin rash',
#   'Dizziness',
#   'Peripheral edema',
#   'Lip swelling',
#   'Headache',
#   'Vomiting',
#   'Throat swelling'],
#  ['Allergic reaction',
#   'Dizziness',
#   'Lip swelling',
#   'Nausea',
#   'Shortness of breath'],
#  ['Abnormal involuntary movements'],
#  ['Diminished vision',
#   'Pain in eye',
#   'Symptoms of eye',
#   'Foreign body sensation in eye'],
#  ['Back pain', 'Neck pain', 'Leg pain', 'Low back pain'],
#  ['Pain in eye'],
#  ['Sharp abdominal pain'],
#  ['Weakness'],
#  ['Back pain', 'Muscle pain', 'Leg pain', 'Sharp chest pain'],
#  ['Lacrimation'],
#  [],
#  ['Difficulty speaking', 'Problems with movement'],
#  ['Headache', 'Focal weakness', 'Muscle stiffness or tightness', 'Arm pain'],
#  ['Symptoms of eye',
#   'Eye redness',
#   'Spots or clouds in vision',
#   'Eyelid lesion or rash'],
#  ['Sharp chest pain', 'Insomnia', 'Dizziness'],
#  ['Anxiety and nervousness'],
#  ['Skin rash'],
#  ['Pulling at ears'],
#  ['Abusing alcohol'],
#  ['Leg weakness', 'Leg pain', 'Loss of sensation', 'Difficulty speaking'],
#  ['Nausea', 'Diarrhea', 'Depressive or psychotic symptoms', 'Fainting'],
#  [],
#  ['Diminished vision'],
#  ['Impotence'],
#  ['Pain in testicles', 'Sharp abdominal pain', 'Painful urination'],
#  ['Vaginal itching'],
#  ['Diarrhea', 'Itching of skin', 'Skin irritation'],
#  ['Itching of skin'],
#  ['Skin rash', 'Dizziness', 'Vomiting'],
#  ['Hip pain', 'Problems with movement'],
#  ['Headache', 'Neck pain', 'Focal weakness', 'Diminished vision', 'Dizziness'],
#  [],
#  ['Diminished vision', 'Eye redness', 'Blindness'],
#  ['Shoulder pain'],
#  ['Shoulder pain'],
#  ['Shortness of breath', 'Nausea', 'Hand or finger swelling'],
#  ['Knee lump or mass', 'Fatigue'],
#  ['Itchiness of eye', 'Lacrimation'],
#  ['Sharp chest pain', 'Hip pain'],
#  ['Foot or toe pain'],
#  [],
#  ['Skin lesion'],
#  [],
#  ['Skin rash'],
#  ['Foot or toe pain', 'Paresthesia', 'Lymphedema'],
#  ['Diminished vision', 'Pain in eye'],
#  ['Abnormal appearing skin', 'Skin lesion', 'Skin rash'],
#  ['Back pain',
#   'Ache all over',
#   'Arm pain',
#   'Low back pain',
#   'Neck pain',
#   'Abnormal involuntary movements'],
#  ['Weakness',
#   'Leg weakness',
#   'Abnormal involuntary movements',
#   'Back pain',
#   'Difficulty in swallowing',
#   'Leg pain',
#   'Muscle weakness'],
#  ['Lacrimation',
#   'Abnormal movement of eyelid',
#   'Symptoms of eye',
#   'Eye redness',
#   'Swollen eye',
#   'White discharge from eye',
#   'Itchiness of eye'],
#  ['Headache'],
#  ['Rib pain', 'Back pain', 'Ache all over', 'Shortness of breath'],
#  ['Disturbance of memory', 'Depression'],
#  ['Seizures', 'Depression', 'Cough', 'Focal weakness'],
#  ['Weakness', 'Sore throat', 'Fainting'],
#  ['Pain in eye', 'Eye redness', 'Swollen eye'],
#  [],
#  ['Leg pain', 'Foot or toe pain', 'Back pain'],
#  ['Pain in eye', 'Eye redness', 'Swollen eye'],
#  ['Low back pain', 'Hip pain', 'Paresthesia'],
#  [],
#  ['Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass'],
#  ['Headache', 'Dizziness'],
#  ['Neck pain', 'Muscle pain', 'Shoulder pain', 'Sharp chest pain', 'Hip pain'],
#  ['Feeling ill'],
#  ['Pelvic pain', 'Sharp abdominal pain', 'Infertility', 'Chills'],
#  [],
#  ['Skin rash', 'Itching of skin', 'Coryza', 'Fluid retention'],
#  ['Pain in eye',
#   'Symptoms of eye',
#   'Foreign body sensation in eye',
#   'Swollen eye',
#   'Itchiness of eye'],
#  ['Neck pain',
#   'Vomiting',
#   'Difficulty speaking',
#   'Loss of sensation',
#   'Dizziness'],
#  ['Abnormal involuntary movements',
#   'Disturbance of memory',
#   'Arm stiffness or tightness'],
#  ['Skin dryness, peeling, scaliness, or roughness'],
#  [],
#  ['Back pain', 'Low back pain', 'Lower body pain', 'Rib pain'],
#  ['Itching of skin',
#   'Abnormal appearing skin',
#   'Skin lesion',
#   'Skin swelling',
#   'Acne or pimples'],
#  ['Sharp abdominal pain', 'Painful urination', 'Vaginal pain'],
#  ['Loss of sensation', 'Wrist pain'],
#  ['Leg pain', 'Joint pain'],
#  ['Unpredictable menstruation'],
#  ['Mass on eyelid',
#   'Pain in eye',
#   'Swollen eye',
#   'Eye redness',
#   'Eyelid swelling',
#   'Skin growth',
#   'Foreign body sensation in eye'],
#  ['Ache all over'],
#  ['Skin rash',
#   'Itching of skin',
#   'Skin dryness, peeling, scaliness, or roughness'],
#  ['Nausea',
#   'Symptoms of the kidneys',
#   'Peripheral edema',
#   'Retention of urine'],
#  ['Knee pain'],
#  [],
#  [],
#  ['Itching of skin',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Skin lesion'],
#  ['Fatigue', 'Anxiety and nervousness', 'Abnormal appearing skin'],
#  ['Nausea', 'Dizziness', 'Vomiting'],
#  ['Hot flashes'],
#  ['Skin swelling',
#   'Skin rash',
#   'Loss of sensation',
#   'Skin lesion',
#   'Fever',
#   'Swollen eye'],
#  [],
#  [],
#  ['Fatigue', 'Eye strain'],
#  ['Paresthesia', 'Lip swelling'],
#  ['Skin rash'],
#  ['Neck pain', 'Loss of sensation', 'Nausea'],
#  ['Wrist pain',
#   'Joint stiffness or tightness',
#   'Knee lump or mass',
#   'Fatigue'],
#  ['Disturbance of memory',
#   'Depressive or psychotic symptoms',
#   'Depression',
#   'Elbow cramps or spasms'],
#  ['Eye redness', 'Itchiness of eye', 'Pain in eye'],
#  ['Frequent menstruation'],
#  ['Depressive or psychotic symptoms'],
#  ['Back pain', 'Sharp abdominal pain', 'Knee pain'],
#  ['Lacrimation'],
#  ['Sharp abdominal pain', 'Burning abdominal pain', 'Intermenstrual bleeding'],
#  ['Hand or finger pain', 'Paresthesia', 'Neck pain'],
#  ['Pain in eye',
#   'Shoulder cramps or spasms',
#   'Ankle pain',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  [],
#  ['Nausea'],
#  ['Abnormal involuntary movements',
#   'Anxiety and nervousness',
#   'Nausea',
#   'Problems with movement'],
#  ['Disturbance of memory'],
#  ['Loss of sensation'],
#  ['Lump or mass of breast'],
#  ['Back pain', 'Leg pain'],
#  ['Pain in eye',
#   'Eyelid lesion or rash',
#   'Diminished vision',
#   'Itchiness of eye',
#   'Foreign body sensation in eye'],
#  ['Anxiety and nervousness', 'Excessive anger', 'Temper problems'],
#  ['Suprapubic pain', 'Frequent urination', 'Sharp abdominal pain'],
#  ['Pain in testicles', 'Groin pain'],
#  ['Dizziness', 'Neck pain', 'Vomiting'],
#  ['Pain in eye', 'Eye redness'],
#  ['Loss of sensation', 'Paresthesia'],
#  ['Skin rash'],
#  ['Diminished vision'],
#  ['Anxiety and nervousness', 'Depression'],
#  ['Retention of urine'],
#  [],
#  ['Symptoms of eye'],
#  ['Headache',
#   'Dizziness',
#   'Depressive or psychotic symptoms',
#   'Sleepiness',
#   'Frontal headache',
#   'Fainting'],
#  ['Cough', 'Nasal congestion'],
#  ['Disturbance of memory'],
#  ['Pain in testicles',
#   'Swelling of scrotum',
#   'Groin pain',
#   'Sharp abdominal pain',
#   'Side pain'],
#  ['Skin growth',
#   'Diminished vision',
#   'Wrinkles on skin',
#   'Abnormal movement of eyelid',
#   'Skin rash'],
#  ['Back pain',
#   'Leg pain',
#   'Neck pain',
#   'Hip pain',
#   'Ache all over',
#   'Paresthesia',
#   'Joint pain'],
#  ['Joint pain',
#   'Skin rash',
#   'Foot or toe pain',
#   'Fever',
#   'Arm pain',
#   'Headache',
#   'Difficulty in swallowing'],
#  ['Shortness of breath', 'Symptoms of the kidneys', 'Peripheral edema'],
#  ['Vaginal bleeding after menopause'],
#  ['Pelvic pain', 'Elbow cramps or spasms'],
#  ['Loss of sensation',
#   'Fever',
#   'Ache all over',
#   'Paresthesia',
#   'Hand or finger pain'],
#  ['Pain in eye',
#   'Wrist pain',
#   'Pain during pregnancy',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Fatigue'],
#  ['Loss of sensation', 'Hand or finger pain', 'Hand or finger weakness'],
#  ['Depressive or psychotic symptoms', 'Anxiety and nervousness'],
#  ['Skin lesion',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Skin moles'],
#  ['Diminished vision',
#   'Pain in eye',
#   'Eye redness',
#   'Foreign body sensation in eye'],
#  ['Back pain'],
#  ['Difficulty breathing'],
#  ['Groin pain'],
#  ['Diminished vision', 'Itchiness of eye', 'Bleeding from eye'],
#  ['Abnormal involuntary movements'],
#  ['Skin rash', 'Itching of skin', 'Peripheral edema', 'Itchiness of eye'],
#  [],
#  ['Headache'],
#  ['Skin rash', 'Itching of skin', 'Pain in testicles'],
#  ['Skin rash', 'Fever', 'Itching of skin'],
#  ['Nasal congestion', 'Skin rash'],
#  ['Intermenstrual bleeding', 'Vaginal itching', 'Cramps and spasms'],
#  ['Dizziness', 'Leg pain', 'Emotional symptoms'],
#  ['Weakness', 'Sharp chest pain'],
#  ['Impotence'],
#  ['Difficulty in swallowing'],
#  ['Weight gain', 'Allergic reaction', 'Apnea'],
#  ['Diminished hearing', 'Plugged feeling in ear', 'Dizziness'],
#  ['Skin growth'],
#  ['Pelvic pain'],
#  ['Abnormal appearing skin',
#   'Skin rash',
#   'Skin dryness, peeling, scaliness, or roughness',
#   'Irregular appearing scalp',
#   'Skin swelling'],
#  ['Painful menstruation', 'Hot flashes'],
#  ['Shortness of breath',
#   'Peripheral edema',
#   'Fluid retention',
#   'Leg swelling',
#   'Difficulty breathing'],
#  ['Symptoms of eye', 'Swollen eye'],
#  [],
#  ['Vaginal discharge',
#   'Paresthesia',
#   'Spotting or bleeding during pregnancy',
#   'Cramps and spasms'],
#  [],
#  ['Leg pain'],
#  ['Wrist pain', 'Arm pain'],
#  ['Leg pain',
#   'Loss of sensation',
#   'Fever',
#   'Ache all over',
#   'Dizziness',
#   'Paresthesia',
#   'Weakness'],
#  ['Vomiting', 'Weakness', 'Diarrhea'],
#  [],
#  ['Skin rash', 'Fever', 'Pain in eye'],
#  ['Vaginal bleeding after menopause', 'Pelvic pain'],
#  ['Loss of sensation', 'Hand or finger pain', 'Paresthesia'],
#  ['Ringing in ear'],
#  ['Irregular appearing scalp'],
#  ['Abnormal appearing skin', 'Frequent urination'],
#  ['Leg cramps or spasms'],
#  [],
#  [],
#  ['Skin rash',
#   'Abnormal appearing skin',
#   'Skin dryness, peeling, scaliness, or roughness'],
#  ['Low back pain', 'Knee pain', 'Ache all over', 'Stiffness all over'],
#  [],
#  ['Abnormal involuntary movements'],
#  ['Shortness of breath',
#   'Peripheral edema',
#   'Sharp abdominal pain',
#   'Nausea',
#   'Cough',
#   'Sharp chest pain'],
#  ['Pain in eye',
#   'Ankle pain',
#   'Excessive anger',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Fatigue',
#   'Excessive urination at night'],
#  ['Skin lesion'],
#  ['Depressive or psychotic symptoms', 'Side pain'],
#  ['Foot or toe pain', 'Arm pain'],
#  ['Shoulder pain', 'Neck pain'],
#  ['Headache', 'Neck pain'],
#  ['Ear pain', 'Plugged feeling in ear', 'Ringing in ear'],
#  ['Foot or toe pain', 'Knee pain'],
#  ['Blood in urine'],
#  ['Skin rash', 'Allergic reaction'],
#  ['Skin rash', 'Cough'],
#  ['Abnormal involuntary movements', 'Loss of sensation'],
#  [],
#  ['Drug abuse'],
#  ['Depressive or psychotic symptoms'],
#  ['Wrist pain', 'Hand or finger swelling'],
#  ['Neck pain', 'Vomiting'],
#  ['Symptoms of eye', 'Eye redness', 'Itchiness of eye'],
#  [],
#  ['Pain in eye', 'Spots or clouds in vision'],
#  [],
#  ['Pain or soreness of breast', 'Warts'],
#  ['Itchiness of eye',
#   'Pain in eye',
#   'Nasal congestion',
#   'Swollen eye',
#   'Allergic reaction'],
#  ['Skin on leg or foot looks infected'],
#  ['Sore throat',
#   'Fever',
#   'Wrist pain',
#   'Joint stiffness or tightness',
#   'Facial pain'],
#  ['Involuntary urination', 'Shoulder swelling'],
#  [],
#  ['Pain in eye',
#   'Facial pain',
#   'Pain during pregnancy',
#   'Joint stiffness or tightness',
#   'Pain or soreness of breast',
#   'Knee lump or mass',
#   'Excessive urination at night'],
#  ['Knee pain'],
#  ['Depressive or psychotic symptoms', 'Leg pain', 'Feeling hot and cold'],
#  [],
#  ['Pain in testicles'],
#  ['Foot or toe pain',
#   'Low back pain',
#   'Neck pain',
#   'Abnormal involuntary movements',
#   'Problems with movement'],
#  [],
#  ['Absence of menstruation'],
#  ['Anxiety and nervousness', 'Depressive or psychotic symptoms'],
#  ['Shortness of breath',
#   'Peripheral edema',
#   'Difficulty breathing',
#   'Vomiting'],
#  ['Seizures', 'Allergic reaction', 'Fainting'],
#  ['Vaginal bleeding after menopause', 'Heavy menstrual flow'],
#  ['Abnormal appearing skin', 'Irregular appearing scalp', 'Lack of growth'],
#  ['Low self-esteem', 'Excessive anger'],
#  [],
#  ['Impotence'],
#  ['Sore throat', 'Excessive anger'],
#  ['Back pain', 'Leg pain', 'Knee pain', 'Elbow pain'],
#  ['Depression'],
#  ['Mass on eyelid', 'Symptoms of eye', 'Itchiness of eye'],
#  ['Acne or pimples'],
#  [],
#  [],
#  ['Infertility'],
#  ['Seizures',
#   'Allergic reaction',
#   'Weakness',
#   'Abnormal involuntary movements',
#   'Fatigue',
#   'Focal weakness'],
#  [],
#  ['Problems with movement'],
#  ['Rib pain', 'Side pain', 'Ache all over'],
#  ['Back pain'],
#  [],
#  [],
#  [],
#  ['Involuntary urination', 'Itchy eyelid'],
#  ['Shoulder stiffness or tightness', 'Neck pain', 'Elbow pain'],
#  ['Skin lesion', 'Acne or pimples', 'Foot or toe lump or mass'],
#  ...]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_dummy, Y_train_tranform)
# Out:
# RandomForestClassifier(random_state=42)

# %%
X_test = [list(item['goal']['explicit_inform_slots'].keys())[0] for item in test_data]
Y_test = [list((item['goal']['implicit_inform_slots'].keys())) for item in test_data]

X_test_expanded = []
Y_test_expanded = []

for x, ys in zip(X_test, Y_test):
    for y in ys:
        X_test_expanded.append(x)
        Y_test_expanded.append(y)


X_test_dummy = X_train = pd.get_dummies(X_test_expanded)
X_test_dummy = X_test_dummy.reindex(columns=X_train_dummy.columns, fill_value=0)
Y_test_transform = mlb.fit_transform(Y_test_expanded)

# %%
predictions = model.predict(X_test_dummy)

# %%
from sklearn.metrics import accuracy_score, hamming_loss, precision_score, recall_score, f1_score

# 성능 평가: 여러 성능 지표를 사용해 모델 평가
precision = precision_score(Y_test_transform, predictions, average='samples')
recall = recall_score(Y_test_transform, predictions, average='samples')
f1 = f1_score(Y_test_transform, predictions, average='samples')
hammingloss = hamming_loss(Y_test_transform, predictions)

print(f"Precision: {precision}\nRecall: {recall}\nF1 Score: {f1}\nHamming Loss: {hammingloss}")
# Out:
# Precision: 0.734631414253236
# Recall: 0.5549288258960391
# F1 Score: 0.6176208238193042
# Hamming Loss: 0.13449758609591245

# %%
new_input = pd.DataFrame({'explicit_inform_slots': ['Spots or clouds in vision']})
new_input
X_test = pd.get_dummies(new_input)

X_test = X_test.reindex(columns=X_train.columns, fill_value=False)
X_test['Spots or clouds in vision'] = True
probabilities = model.predict_proba(X_test)

# 각 레이블에 대한 "있음" 확률을 모으기 위한 배열 초기화
positive_probabilities = []

# 각 레이블에 대한 "있음" 확률을 추출
for prob in probabilities:
    positive_probabilities.append(prob[0][1])  # 레이블이 "있음"일 확률

# "있음" 확률이 높은 상위 5개 인덱스 찾기
top_indices = np.argsort(positive_probabilities)[-5:][::-1]

print(top_indices)
# 상위 5개 인덱스에 해당하는 암묵적 증상 이름 조회
top_symptoms = [X_train.columns[i] for i in top_indices]

print("상위 5개 암묵적 증상:", top_symptoms)

print("상위 5개 암묵적 증상:", top_symptoms)
# Out:
# [28  0 37 32 38]
# 상위 5개 암묵적 증상: ['Blindness', 'Abnormal appearing skin', 'Cough', 'Burning abdominal pain', 'Cramps and spasms']
# 상위 5개 암묵적 증상: ['Blindness', 'Abnormal appearing skin', 'Cough', 'Burning abdominal pain', 'Cramps and spasms']

# %%
symptom_relations = {}

for _, row in train_df.iterrows():
    explicit_symptoms = row['goal']['explicit_inform_slots'].keys()
    implicit_symptoms = row['goal']['implicit_inform_slots'].keys()

    for e_symptom in explicit_symptoms:
        if e_symptom not in symptom_relations:
            symptom_relations[e_symptom] = {}
        for i_symptom in implicit_symptoms:
            if i_symptom in symptom_relations[e_symptom]:
                symptom_relations[e_symptom][i_symptom] += 1
            else:
                symptom_relations[e_symptom][i_symptom] = 1


for e_symptom, i_symptoms in symptom_relations.items():
    sorted_i_symptoms = sorted(i_symptoms.items(), key=lambda x: x[1], reverse=True)
    total_occurrences = sum(i_symptoms.values())
    if(e_symptom == ''Cat
    print(f"\n명시적 증상: {e_symptom}, 총 발생 횟수: {total_occurrences}")
    for i_symptom, count in sorted_i_symptoms:
        ratio = count / total_occurrences
        print(f"  암묵적 증상: {i_symptom}, 발생 횟수: {count}, 비율: {ratio:.2f}")
# Out:
# 명시적 증상: Spots or clouds in vision, 총 발생 횟수: 315
#   암묵적 증상: Diminished vision, 발생 횟수: 90, 비율: 0.29
#   암묵적 증상: Pain in eye, 발생 횟수: 52, 비율: 0.17
#   암묵적 증상: Symptoms of eye, 발생 횟수: 38, 비율: 0.12
#   암묵적 증상: Eye redness, 발생 횟수: 23, 비율: 0.07
#   암묵적 증상: Itchiness of eye, 발생 횟수: 21, 비율: 0.07
#   암묵적 증상: Lacrimation, 발생 횟수: 19, 비율: 0.06
#   암묵적 증상: Foreign body sensation in eye, 발생 횟수: 15, 비율: 0.05
#   암묵적 증상: Abnormal movement of eyelid, 발생 횟수: 12, 비율: 0.04
#   암묵적 증상: Blindness, 발생 횟수: 10, 비율: 0.03
#   암묵적 증상: Eye burns or stings, 발생 횟수: 7, 비율: 0.02
#   암묵적 증상: Swollen eye, 발생 횟수: 6, 비율: 0.02
#   암묵적 증상: Eyelid lesion or rash, 발생 횟수: 5, 비율: 0.02
#   암묵적 증상: White discharge from eye, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Bleeding from eye, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Mass on eyelid, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Feeling ill, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Decreased appetite, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Intermenstrual bleeding, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Eye deviation, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Double vision, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Cough, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Shoulder pain, 총 발생 횟수: 522
#   암묵적 증상: Neck pain, 발생 횟수: 48, 비율: 0.09
#   암묵적 증상: Ache all over, 발생 횟수: 44, 비율: 0.08
#   암묵적 증상: Shoulder stiffness or tightness, 발생 횟수: 42, 비율: 0.08
#   암묵적 증상: Back pain, 발생 횟수: 40, 비율: 0.08
#   암묵적 증상: Arm pain, 발생 횟수: 33, 비율: 0.06
#   암묵적 증상: Wrist pain, 발생 횟수: 30, 비율: 0.06
#   암묵적 증상: Hand or finger pain, 발생 횟수: 28, 비율: 0.05
#   암묵적 증상: Low back pain, 발생 횟수: 24, 비율: 0.05
#   암묵적 증상: Leg pain, 발생 횟수: 22, 비율: 0.04
#   암묵적 증상: Rib pain, 발생 횟수: 18, 비율: 0.03
#   암묵적 증상: Sharp chest pain, 발생 횟수: 15, 비율: 0.03
#   암묵적 증상: Wrist swelling, 발생 횟수: 14, 비율: 0.03
#   암묵적 증상: Decreased heart rate, 발생 횟수: 14, 비율: 0.03
#   암묵적 증상: Muscle pain, 발생 횟수: 13, 비율: 0.02
#   암묵적 증상: Weight gain, 발생 횟수: 13, 비율: 0.02
#   암묵적 증상: Hip pain, 발생 횟수: 10, 비율: 0.02
#   암묵적 증상: Headache, 발생 횟수: 10, 비율: 0.02
#   암묵적 증상: Elbow pain, 발생 횟수: 10, 비율: 0.02
#   암묵적 증상: Ankle stiffness or tightness, 발생 횟수: 8, 비율: 0.02
#   암묵적 증상: Peripheral edema, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Side pain, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Stiffness all over, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Lower body pain, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Wrist stiffness or tightness, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Shoulder swelling, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Hand or finger swelling, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Skin on arm or hand looks infected, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Loss of sensation, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Hurts to breath, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Shortness of breath, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Fatigue, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Paresthesia, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Elbow weakness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Emotional symptoms, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Knee pain, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Bones are painful, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Low back weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Muscle swelling, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Back mass or lump, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Itching of scrotum, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Foreign body sensation in eye, 총 발생 횟수: 267
#   암묵적 증상: Diminished vision, 발생 횟수: 56, 비율: 0.21
#   암묵적 증상: Pain in eye, 발생 횟수: 43, 비율: 0.16
#   암묵적 증상: Eye redness, 발생 횟수: 35, 비율: 0.13
#   암묵적 증상: Symptoms of eye, 발생 횟수: 25, 비율: 0.09
#   암묵적 증상: Lacrimation, 발생 횟수: 17, 비율: 0.06
#   암묵적 증상: Itchiness of eye, 발생 횟수: 17, 비율: 0.06
#   암묵적 증상: Abnormal movement of eyelid, 발생 횟수: 14, 비율: 0.05
#   암묵적 증상: Spots or clouds in vision, 발생 횟수: 14, 비율: 0.05
#   암묵적 증상: Swollen eye, 발생 횟수: 9, 비율: 0.03
#   암묵적 증상: Mass on eyelid, 발생 횟수: 8, 비율: 0.03
#   암묵적 증상: Eyelid lesion or rash, 발생 횟수: 7, 비율: 0.03
#   암묵적 증상: White discharge from eye, 발생 횟수: 5, 비율: 0.02
#   암묵적 증상: Blindness, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Double vision, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Eyelid swelling, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Eye deviation, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Eye burns or stings, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Skin growth, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Elbow pain, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Low back pain, 총 발생 횟수: 617
#   암묵적 증상: Back pain, 발생 횟수: 147, 비율: 0.24
#   암묵적 증상: Leg pain, 발생 횟수: 71, 비율: 0.12
#   암묵적 증상: Neck pain, 발생 횟수: 67, 비율: 0.11
#   암묵적 증상: Hip pain, 발생 횟수: 55, 비율: 0.09
#   암묵적 증상: Ache all over, 발생 횟수: 50, 비율: 0.08
#   암묵적 증상: Knee pain, 발생 횟수: 28, 비율: 0.05
#   암묵적 증상: Loss of sensation, 발생 횟수: 27, 비율: 0.04
#   암묵적 증상: Arm pain, 발생 횟수: 24, 비율: 0.04
#   암묵적 증상: Shoulder pain, 발생 횟수: 22, 비율: 0.04
#   암묵적 증상: Headache, 발생 횟수: 21, 비율: 0.03
#   암묵적 증상: Lower body pain, 발생 횟수: 19, 비율: 0.03
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 18, 비율: 0.03
#   암묵적 증상: Paresthesia, 발생 횟수: 11, 비율: 0.02
#   암묵적 증상: Elbow pain, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Side pain, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Rib pain, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Muscle pain, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Sharp chest pain, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Problems with movement, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Foot or toe pain, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Fatigue, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Hand or finger pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Pelvic pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Leg weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Joint pain, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Groin pain, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Wrist pain, 총 발생 횟수: 1108
#   암묵적 증상: Hand or finger pain, 발생 횟수: 89, 비율: 0.08
#   암묵적 증상: Knee lump or mass, 발생 횟수: 72, 비율: 0.06
#   암묵적 증상: Excessive anger, 발생 횟수: 67, 비율: 0.06
#   암묵적 증상: Ankle pain, 발생 횟수: 66, 비율: 0.06
#   암묵적 증상: Pain or soreness of breast, 발생 횟수: 64, 비율: 0.06
#   암묵적 증상: Pain during pregnancy, 발생 횟수: 63, 비율: 0.06
#   암묵적 증상: Pain in eye, 발생 횟수: 57, 비율: 0.05
#   암묵적 증상: Facial pain, 발생 횟수: 56, 비율: 0.05
#   암묵적 증상: Joint stiffness or tightness, 발생 횟수: 56, 비율: 0.05
#   암묵적 증상: Excessive urination at night, 발생 횟수: 55, 비율: 0.05
#   암묵적 증상: Shoulder cramps or spasms, 발생 횟수: 54, 비율: 0.05
#   암묵적 증상: Fatigue, 발생 횟수: 54, 비율: 0.05
#   암묵적 증상: Loss of sensation, 발생 횟수: 31, 비율: 0.03
#   암묵적 증상: Arm pain, 발생 횟수: 29, 비율: 0.03
#   암묵적 증상: Knee pain, 발생 횟수: 26, 비율: 0.02
#   암묵적 증상: Foot or toe pain, 발생 횟수: 25, 비율: 0.02
#   암묵적 증상: Shoulder pain, 발생 횟수: 24, 비율: 0.02
#   암묵적 증상: Wrist swelling, 발생 횟수: 22, 비율: 0.02
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 21, 비율: 0.02
#   암묵적 증상: Sore throat, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Fever, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Hand or finger swelling, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Paresthesia, 발생 횟수: 18, 비율: 0.02
#   암묵적 증상: Leg pain, 발생 횟수: 16, 비율: 0.01
#   암묵적 증상: Leg swelling, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Peripheral edema, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Wrist lump or mass, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Neck pain, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Foot or toe swelling, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Hand or finger lump or mass, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Lower body pain, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Skin growth, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Elbow pain, 발생 횟수: 5, 비율: 0.00
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Wrist stiffness or tightness, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Hand or finger weakness, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Joint pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Knee swelling, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Hand or finger stiffness or tightness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Ankle swelling, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Skin rash, 총 발생 횟수: 1707
#   암묵적 증상: Itching of skin, 발생 횟수: 231, 비율: 0.14
#   암묵적 증상: Skin lesion, 발생 횟수: 173, 비율: 0.10
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 155, 비율: 0.09
#   암묵적 증상: Fever, 발생 횟수: 98, 비율: 0.06
#   암묵적 증상: Allergic reaction, 발생 횟수: 85, 비율: 0.05
#   암묵적 증상: Vomiting, 발생 횟수: 79, 비율: 0.05
#   암묵적 증상: Acne or pimples, 발생 횟수: 70, 비율: 0.04
#   암묵적 증상: Skin swelling, 발생 횟수: 69, 비율: 0.04
#   암묵적 증상: Skin dryness, peeling, scaliness, or roughness, 발생 횟수: 63, 비율: 0.04
#   암묵적 증상: Cough, 발생 횟수: 47, 비율: 0.03
#   암묵적 증상: Swelling of scrotum, 발생 횟수: 31, 비율: 0.02
#   암묵적 증상: Ache all over, 발생 횟수: 29, 비율: 0.02
#   암묵적 증상: Peripheral edema, 발생 횟수: 28, 비율: 0.02
#   암묵적 증상: Difficulty in swallowing, 발생 횟수: 25, 비율: 0.01
#   암묵적 증상: Skin moles, 발생 횟수: 24, 비율: 0.01
#   암묵적 증상: Irregular appearing scalp, 발생 횟수: 24, 비율: 0.01
#   암묵적 증상: Headache, 발생 횟수: 24, 비율: 0.01
#   암묵적 증상: Lip swelling, 발생 횟수: 23, 비율: 0.01
#   암묵적 증상: Swollen eye, 발생 횟수: 21, 비율: 0.01
#   암묵적 증상: Coryza, 발생 횟수: 20, 비율: 0.01
#   암묵적 증상: Mouth ulcer, 발생 횟수: 20, 비율: 0.01
#   암묵적 증상: Skin growth, 발생 횟수: 20, 비율: 0.01
#   암묵적 증상: Pain in eye, 발생 횟수: 15, 비율: 0.01
#   암묵적 증상: Dizziness, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Fluid retention, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Skin pain, 발생 횟수: 13, 비율: 0.01
#   암묵적 증상: Pain in testicles, 발생 횟수: 12, 비율: 0.01
#   암묵적 증상: Joint pain, 발생 횟수: 12, 비율: 0.01
#   암묵적 증상: Frequent urination, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Neck swelling, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Back pain, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Mass on eyelid, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Arm swelling, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Irritable infant, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Problems during pregnancy, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Shortness of breath, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Ankle pain, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Diarrhea, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Skin irritation, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Paresthesia, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Itchiness of eye, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Nausea, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Loss of sensation, 발생 횟수: 7, 비율: 0.00
#   암묵적 증상: Dry or flaky scalp, 발생 횟수: 7, 비율: 0.00
#   암묵적 증상: Lack of growth, 발생 횟수: 7, 비율: 0.00
#   암묵적 증상: Arm pain, 발생 횟수: 7, 비율: 0.00
#   암묵적 증상: Throat swelling, 발생 횟수: 6, 비율: 0.00
#   암묵적 증상: Arm lump or mass, 발생 횟수: 6, 비율: 0.00
#   암묵적 증상: Foot or toe lump or mass, 발생 횟수: 6, 비율: 0.00
#   암묵적 증상: Abnormal movement of eyelid, 발생 횟수: 6, 비율: 0.00
#   암묵적 증상: Skin on leg or foot looks infected, 발생 횟수: 6, 비율: 0.00
#   암묵적 증상: Eyelid lesion or rash, 발생 횟수: 6, 비율: 0.00
#   암묵적 증상: Diminished vision, 발생 횟수: 6, 비율: 0.00
#   암묵적 증상: Groin mass, 발생 횟수: 6, 비율: 0.00
#   암묵적 증상: Wrinkles on skin, 발생 횟수: 5, 비율: 0.00
#   암묵적 증상: Eye redness, 발생 횟수: 5, 비율: 0.00
#   암묵적 증상: Lymphedema, 발생 횟수: 5, 비율: 0.00
#   암묵적 증상: Symptoms of eye, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Diaper rash, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Elbow weakness, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Fatigue, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Nasal congestion, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Suprapubic pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Swollen tongue, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Itchy scalp, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Warts, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Cross-eyed, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Foot or toe pain, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Symptoms of the face, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Emotional symptoms, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Feeling ill, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Excessive growth, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Infant spitting up, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Bowlegged or knock-kneed, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Wrist weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Long menstrual periods, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Too little hair, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Diarrhea, 총 발생 횟수: 241
#   암묵적 증상: Nausea, 발생 횟수: 34, 비율: 0.14
#   암묵적 증상: Vomiting, 발생 횟수: 29, 비율: 0.12
#   암묵적 증상: Headache, 발생 횟수: 20, 비율: 0.08
#   암묵적 증상: Cough, 발생 횟수: 15, 비율: 0.06
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 15, 비율: 0.06
#   암묵적 증상: Dizziness, 발생 횟수: 12, 비율: 0.05
#   암묵적 증상: Nasal congestion, 발생 횟수: 11, 비율: 0.05
#   암묵적 증상: Fever, 발생 횟수: 11, 비율: 0.05
#   암묵적 증상: Weakness, 발생 횟수: 11, 비율: 0.05
#   암묵적 증상: Skin rash, 발생 횟수: 11, 비율: 0.05
#   암묵적 증상: Fainting, 발생 횟수: 9, 비율: 0.04
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 7, 비율: 0.03
#   암묵적 증상: Sharp chest pain, 발생 횟수: 7, 비율: 0.03
#   암묵적 증상: Sleepiness, 발생 횟수: 7, 비율: 0.03
#   암묵적 증상: Frontal headache, 발생 횟수: 7, 비율: 0.03
#   암묵적 증상: Irritable infant, 발생 횟수: 6, 비율: 0.02
#   암묵적 증상: Decreased appetite, 발생 횟수: 4, 비율: 0.02
#   암묵적 증상: Suprapubic pain, 발생 횟수: 4, 비율: 0.02
#   암묵적 증상: Skin swelling, 발생 횟수: 4, 비율: 0.02
#   암묵적 증상: Infant spitting up, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Itching of skin, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Pulling at ears, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Thirst, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Skin irritation, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Low back weakness, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Fluid retention, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Frequent urination, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Elbow cramps or spasms, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Facial pain, 총 발생 횟수: 844
#   암묵적 증상: Pain or soreness of breast, 발생 횟수: 72, 비율: 0.09
#   암묵적 증상: Fatigue, 발생 횟수: 71, 비율: 0.08
#   암묵적 증상: Ankle pain, 발생 횟수: 68, 비율: 0.08
#   암묵적 증상: Excessive anger, 발생 횟수: 66, 비율: 0.08
#   암묵적 증상: Wrist pain, 발생 횟수: 65, 비율: 0.08
#   암묵적 증상: Pain in eye, 발생 횟수: 65, 비율: 0.08
#   암묵적 증상: Joint stiffness or tightness, 발생 횟수: 63, 비율: 0.07
#   암묵적 증상: Knee lump or mass, 발생 횟수: 62, 비율: 0.07
#   암묵적 증상: Shoulder cramps or spasms, 발생 횟수: 61, 비율: 0.07
#   암묵적 증상: Pain during pregnancy, 발생 횟수: 61, 비율: 0.07
#   암묵적 증상: Excessive urination at night, 발생 횟수: 58, 비율: 0.07
#   암묵적 증상: Fever, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Headache, 발생 횟수: 14, 비율: 0.02
#   암묵적 증상: Dizziness, 발생 횟수: 14, 비율: 0.02
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 14, 비율: 0.02
#   암묵적 증상: Sore throat, 발생 횟수: 13, 비율: 0.02
#   암묵적 증상: Neck pain, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Leg weakness, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Leg pain, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Difficulty speaking, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Nausea, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Paresthesia, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Disturbance of memory, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Vomiting, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Loss of sensation, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Ache all over, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Hand or finger pain, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Weakness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Problems with movement, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Sleepiness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Rib pain, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Double vision, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Depression, 총 발생 횟수: 926
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 176, 비율: 0.19
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 130, 비율: 0.14
#   암묵적 증상: Disturbance of memory, 발생 횟수: 61, 비율: 0.07
#   암묵적 증상: Abusing alcohol, 발생 횟수: 42, 비율: 0.05
#   암묵적 증상: Excessive anger, 발생 횟수: 34, 비율: 0.04
#   암묵적 증상: Sharp chest pain, 발생 횟수: 32, 비율: 0.03
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 30, 비율: 0.03
#   암묵적 증상: Insomnia, 발생 횟수: 26, 비율: 0.03
#   암묵적 증상: Drug abuse, 발생 횟수: 25, 비율: 0.03
#   암묵적 증상: Paresthesia, 발생 횟수: 24, 비율: 0.03
#   암묵적 증상: Seizures, 발생 횟수: 22, 비율: 0.02
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 21, 비율: 0.02
#   암묵적 증상: Sore throat, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Hostile behavior, 발생 횟수: 18, 비율: 0.02
#   암묵적 증상: Allergic reaction, 발생 횟수: 17, 비율: 0.02
#   암묵적 증상: Lip swelling, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Weakness, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Headache, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Low self-esteem, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Shortness of breath, 발생 횟수: 15, 비율: 0.02
#   암묵적 증상: Fainting, 발생 횟수: 14, 비율: 0.02
#   암묵적 증상: Sweating, 발생 횟수: 13, 비율: 0.01
#   암묵적 증상: Fatigue, 발생 횟수: 13, 비율: 0.01
#   암묵적 증상: Loss of sensation, 발생 횟수: 12, 비율: 0.01
#   암묵적 증상: Focal weakness, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Vomiting, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Decreased appetite, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Dizziness, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Problems with movement, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Difficulty eating, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Temper problems, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Cough, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Fears and phobias, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Nausea, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Weight gain, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Palpitations, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Restlessness, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Excessive appetite, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Increased heart rate, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Chest tightness, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Burning abdominal pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Vomiting blood, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Acne or pimples, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Difficulty speaking, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Nightmares, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Excessive growth, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Wrist weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Low back weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Irregular appearing scalp, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Hysterical behavior, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Pain or soreness of breast, 총 발생 횟수: 789
#   암묵적 증상: Facial pain, 발생 횟수: 66, 비율: 0.08
#   암묵적 증상: Shoulder cramps or spasms, 발생 횟수: 64, 비율: 0.08
#   암묵적 증상: Pain during pregnancy, 발생 횟수: 64, 비율: 0.08
#   암묵적 증상: Pain in eye, 발생 횟수: 63, 비율: 0.08
#   암묵적 증상: Wrist pain, 발생 횟수: 62, 비율: 0.08
#   암묵적 증상: Fatigue, 발생 횟수: 61, 비율: 0.08
#   암묵적 증상: Ankle pain, 발생 횟수: 59, 비율: 0.07
#   암묵적 증상: Joint stiffness or tightness, 발생 횟수: 58, 비율: 0.07
#   암묵적 증상: Lump or mass of breast, 발생 횟수: 58, 비율: 0.07
#   암묵적 증상: Excessive anger, 발생 횟수: 57, 비율: 0.07
#   암묵적 증상: Knee lump or mass, 발생 횟수: 56, 비율: 0.07
#   암묵적 증상: Excessive urination at night, 발생 횟수: 53, 비율: 0.07
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Bleeding or discharge from nipple, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Sore throat, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Fever, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Weight gain, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Long menstrual periods, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Skin lesion, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Leg cramps or spasms, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Allergic reaction, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Skin irritation, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Acne or pimples, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Apnea, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Infertility, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Frequent menstruation, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Absence of menstruation, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Skin growth, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Intermenstrual bleeding, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Warts, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Plugged feeling in ear, 총 발생 횟수: 80
#   암묵적 증상: Diminished hearing, 발생 횟수: 26, 비율: 0.33
#   암묵적 증상: Ear pain, 발생 횟수: 14, 비율: 0.17
#   암묵적 증상: Dizziness, 발생 횟수: 12, 비율: 0.15
#   암묵적 증상: Ringing in ear, 발생 횟수: 11, 비율: 0.14
#   암묵적 증상: Redness in ear, 발생 횟수: 10, 비율: 0.12
#   암묵적 증상: Swollen or red tonsils, 발생 횟수: 3, 비율: 0.04
#   암묵적 증상: Hoarse voice, 발생 횟수: 2, 비율: 0.03
#   암묵적 증상: Fluid in ear, 발생 횟수: 1, 비율: 0.01
#   암묵적 증상: Difficulty speaking, 발생 횟수: 1, 비율: 0.01
#
# 명시적 증상: Anxiety and nervousness, 총 발생 횟수: 933
#   암묵적 증상: Depression, 발생 횟수: 151, 비율: 0.16
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 144, 비율: 0.15
#   암묵적 증상: Sharp chest pain, 발생 횟수: 51, 비율: 0.05
#   암묵적 증상: Insomnia, 발생 횟수: 47, 비율: 0.05
#   암묵적 증상: Shortness of breath, 발생 횟수: 45, 비율: 0.05
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 43, 비율: 0.05
#   암묵적 증상: Headache, 발생 횟수: 37, 비율: 0.04
#   암묵적 증상: Excessive anger, 발생 횟수: 31, 비율: 0.03
#   암묵적 증상: Fatigue, 발생 횟수: 28, 비율: 0.03
#   암묵적 증상: Low self-esteem, 발생 횟수: 27, 비율: 0.03
#   암묵적 증상: Abusing alcohol, 발생 횟수: 25, 비율: 0.03
#   암묵적 증상: Seizures, 발생 횟수: 23, 비율: 0.02
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 21, 비율: 0.02
#   암묵적 증상: Disturbance of memory, 발생 횟수: 20, 비율: 0.02
#   암묵적 증상: Dizziness, 발생 횟수: 18, 비율: 0.02
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 17, 비율: 0.02
#   암묵적 증상: Decreased appetite, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Weakness, 발생 횟수: 12, 비율: 0.01
#   암묵적 증상: Excessive appetite, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Nausea, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Fears and phobias, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Fever, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Sweating, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Vomiting, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Fainting, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Allergic reaction, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Chest tightness, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Hostile behavior, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Cramps and spasms, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Symptoms of the kidneys, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Sore throat, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Weight gain, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Neck stiffness or tightness, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Congestion in chest, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Increased heart rate, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Problems with movement, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Restlessness, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Focal weakness, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Burning abdominal pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Acne or pimples, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Vomiting blood, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Temper problems, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Cough, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Difficulty eating, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Arm stiffness or tightness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Palpitations, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Eye strain, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Nailbiting, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Wrist weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Feeling hot and cold, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Eye redness, 총 발생 횟수: 799
#   암묵적 증상: Pain in eye, 발생 횟수: 152, 비율: 0.19
#   암묵적 증상: Diminished vision, 발생 횟수: 112, 비율: 0.14
#   암묵적 증상: Symptoms of eye, 발생 횟수: 68, 비율: 0.09
#   암묵적 증상: Itchiness of eye, 발생 횟수: 66, 비율: 0.08
#   암묵적 증상: Lacrimation, 발생 횟수: 64, 비율: 0.08
#   암묵적 증상: Swollen eye, 발생 횟수: 61, 비율: 0.08
#   암묵적 증상: Mass on eyelid, 발생 횟수: 36, 비율: 0.05
#   암묵적 증상: Spots or clouds in vision, 발생 횟수: 27, 비율: 0.03
#   암묵적 증상: Foreign body sensation in eye, 발생 횟수: 26, 비율: 0.03
#   암묵적 증상: Eye burns or stings, 발생 횟수: 18, 비율: 0.02
#   암묵적 증상: Eyelid lesion or rash, 발생 횟수: 17, 비율: 0.02
#   암묵적 증상: Nasal congestion, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Cough, 발생 횟수: 13, 비율: 0.02
#   암묵적 증상: White discharge from eye, 발생 횟수: 13, 비율: 0.02
#   암묵적 증상: Abnormal movement of eyelid, 발생 횟수: 12, 비율: 0.02
#   암묵적 증상: Foot or toe pain, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Skin rash, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Painful urination, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Allergic reaction, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Eyelid swelling, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Skin lesion, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Painful sinuses, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Fever, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Paresthesia, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Skin growth, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Itching of skin, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Skin swelling, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Double vision, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Pain in testicles, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Irritable infant, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Sneezing, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Blindness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Ache all over, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Problems during pregnancy, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Dizziness, 총 발생 횟수: 958
#   암묵적 증상: Headache, 발생 횟수: 104, 비율: 0.11
#   암묵적 증상: Nausea, 발생 횟수: 58, 비율: 0.06
#   암묵적 증상: Vomiting, 발생 횟수: 44, 비율: 0.05
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 42, 비율: 0.04
#   암묵적 증상: Leg pain, 발생 횟수: 37, 비율: 0.04
#   암묵적 증상: Loss of sensation, 발생 횟수: 34, 비율: 0.04
#   암묵적 증상: Diminished hearing, 발생 횟수: 29, 비율: 0.03
#   암묵적 증상: Neck pain, 발생 횟수: 29, 비율: 0.03
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 29, 비율: 0.03
#   암묵적 증상: Frequent urination, 발생 횟수: 27, 비율: 0.03
#   암묵적 증상: Back pain, 발생 횟수: 26, 비율: 0.03
#   암묵적 증상: Shortness of breath, 발생 횟수: 26, 비율: 0.03
#   암묵적 증상: Difficulty in swallowing, 발생 횟수: 26, 비율: 0.03
#   암묵적 증상: Cough, 발생 횟수: 25, 비율: 0.03
#   암묵적 증상: Excessive appetite, 발생 횟수: 22, 비율: 0.02
#   암묵적 증상: Problems with movement, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Weakness, 발생 횟수: 18, 비율: 0.02
#   암묵적 증상: Disturbance of memory, 발생 횟수: 18, 비율: 0.02
#   암묵적 증상: Side pain, 발생 횟수: 16, 비율: 0.02
#   암묵적 증상: Sharp chest pain, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Leg weakness, 발생 횟수: 12, 비율: 0.01
#   암묵적 증상: Difficulty speaking, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Skin rash, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Facial pain, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Frontal headache, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Fainting, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Ringing in ear, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Paresthesia, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Seizures, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Diarrhea, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Sleepiness, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Fatigue, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Ache all over, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Fever, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Lip swelling, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Palpitations, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Plugged feeling in ear, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Allergic reaction, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Insomnia, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Ear pain, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Diminished vision, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Elbow cramps or spasms, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Hand or finger pain, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Redness in ear, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Double vision, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Depression, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Itching of skin, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Blood in urine, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Peripheral edema, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Leg cramps or spasms, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Retention of urine, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Focal weakness, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Elbow weakness, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Foot or toe swelling, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Emotional symptoms, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Hoarse voice, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Itchy eyelid, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Burning abdominal pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Chest tightness, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Kidney mass, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Weight gain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Fluid in ear, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Joint pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Symptoms of the kidneys, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Wrist weakness, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Swollen or red tonsils, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Nailbiting, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Fears and phobias, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Arm stiffness or tightness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Rib pain, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Feeling hot and cold, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Lack of growth, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Muscle pain, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Arm pain, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Hemoptysis, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Excessive growth, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Muscle cramps, contractures, or spasms, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Low back weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Sweating, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Allergic reaction, 총 발생 횟수: 492
#   암묵적 증상: Skin rash, 발생 횟수: 87, 비율: 0.18
#   암묵적 증상: Itching of skin, 발생 횟수: 49, 비율: 0.10
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 27, 비율: 0.05
#   암묵적 증상: Peripheral edema, 발생 횟수: 24, 비율: 0.05
#   암묵적 증상: Cough, 발생 횟수: 19, 비율: 0.04
#   암묵적 증상: Seizures, 발생 횟수: 15, 비율: 0.03
#   암묵적 증상: Skin lesion, 발생 횟수: 15, 비율: 0.03
#   암묵적 증상: Dizziness, 발생 횟수: 14, 비율: 0.03
#   암묵적 증상: Lip swelling, 발생 횟수: 14, 비율: 0.03
#   암묵적 증상: Itchiness of eye, 발생 횟수: 14, 비율: 0.03
#   암묵적 증상: Vomiting, 발생 횟수: 12, 비율: 0.02
#   암묵적 증상: Weight gain, 발생 횟수: 12, 비율: 0.02
#   암묵적 증상: Depression, 발생 횟수: 10, 비율: 0.02
#   암묵적 증상: Skin dryness, peeling, scaliness, or roughness, 발생 횟수: 9, 비율: 0.02
#   암묵적 증상: Swollen eye, 발생 횟수: 9, 비율: 0.02
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 8, 비율: 0.02
#   암묵적 증상: Eye redness, 발생 횟수: 8, 비율: 0.02
#   암묵적 증상: Sore throat, 발생 횟수: 8, 비율: 0.02
#   암묵적 증상: Nausea, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Focal weakness, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Fatigue, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Pain in eye, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Skin swelling, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Shortness of breath, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Sweating, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Headache, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Throat swelling, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Weakness, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Infertility, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Coryza, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Fever, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Fainting, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Warts, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Skin moles, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Nasal congestion, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Eye burns or stings, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Swollen tongue, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Lacrimation, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Diminished vision, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Acne or pimples, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Symptoms of eye, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Skin pain, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Mouth ulcer, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Irregular appearing scalp, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Skin growth, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Difficulty in swallowing, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Skin irritation, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Pain or soreness of breast, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Sneezing, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Hot flashes, 총 발생 횟수: 55
#   암묵적 증상: Vaginal bleeding after menopause, 발생 횟수: 12, 비율: 0.22
#   암묵적 증상: Pelvic pain, 발생 횟수: 7, 비율: 0.13
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 7, 비율: 0.13
#   암묵적 증상: Intermenstrual bleeding, 발생 횟수: 6, 비율: 0.11
#   암묵적 증상: Unpredictable menstruation, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Vaginal itching, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Painful menstruation, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Lower abdominal pain, 발생 횟수: 2, 비율: 0.04
#   암묵적 증상: Cramps and spasms, 발생 횟수: 2, 비율: 0.04
#   암묵적 증상: Burning abdominal pain, 발생 횟수: 2, 비율: 0.04
#   암묵적 증상: Vaginal discharge, 발생 횟수: 2, 비율: 0.04
#   암묵적 증상: Mass on vulva, 발생 횟수: 1, 비율: 0.02
#   암묵적 증상: Heavy menstrual flow, 발생 횟수: 1, 비율: 0.02
#   암묵적 증상: Infrequent menstruation, 발생 횟수: 1, 비율: 0.02
#   암묵적 증상: Infertility, 발생 횟수: 1, 비율: 0.02
#   암묵적 증상: Chills, 발생 횟수: 1, 비율: 0.02
#   암묵적 증상: Long menstrual periods, 발생 횟수: 1, 비율: 0.02
#
# 명시적 증상: Vaginal pain, 총 발생 횟수: 268
#   암묵적 증상: Groin pain, 발생 횟수: 41, 비율: 0.15
#   암묵적 증상: Nausea, 발생 횟수: 36, 비율: 0.13
#   암묵적 증상: Sharp chest pain, 발생 횟수: 34, 비율: 0.13
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 21, 비율: 0.08
#   암묵적 증상: Penile discharge, 발생 횟수: 19, 비율: 0.07
#   암묵적 증상: Vaginal discharge, 발생 횟수: 14, 비율: 0.05
#   암묵적 증상: Pelvic pain, 발생 횟수: 14, 비율: 0.05
#   암묵적 증상: Vulvar sore, 발생 횟수: 11, 비율: 0.04
#   암묵적 증상: Itching of skin, 발생 횟수: 10, 비율: 0.04
#   암묵적 증상: Painful urination, 발생 횟수: 9, 비율: 0.03
#   암묵적 증상: Wrist weakness, 발생 횟수: 8, 비율: 0.03
#   암묵적 증상: Vaginal itching, 발생 횟수: 6, 비율: 0.02
#   암묵적 증상: Excessive growth, 발생 횟수: 5, 비율: 0.02
#   암묵적 증상: Lower abdominal pain, 발생 횟수: 5, 비율: 0.02
#   암묵적 증상: Nailbiting, 발생 횟수: 5, 비율: 0.02
#   암묵적 증상: Loss of sex drive, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Frequent urination, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Penis pain, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Knee lump or mass, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Neck cramps or spasms, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Shoulder swelling, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Burning abdominal pain, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Infertility, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Absence of menstruation, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Paresthesia, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Heavy menstrual flow, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Cramps and spasms, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Painful menstruation, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Problems with movement, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Restlessness, 총 발생 횟수: 58
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 9, 비율: 0.16
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 6, 비율: 0.10
#   암묵적 증상: Seizures, 발생 횟수: 5, 비율: 0.09
#   암묵적 증상: Disturbance of memory, 발생 횟수: 5, 비율: 0.09
#   암묵적 증상: Depression, 발생 횟수: 4, 비율: 0.07
#   암묵적 증상: Arm stiffness or tightness, 발생 횟수: 4, 비율: 0.07
#   암묵적 증상: Cramps and spasms, 발생 횟수: 4, 비율: 0.07
#   암묵적 증상: Hostile behavior, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Problems with movement, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Headache, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Neck stiffness or tightness, 발생 횟수: 2, 비율: 0.03
#   암묵적 증상: Low self-esteem, 발생 횟수: 2, 비율: 0.03
#   암묵적 증상: Nausea, 발생 횟수: 1, 비율: 0.02
#   암묵적 증상: Excessive anger, 발생 횟수: 1, 비율: 0.02
#
# 명시적 증상: Pain in eye, 총 발생 횟수: 1766
#   암묵적 증상: Diminished vision, 발생 횟수: 191, 비율: 0.11
#   암묵적 증상: Eye redness, 발생 횟수: 154, 비율: 0.09
#   암묵적 증상: Lacrimation, 발생 횟수: 97, 비율: 0.05
#   암묵적 증상: Symptoms of eye, 발생 횟수: 89, 비율: 0.05
#   암묵적 증상: Itchiness of eye, 발생 횟수: 85, 비율: 0.05
#   암묵적 증상: Swollen eye, 발생 횟수: 75, 비율: 0.04
#   암묵적 증상: Joint stiffness or tightness, 발생 횟수: 63, 비율: 0.04
#   암묵적 증상: Excessive anger, 발생 횟수: 63, 비율: 0.04
#   암묵적 증상: Ankle pain, 발생 횟수: 63, 비율: 0.04
#   암묵적 증상: Shoulder cramps or spasms, 발생 횟수: 63, 비율: 0.04
#   암묵적 증상: Mass on eyelid, 발생 횟수: 60, 비율: 0.03
#   암묵적 증상: Wrist pain, 발생 횟수: 60, 비율: 0.03
#   암묵적 증상: Facial pain, 발생 횟수: 59, 비율: 0.03
#   암묵적 증상: Pain during pregnancy, 발생 횟수: 59, 비율: 0.03
#   암묵적 증상: Knee lump or mass, 발생 횟수: 55, 비율: 0.03
#   암묵적 증상: Pain or soreness of breast, 발생 횟수: 53, 비율: 0.03
#   암묵적 증상: Excessive urination at night, 발생 횟수: 50, 비율: 0.03
#   암묵적 증상: Fatigue, 발생 횟수: 48, 비율: 0.03
#   암묵적 증상: Foreign body sensation in eye, 발생 횟수: 42, 비율: 0.02
#   암묵적 증상: Spots or clouds in vision, 발생 횟수: 40, 비율: 0.02
#   암묵적 증상: Eye burns or stings, 발생 횟수: 33, 비율: 0.02
#   암묵적 증상: Abnormal movement of eyelid, 발생 횟수: 27, 비율: 0.02
#   암묵적 증상: Eyelid lesion or rash, 발생 횟수: 25, 비율: 0.01
#   암묵적 증상: Fever, 발생 횟수: 20, 비율: 0.01
#   암묵적 증상: Skin growth, 발생 횟수: 17, 비율: 0.01
#   암묵적 증상: Sore throat, 발생 횟수: 17, 비율: 0.01
#   암묵적 증상: White discharge from eye, 발생 횟수: 15, 비율: 0.01
#   암묵적 증상: Eyelid swelling, 발생 횟수: 13, 비율: 0.01
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Blindness, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Painful sinuses, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Skin lesion, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Nasal congestion, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Cough, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Foot or toe pain, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Skin rash, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Wrinkles on skin, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Painful urination, 발생 횟수: 8, 비율: 0.00
#   암묵적 증상: Paresthesia, 발생 횟수: 7, 비율: 0.00
#   암묵적 증상: Double vision, 발생 횟수: 7, 비율: 0.00
#   암묵적 증상: Allergic reaction, 발생 횟수: 5, 비율: 0.00
#   암묵적 증상: Coryza, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Bleeding from eye, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Mouth ulcer, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Skin pain, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Fluid retention, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Elbow pain, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Vomiting, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Eye deviation, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Disturbance of memory, 총 발생 횟수: 443
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 74, 비율: 0.17
#   암묵적 증상: Depression, 발생 횟수: 58, 비율: 0.13
#   암묵적 증상: Loss of sensation, 발생 횟수: 37, 비율: 0.08
#   암묵적 증상: Paresthesia, 발생 횟수: 32, 비율: 0.07
#   암묵적 증상: Lip swelling, 발생 횟수: 24, 비율: 0.05
#   암묵적 증상: Headache, 발생 횟수: 24, 비율: 0.05
#   암묵적 증상: Seizures, 발생 횟수: 22, 비율: 0.05
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 21, 비율: 0.05
#   암묵적 증상: Problems with movement, 발생 횟수: 18, 비율: 0.04
#   암묵적 증상: Dizziness, 발생 횟수: 15, 비율: 0.03
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 11, 비율: 0.02
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 11, 비율: 0.02
#   암묵적 증상: Hostile behavior, 발생 횟수: 10, 비율: 0.02
#   암묵적 증상: Difficulty speaking, 발생 횟수: 8, 비율: 0.02
#   암묵적 증상: Nausea, 발생 횟수: 8, 비율: 0.02
#   암묵적 증상: Restlessness, 발생 횟수: 7, 비율: 0.02
#   암묵적 증상: Neck pain, 발생 횟수: 7, 비율: 0.02
#   암묵적 증상: Low self-esteem, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Leg pain, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Vomiting, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Excessive anger, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Leg weakness, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Insomnia, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Fatigue, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Back pain, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Muscle cramps, contractures, or spasms, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Joint pain, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Facial pain, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Eye burns or stings, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Elbow weakness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Arm stiffness or tightness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Nailbiting, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Muscle pain, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Cramps and spasms, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Itchy eyelid, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Muscle swelling, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Back weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Fears and phobias, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Irregular appearing scalp, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Double vision, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Wrist weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Excessive growth, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Arm stiffness or tightness, 총 발생 횟수: 39
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 9, 비율: 0.23
#   암묵적 증상: Cramps and spasms, 발생 횟수: 5, 비율: 0.13
#   암묵적 증상: Seizures, 발생 횟수: 4, 비율: 0.10
#   암묵적 증상: Problems with movement, 발생 횟수: 4, 비율: 0.10
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 4, 비율: 0.10
#   암묵적 증상: Nausea, 발생 횟수: 2, 비율: 0.05
#   암묵적 증상: Headache, 발생 횟수: 2, 비율: 0.05
#   암묵적 증상: Neck stiffness or tightness, 발생 횟수: 2, 비율: 0.05
#   암묵적 증상: Restlessness, 발생 횟수: 2, 비율: 0.05
#   암묵적 증상: Disturbance of memory, 발생 횟수: 2, 비율: 0.05
#   암묵적 증상: Loss of sensation, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Muscle pain, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Painful sinuses, 발생 횟수: 1, 비율: 0.03
#
# 명시적 증상: Skin growth, 총 발생 횟수: 347
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 23, 비율: 0.07
#   암묵적 증상: Mass on eyelid, 발생 횟수: 23, 비율: 0.07
#   암묵적 증상: Skin lesion, 발생 횟수: 21, 비율: 0.06
#   암묵적 증상: Knee pain, 발생 횟수: 18, 비율: 0.05
#   암묵적 증상: Acne or pimples, 발생 횟수: 18, 비율: 0.05
#   암묵적 증상: Skin rash, 발생 횟수: 18, 비율: 0.05
#   암묵적 증상: Wrist pain, 발생 횟수: 17, 비율: 0.05
#   암묵적 증상: Eyelid lesion or rash, 발생 횟수: 17, 비율: 0.05
#   암묵적 증상: Symptoms of eye, 발생 횟수: 15, 비율: 0.04
#   암묵적 증상: Diminished vision, 발생 횟수: 14, 비율: 0.04
#   암묵적 증상: Itchiness of eye, 발생 횟수: 13, 비율: 0.04
#   암묵적 증상: Skin dryness, peeling, scaliness, or roughness, 발생 횟수: 12, 비율: 0.03
#   암묵적 증상: Leg pain, 발생 횟수: 12, 비율: 0.03
#   암묵적 증상: Pain in eye, 발생 횟수: 12, 비율: 0.03
#   암묵적 증상: Wrist lump or mass, 발생 횟수: 10, 비율: 0.03
#   암묵적 증상: Wrinkles on skin, 발생 횟수: 10, 비율: 0.03
#   암묵적 증상: Hand or finger pain, 발생 횟수: 9, 비율: 0.03
#   암묵적 증상: Foot or toe pain, 발생 횟수: 8, 비율: 0.02
#   암묵적 증상: Irregular appearing scalp, 발생 횟수: 8, 비율: 0.02
#   암묵적 증상: Skin swelling, 발생 횟수: 7, 비율: 0.02
#   암묵적 증상: Skin moles, 발생 횟수: 7, 비율: 0.02
#   암묵적 증상: Hand or finger lump or mass, 발생 횟수: 7, 비율: 0.02
#   암묵적 증상: Knee lump or mass, 발생 횟수: 6, 비율: 0.02
#   암묵적 증상: Abnormal movement of eyelid, 발생 횟수: 6, 비율: 0.02
#   암묵적 증상: Wrist swelling, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Itching of skin, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Swollen eye, 발생 횟수: 4, 비율: 0.01
#   암묵적 증상: Weight gain, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Eye redness, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Knee swelling, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Retention of urine, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Apnea, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Lacrimation, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Skin irritation, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Itchy scalp, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Too little hair, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Foreign body sensation in eye, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Infertility, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Symptoms of the face, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Lack of growth, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Eyelid swelling, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Leg swelling, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Warts, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Depressive or psychotic symptoms, 총 발생 횟수: 1093
#   암묵적 증상: Depression, 발생 횟수: 169, 비율: 0.15
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 140, 비율: 0.13
#   암묵적 증상: Disturbance of memory, 발생 횟수: 68, 비율: 0.06
#   암묵적 증상: Sharp chest pain, 발생 횟수: 47, 비율: 0.04
#   암묵적 증상: Abusing alcohol, 발생 횟수: 46, 비율: 0.04
#   암묵적 증상: Low self-esteem, 발생 횟수: 40, 비율: 0.04
#   암묵적 증상: Dizziness, 발생 횟수: 39, 비율: 0.04
#   암묵적 증상: Excessive anger, 발생 횟수: 37, 비율: 0.03
#   암묵적 증상: Headache, 발생 횟수: 31, 비율: 0.03
#   암묵적 증상: Nausea, 발생 횟수: 28, 비율: 0.03
#   암묵적 증상: Drug abuse, 발생 횟수: 27, 비율: 0.02
#   암묵적 증상: Leg pain, 발생 횟수: 26, 비율: 0.02
#   암묵적 증상: Loss of sensation, 발생 횟수: 25, 비율: 0.02
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 25, 비율: 0.02
#   암묵적 증상: Back pain, 발생 횟수: 24, 비율: 0.02
#   암묵적 증상: Paresthesia, 발생 횟수: 24, 비율: 0.02
#   암묵적 증상: Vomiting, 발생 횟수: 23, 비율: 0.02
#   암묵적 증상: Side pain, 발생 횟수: 22, 비율: 0.02
#   암묵적 증상: Insomnia, 발생 횟수: 21, 비율: 0.02
#   암묵적 증상: Diminished hearing, 발생 횟수: 20, 비율: 0.02
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Hostile behavior, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Lip swelling, 발생 횟수: 15, 비율: 0.01
#   암묵적 증상: Problems with movement, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Decreased appetite, 발생 횟수: 13, 비율: 0.01
#   암묵적 증상: Shortness of breath, 발생 횟수: 13, 비율: 0.01
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Diarrhea, 발생 횟수: 9, 비율: 0.01
#   암묵적 증상: Excessive appetite, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Frontal headache, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Acne or pimples, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Fainting, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Weight gain, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Fears and phobias, 발생 횟수: 5, 비율: 0.00
#   암묵적 증상: Weakness, 발생 횟수: 5, 비율: 0.00
#   암묵적 증상: Difficulty eating, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Difficulty speaking, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Excessive growth, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Elbow cramps or spasms, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Palpitations, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Fatigue, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Burning abdominal pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Temper problems, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Vomiting blood, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Nightmares, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Thirst, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Low back weakness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Elbow weakness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Restlessness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Chest tightness, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Nailbiting, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Increased heart rate, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Emotional symptoms, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Itchy eyelid, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Sleepiness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Muscle swelling, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Fluid retention, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Frequent urination, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Wrist weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Irregular appearing scalp, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Pus in urine, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Feeling hot and cold, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Abusing alcohol, 총 발생 횟수: 337
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 64, 비율: 0.19
#   암묵적 증상: Depression, 발생 횟수: 40, 비율: 0.12
#   암묵적 증상: Drug abuse, 발생 횟수: 35, 비율: 0.10
#   암묵적 증상: Sharp chest pain, 발생 횟수: 33, 비율: 0.10
#   암묵적 증상: Vomiting, 발생 횟수: 27, 비율: 0.08
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 24, 비율: 0.07
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 18, 비율: 0.05
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 16, 비율: 0.05
#   암묵적 증상: Nausea, 발생 횟수: 11, 비율: 0.03
#   암묵적 증상: Fainting, 발생 횟수: 10, 비율: 0.03
#   암묵적 증상: Problems with movement, 발생 횟수: 10, 비율: 0.03
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 9, 비율: 0.03
#   암묵적 증상: Excessive appetite, 발생 횟수: 9, 비율: 0.03
#   암묵적 증상: Excessive anger, 발생 횟수: 6, 비율: 0.02
#   암묵적 증상: Decreased appetite, 발생 횟수: 6, 비율: 0.02
#   암묵적 증상: Weight gain, 발생 횟수: 5, 비율: 0.01
#   암묵적 증상: Difficulty eating, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Hostile behavior, 발생 횟수: 3, 비율: 0.01
#   암묵적 증상: Insomnia, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Vomiting blood, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Fears and phobias, 발생 횟수: 2, 비율: 0.01
#   암묵적 증상: Acne or pimples, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Nightmares, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Leg pain, 총 발생 횟수: 1188
#   암묵적 증상: Back pain, 발생 횟수: 129, 비율: 0.11
#   암묵적 증상: Low back pain, 발생 횟수: 100, 비율: 0.08
#   암묵적 증상: Loss of sensation, 발생 횟수: 78, 비율: 0.07
#   암묵적 증상: Ache all over, 발생 횟수: 67, 비율: 0.06
#   암묵적 증상: Hip pain, 발생 횟수: 60, 비율: 0.05
#   암묵적 증상: Neck pain, 발생 횟수: 57, 비율: 0.05
#   암묵적 증상: Knee pain, 발생 횟수: 56, 비율: 0.05
#   암묵적 증상: Problems with movement, 발생 횟수: 36, 비율: 0.03
#   암묵적 증상: Paresthesia, 발생 횟수: 36, 비율: 0.03
#   암묵적 증상: Dizziness, 발생 횟수: 35, 비율: 0.03
#   암묵적 증상: Foot or toe pain, 발생 횟수: 34, 비율: 0.03
#   암묵적 증상: Difficulty speaking, 발생 횟수: 27, 비율: 0.02
#   암묵적 증상: Headache, 발생 횟수: 27, 비율: 0.02
#   암묵적 증상: Hand or finger pain, 발생 횟수: 27, 비율: 0.02
#   암묵적 증상: Arm pain, 발생 횟수: 26, 비율: 0.02
#   암묵적 증상: Leg weakness, 발생 횟수: 25, 비율: 0.02
#   암묵적 증상: Fever, 발생 횟수: 22, 비율: 0.02
#   암묵적 증상: Weakness, 발생 횟수: 22, 비율: 0.02
#   암묵적 증상: Shoulder pain, 발생 횟수: 21, 비율: 0.02
#   암묵적 증상: Fatigue, 발생 횟수: 20, 비율: 0.02
#   암묵적 증상: Wrist pain, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Groin pain, 발생 횟수: 17, 비율: 0.01
#   암묵적 증상: Side pain, 발생 횟수: 16, 비율: 0.01
#   암묵적 증상: Skin growth, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Skin lesion, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Lower body pain, 발생 횟수: 13, 비율: 0.01
#   암묵적 증상: Seizures, 발생 횟수: 12, 비율: 0.01
#   암묵적 증상: Diminished hearing, 발생 횟수: 12, 비율: 0.01
#   암묵적 증상: Muscle pain, 발생 횟수: 12, 비율: 0.01
#   암묵적 증상: Hand or finger lump or mass, 발생 횟수: 11, 비율: 0.01
#   암묵적 증상: Joint pain, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Wrist lump or mass, 발생 횟수: 10, 비율: 0.01
#   암묵적 증상: Knee swelling, 발생 횟수: 8, 비율: 0.01
#   암묵적 증상: Disturbance of memory, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Knee lump or mass, 발생 횟수: 7, 비율: 0.01
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Difficulty in swallowing, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Facial pain, 발생 횟수: 6, 비율: 0.01
#   암묵적 증상: Hand or finger weakness, 발생 횟수: 5, 비율: 0.00
#   암묵적 증상: Rib pain, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Insomnia, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Muscle weakness, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Poor circulation, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Leg swelling, 발생 횟수: 4, 비율: 0.00
#   암묵적 증상: Leg cramps or spasms, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Bones are painful, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Sharp chest pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Pelvic pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Elbow pain, 발생 횟수: 3, 비율: 0.00
#   암묵적 증상: Stiffness all over, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Feeling hot and cold, 발생 횟수: 2, 비율: 0.00
#   암묵적 증상: Knee weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Skin on leg or foot looks infected, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Foot or toe swelling, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Lymphedema, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Elbow weakness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Hand or finger cramps or spasms, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Knee stiffness or tightness, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Wrist swelling, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Back cramps or spasms, 발생 횟수: 1, 비율: 0.00
#   암묵적 증상: Focal weakness, 발생 횟수: 1, 비율: 0.00
#
# 명시적 증상: Blindness, 총 발생 횟수: 123
#   암묵적 증상: Diminished vision, 발생 횟수: 52, 비율: 0.42
#   암묵적 증상: Symptoms of eye, 발생 횟수: 20, 비율: 0.16
#   암묵적 증상: Spots or clouds in vision, 발생 횟수: 18, 비율: 0.15
#   암묵적 증상: Pain in eye, 발생 횟수: 10, 비율: 0.08
#   암묵적 증상: Foreign body sensation in eye, 발생 횟수: 8, 비율: 0.07
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 4, 비율: 0.03
#   암묵적 증상: Eye redness, 발생 횟수: 2, 비율: 0.02
#   암묵적 증상: Elbow pain, 발생 횟수: 2, 비율: 0.02
#   암묵적 증상: Eye deviation, 발생 횟수: 2, 비율: 0.02
#   암묵적 증상: Double vision, 발생 횟수: 2, 비율: 0.02
#   암묵적 증상: Itchiness of eye, 발생 횟수: 1, 비율: 0.01
#   암묵적 증상: Lacrimation, 발생 횟수: 1, 비율: 0.01
#   암묵적 증상: Bleeding from eye, 발생 횟수: 1, 비율: 0.01
#
# 명시적 증상: Sharp abdominal pain, 총 발생 횟수: 1079
#   암묵적 증상: Penile discharge, 발생 횟수: 50, 비율: 0.05
#   암묵적 증상: Vomiting, 발생 횟수: 45, 비율: 0.04
#   암묵적 증상: Painful urination, 발생 횟수: 43, 비율: 0.04
#   암묵적 증상: Pelvic pain, 발생 횟수: 41, 비율: 0.04
#   암묵적 증상: Vaginal discharge, 발생 횟수: 39, 비율: 0.04
#   암묵적 증상: Nausea, 발생 횟수: 33, 비율: 0.03
#   암묵적 증상: Back pain, 발생 횟수: 28, 비율: 0.03
#   암묵적 증상: Shoulder cramps or spasms, 발생 횟수: 28, 비율: 0.03
#   암묵적 증상: Shortness of breath, 발생 횟수: 27, 비율: 0.03
#   암묵적 증상: Lower abdominal pain, 발생 횟수: 26, 비율: 0.02
#   암묵적 증상: Frequent urination, 발생 횟수: 26, 비율: 0.02
#   암묵적 증상: Wrist pain, 발생 횟수: 25, 비율: 0.02
#   암묵적 증상: Weakness, 발생 횟수: 22, 비율: 0.02
#   암묵적 증상: Joint stiffness or tightness, 발생 횟수: 21, 비율: 0.02
#   암묵적 증상: Pain or soreness of breast, 발생 횟수: 21, 비율: 0.02
#   암묵적 증상: Fatigue, 발생 횟수: 21, 비율: 0.02
#   암묵적 증상: Painful menstruation, 발생 횟수: 20, 비율: 0.02
#   암묵적 증상: Pain in testicles, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Facial pain, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Sharp chest pain, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Pain during pregnancy, 발생 횟수: 19, 비율: 0.02
#   암묵적 증상: Ankle pain, 발생 횟수: 17, 비율: 0.02
#   암묵적 증상: Excessive anger, 발생 횟수: 17, 비율: 0.02
#   암묵적 증상: Blood in urine, 발생 횟수: 16, 비율: 0.01
#   암묵적 증상: Peripheral edema, 발생 횟수: 16, 비율: 0.01
#   암묵적 증상: Vaginal itching, 발생 횟수: 16, 비율: 0.01
#   암묵적 증상: Pain in eye, 발생 횟수: 16, 비율: 0.01
#   암묵적 증상: Itching of skin, 발생 횟수: 16, 비율: 0.01
#   암묵적 증상: Vaginal pain, 발생 횟수: 16, 비율: 0.01
#   암묵적 증상: Knee lump or mass, 발생 횟수: 15, 비율: 0.01
#   암묵적 증상: Suprapubic pain, 발생 횟수: 15, 비율: 0.01
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Swelling of scrotum, 발생 횟수: 14, 비율: 0.01
#   암묵적 증상: Neck pain, 발생 횟수: 14, 비율: 0.01
# ...
#
# 명시적 증상: Penis pain, 총 발생 횟수: 32
#   암묵적 증상: Painful urination, 발생 횟수: 5, 비율: 0.16
#   암묵적 증상: Impotence, 발생 횟수: 4, 비율: 0.12
#   암묵적 증상: Penile discharge, 발생 횟수: 4, 비율: 0.12
#   암묵적 증상: Vaginal discharge, 발생 횟수: 4, 비율: 0.12
#   암묵적 증상: Frequent urination, 발생 횟수: 3, 비율: 0.09
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 3, 비율: 0.09
#   암묵적 증상: Pain in testicles, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Lower abdominal pain, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Retention of urine, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Itching of skin, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Groin pain, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Pelvic pain, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Vaginal pain, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Involuntary urination, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Pain during intercourse, 발생 횟수: 1, 비율: 0.03
#
# 명시적 증상: Dry or flaky scalp, 총 발생 횟수: 45
#   암묵적 증상: Skin rash, 발생 횟수: 11, 비율: 0.24
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 5, 비율: 0.11
#   암묵적 증상: Ankle pain, 발생 횟수: 5, 비율: 0.11
#   암묵적 증상: Skin dryness, peeling, scaliness, or roughness, 발생 횟수: 4, 비율: 0.09
#   암묵적 증상: Itching of skin, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Frequent urination, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Back pain, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Skin on leg or foot looks infected, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Skin lesion, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Acne or pimples, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Foot or toe lump or mass, 발생 횟수: 2, 비율: 0.04
#
# 명시적 증상: Muscle swelling, 총 발생 횟수: 5
#   암묵적 증상: Weight gain, 발생 횟수: 3, 비율: 0.60
#   암묵적 증상: Decreased heart rate, 발생 횟수: 1, 비율: 0.20
#   암묵적 증상: Elbow weakness, 발생 횟수: 1, 비율: 0.20
#
# 명시적 증상: Muscle weakness, 총 발생 횟수: 50
#   암묵적 증상: Weakness, 발생 횟수: 6, 비율: 0.12
#   암묵적 증상: Back pain, 발생 횟수: 6, 비율: 0.12
#   암묵적 증상: Difficulty speaking, 발생 횟수: 5, 비율: 0.10
#   암묵적 증상: Leg cramps or spasms, 발생 횟수: 5, 비율: 0.10
#   암묵적 증상: Problems with movement, 발생 횟수: 5, 비율: 0.10
#   암묵적 증상: Hand or finger weakness, 발생 횟수: 5, 비율: 0.10
#   암묵적 증상: Leg pain, 발생 횟수: 5, 비율: 0.10
#   암묵적 증상: Difficulty in swallowing, 발생 횟수: 4, 비율: 0.08
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 3, 비율: 0.06
#   암묵적 증상: Leg weakness, 발생 횟수: 3, 비율: 0.06
#   암묵적 증상: Fatigue, 발생 횟수: 3, 비율: 0.06
#
# 명시적 증상: Feeling hot and cold, 총 발생 횟수: 18
#   암묵적 증상: Back pain, 발생 횟수: 2, 비율: 0.11
#   암묵적 증상: Skin rash, 발생 횟수: 2, 비율: 0.11
#   암묵적 증상: Swelling of scrotum, 발생 횟수: 2, 비율: 0.11
#   암묵적 증상: Vomiting, 발생 횟수: 2, 비율: 0.11
#   암묵적 증상: Leg pain, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Diminished hearing, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Skin lesion, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Side pain, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Symptoms of the kidneys, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Congestion in chest, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Weakness, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 1, 비율: 0.06
#
# 명시적 증상: Eye deviation, 총 발생 횟수: 12
#   암묵적 증상: Diminished vision, 발생 횟수: 3, 비율: 0.25
#   암묵적 증상: Pain in eye, 발생 횟수: 3, 비율: 0.25
#   암묵적 증상: Blindness, 발생 횟수: 2, 비율: 0.17
#   암묵적 증상: Foreign body sensation in eye, 발생 횟수: 1, 비율: 0.08
#   암묵적 증상: Spots or clouds in vision, 발생 횟수: 1, 비율: 0.08
#   암묵적 증상: Symptoms of eye, 발생 횟수: 1, 비율: 0.08
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 1, 비율: 0.08
#
# 명시적 증상: Hand or finger lump or mass, 총 발생 횟수: 56
#   암묵적 증상: Knee pain, 발생 횟수: 13, 비율: 0.23
#   암묵적 증상: Wrist pain, 발생 횟수: 8, 비율: 0.14
#   암묵적 증상: Leg pain, 발생 횟수: 8, 비율: 0.14
#   암묵적 증상: Wrist lump or mass, 발생 횟수: 7, 비율: 0.12
#   암묵적 증상: Foot or toe pain, 발생 횟수: 6, 비율: 0.11
#   암묵적 증상: Hand or finger pain, 발생 횟수: 5, 비율: 0.09
#   암묵적 증상: Skin growth, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Knee swelling, 발생 횟수: 2, 비율: 0.04
#   암묵적 증상: Leg swelling, 발생 횟수: 2, 비율: 0.04
#   암묵적 증상: Wrist swelling, 발생 횟수: 1, 비율: 0.02
#   암묵적 증상: Knee lump or mass, 발생 횟수: 1, 비율: 0.02
#
# 명시적 증상: Polyuria, 총 발생 횟수: 15
#   암묵적 증상: Nausea, 발생 횟수: 4, 비율: 0.27
#   암묵적 증상: Vomiting, 발생 횟수: 3, 비율: 0.20
#   암묵적 증상: Weakness, 발생 횟수: 2, 비율: 0.13
#   암묵적 증상: Sharp chest pain, 발생 횟수: 2, 비율: 0.13
#   암묵적 증상: Diarrhea, 발생 횟수: 2, 비율: 0.13
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 1, 비율: 0.07
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 1, 비율: 0.07
#
# 명시적 증상: Fluid in ear, 총 발생 횟수: 29
#   암묵적 증상: Diminished hearing, 발생 횟수: 9, 비율: 0.31
#   암묵적 증상: Ear pain, 발생 횟수: 8, 비율: 0.28
#   암묵적 증상: Redness in ear, 발생 횟수: 4, 비율: 0.14
#   암묵적 증상: Plugged feeling in ear, 발생 횟수: 3, 비율: 0.10
#   암묵적 증상: Ringing in ear, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Dizziness, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Difficulty speaking, 발생 횟수: 1, 비율: 0.03
#
# 명시적 증상: Irregular belly button, 총 발생 횟수: 5
#   암묵적 증상: Infertility, 발생 횟수: 4, 비율: 0.80
#   암묵적 증상: Loss of sex drive, 발생 횟수: 1, 비율: 0.20
#
# 명시적 증상: Thirst, 총 발생 횟수: 40
#   암묵적 증상: Vomiting, 발생 횟수: 11, 비율: 0.28
#   암묵적 증상: Nausea, 발생 횟수: 6, 비율: 0.15
#   암묵적 증상: Weakness, 발생 횟수: 6, 비율: 0.15
#   암묵적 증상: Decreased appetite, 발생 횟수: 4, 비율: 0.10
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Sharp chest pain, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Diarrhea, 발생 횟수: 3, 비율: 0.07
#   암묵적 증상: Fluid retention, 발생 횟수: 2, 비율: 0.05
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Frequent urination, 발생 횟수: 1, 비율: 0.03
#
# 명시적 증상: Hoarse voice, 총 발생 횟수: 31
#   암묵적 증상: Diminished hearing, 발생 횟수: 5, 비율: 0.16
#   암묵적 증상: Ear pain, 발생 횟수: 4, 비율: 0.13
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 4, 비율: 0.13
#   암묵적 증상: Plugged feeling in ear, 발생 횟수: 3, 비율: 0.10
#   암묵적 증상: Dizziness, 발생 횟수: 2, 비율: 0.06
#   암묵적 증상: Ringing in ear, 발생 횟수: 2, 비율: 0.06
#   암묵적 증상: Redness in ear, 발생 횟수: 2, 비율: 0.06
#   암묵적 증상: Problems with movement, 발생 횟수: 2, 비율: 0.06
#   암묵적 증상: Headache, 발생 횟수: 2, 비율: 0.06
#   암묵적 증상: Seizures, 발생 횟수: 2, 비율: 0.06
#   암묵적 증상: Fluid in ear, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Swollen or red tonsils, 발생 횟수: 1, 비율: 0.03
#   암묵적 증상: Disturbance of memory, 발생 횟수: 1, 비율: 0.03
#
# 명시적 증상: Increased heart rate, 총 발생 횟수: 8
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 2, 비율: 0.25
#   암묵적 증상: Depression, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Shortness of breath, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Headache, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Insomnia, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 1, 비율: 0.12
#
# 명시적 증상: Swollen abdomen, 총 발생 횟수: 11
#   암묵적 증상: Swelling of scrotum, 발생 횟수: 3, 비율: 0.27
#   암묵적 증상: Blood in urine, 발생 횟수: 2, 비율: 0.18
#   암묵적 증상: Pain in testicles, 발생 횟수: 2, 비율: 0.18
#   암묵적 증상: Groin pain, 발생 횟수: 2, 비율: 0.18
#   암묵적 증상: Lower abdominal pain, 발생 횟수: 1, 비율: 0.09
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 1, 비율: 0.09
#
# 명시적 증상: Arm weakness, 총 발생 횟수: 8
#   암묵적 증상: Hand or finger pain, 발생 횟수: 2, 비율: 0.25
#   암묵적 증상: Loss of sensation, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Wrist pain, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Neck pain, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Hand or finger weakness, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Elbow pain, 발생 횟수: 1, 비율: 0.12
#   암묵적 증상: Hand or finger swelling, 발생 횟수: 1, 비율: 0.12
#
# 명시적 증상: Fears and phobias, 총 발생 횟수: 28
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 4, 비율: 0.14
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 4, 비율: 0.14
#   암묵적 증상: Depression, 발생 횟수: 4, 비율: 0.14
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 3, 비율: 0.11
#   암묵적 증상: Headache, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Sharp chest pain, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Low self-esteem, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Painful sinuses, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Seizures, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Disturbance of memory, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Insomnia, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Excessive anger, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Drug abuse, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Abusing alcohol, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Irregular heartbeat, 발생 횟수: 1, 비율: 0.04
#
# 명시적 증상: Nightmares, 총 발생 횟수: 7
#   암묵적 증상: Depression, 발생 횟수: 3, 비율: 0.43
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 2, 비율: 0.29
#   암묵적 증상: Abusing alcohol, 발생 횟수: 1, 비율: 0.14
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 1, 비율: 0.14
#
# 명시적 증상: Mass on vulva, 총 발생 횟수: 6
#   암묵적 증상: Vaginal bleeding after menopause, 발생 횟수: 3, 비율: 0.50
#   암묵적 증상: Vaginal discharge, 발생 횟수: 1, 비율: 0.17
#   암묵적 증상: Hot flashes, 발생 횟수: 1, 비율: 0.17
#   암묵적 증상: Cramps and spasms, 발생 횟수: 1, 비율: 0.17
#
# 명시적 증상: Eyelid swelling, 총 발생 횟수: 60
#   암묵적 증상: Pain in eye, 발생 횟수: 14, 비율: 0.23
#   암묵적 증상: Mass on eyelid, 발생 횟수: 9, 비율: 0.15
#   암묵적 증상: Swollen eye, 발생 횟수: 7, 비율: 0.12
#   암묵적 증상: Symptoms of eye, 발생 횟수: 6, 비율: 0.10
#   암묵적 증상: Diminished vision, 발생 횟수: 5, 비율: 0.08
#   암묵적 증상: Foreign body sensation in eye, 발생 횟수: 4, 비율: 0.07
#   암묵적 증상: Itchiness of eye, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Lacrimation, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Eye redness, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Eyelid lesion or rash, 발생 횟수: 3, 비율: 0.05
#   암묵적 증상: Skin growth, 발생 횟수: 2, 비율: 0.03
#   암묵적 증상: Eye burns or stings, 발생 횟수: 1, 비율: 0.02
#
# 명시적 증상: Temper problems, 총 발생 횟수: 5
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 1, 비율: 0.20
#   암묵적 증상: Excessive anger, 발생 횟수: 1, 비율: 0.20
#   암묵적 증상: Hostile behavior, 발생 횟수: 1, 비율: 0.20
#   암묵적 증상: Depression, 발생 횟수: 1, 비율: 0.20
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 1, 비율: 0.20
#
# 명시적 증상: Infant spitting up, 총 발생 횟수: 7
#   암묵적 증상: Fever, 발생 횟수: 2, 비율: 0.29
#   암묵적 증상: Skin irritation, 발생 횟수: 1, 비율: 0.14
#   암묵적 증상: Cough, 발생 횟수: 1, 비율: 0.14
#   암묵적 증상: Skin rash, 발생 횟수: 1, 비율: 0.14
#   암묵적 증상: Skin swelling, 발생 횟수: 1, 비율: 0.14
#   암묵적 증상: Pulling at ears, 발생 횟수: 1, 비율: 0.14
#
# 명시적 증상: Pulling at ears, 총 발생 횟수: 13
#   암묵적 증상: Nasal congestion, 발생 횟수: 3, 비율: 0.23
#   암묵적 증상: Infant spitting up, 발생 횟수: 2, 비율: 0.15
#   암묵적 증상: Cough, 발생 횟수: 2, 비율: 0.15
#   암묵적 증상: Fever, 발생 횟수: 2, 비율: 0.15
#   암묵적 증상: Suprapubic pain, 발생 횟수: 2, 비율: 0.15
#   암묵적 증상: Skin rash, 발생 횟수: 1, 비율: 0.08
#   암묵적 증상: Diarrhea, 발생 횟수: 1, 비율: 0.08
#
# 명시적 증상: Spotting or bleeding during pregnancy, 총 발생 횟수: 22
#   암묵적 증상: Vaginal discharge, 발생 횟수: 5, 비율: 0.23
#   암묵적 증상: Sharp abdominal pain, 발생 횟수: 5, 비율: 0.23
#   암묵적 증상: Penile discharge, 발생 횟수: 5, 비율: 0.23
#   암묵적 증상: Painful urination, 발생 횟수: 3, 비율: 0.14
#   암묵적 증상: Problems with movement, 발생 횟수: 1, 비율: 0.05
#   암묵적 증상: Cramps and spasms, 발생 횟수: 1, 비율: 0.05
#   암묵적 증상: Paresthesia, 발생 횟수: 1, 비율: 0.05
#   암묵적 증상: Vaginal pain, 발생 횟수: 1, 비율: 0.05
#
# 명시적 증상: Ankle stiffness or tightness, 총 발생 횟수: 20
#   암묵적 증상: Shoulder pain, 발생 횟수: 7, 비율: 0.35
#   암묵적 증상: Shoulder stiffness or tightness, 발생 횟수: 4, 비율: 0.20
#   암묵적 증상: Elbow pain, 발생 횟수: 2, 비율: 0.10
#   암묵적 증상: Neck pain, 발생 횟수: 2, 비율: 0.10
#   암묵적 증상: Ache all over, 발생 횟수: 1, 비율: 0.05
#   암묵적 증상: Arm pain, 발생 횟수: 1, 비율: 0.05
#   암묵적 증상: Shoulder swelling, 발생 횟수: 1, 비율: 0.05
#   암묵적 증상: Skin on arm or hand looks infected, 발생 횟수: 1, 비율: 0.05
#   암묵적 증상: Muscle pain, 발생 횟수: 1, 비율: 0.05
#
# 명시적 증상: Low back weakness, 총 발생 횟수: 27
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 4, 비율: 0.15
#   암묵적 증상: Headache, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Nausea, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Vaginal bleeding after menopause, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Depression, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Low self-esteem, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Decreased heart rate, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Elbow cramps or spasms, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Dizziness, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Diarrhea, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Heavy menstrual flow, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Pelvic pain, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Anxiety and nervousness, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Disturbance of memory, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Vaginal discharge, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Back pain, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Leg pain, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Excessive anger, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Delusions or hallucinations, 발생 횟수: 1, 비율: 0.04
#
# 명시적 증상: Swollen or red tonsils, 총 발생 횟수: 14
#   암묵적 증상: Diminished hearing, 발생 횟수: 5, 비율: 0.36
#   암묵적 증상: Redness in ear, 발생 횟수: 3, 비율: 0.21
#   암묵적 증상: Ear pain, 발생 횟수: 2, 비율: 0.14
#   암묵적 증상: Low self-esteem, 발생 횟수: 1, 비율: 0.07
#   암묵적 증상: Plugged feeling in ear, 발생 횟수: 1, 비율: 0.07
#   암묵적 증상: Difficulty speaking, 발생 횟수: 1, 비율: 0.07
#   암묵적 증상: Ringing in ear, 발생 횟수: 1, 비율: 0.07
#
# 명시적 증상: Pain during intercourse, 총 발생 횟수: 17
#   암묵적 증상: Impotence, 발생 횟수: 7, 비율: 0.41
#   암묵적 증상: Infertility, 발생 횟수: 2, 비율: 0.12
#   암묵적 증상: Symptoms of prostate, 발생 횟수: 2, 비율: 0.12
#   암묵적 증상: Frequent urination, 발생 횟수: 2, 비율: 0.12
#   암묵적 증상: Involuntary urination, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Excessive urination at night, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Loss of sex drive, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Pain in testicles, 발생 횟수: 1, 비율: 0.06
#
# 명시적 증상: Itching of scrotum, 총 발생 횟수: 1
#   암묵적 증상: Decreased heart rate, 발생 횟수: 1, 비율: 1.00
#
# 명시적 증상: Bleeding from eye, 총 발생 횟수: 9
#   암묵적 증상: Diminished vision, 발생 횟수: 5, 비율: 0.56
#   암묵적 증상: Eye redness, 발생 횟수: 1, 비율: 0.11
#   암묵적 증상: Spots or clouds in vision, 발생 횟수: 1, 비율: 0.11
#   암묵적 증상: Foreign body sensation in eye, 발생 횟수: 1, 비율: 0.11
#   암묵적 증상: Pain in eye, 발생 횟수: 1, 비율: 0.11
#
# 명시적 증상: Hand or finger stiffness or tightness, 총 발생 횟수: 26
#   암묵적 증상: Loss of sensation, 발생 횟수: 5, 비율: 0.19
#   암묵적 증상: Arm pain, 발생 횟수: 5, 비율: 0.19
#   암묵적 증상: Paresthesia, 발생 횟수: 4, 비율: 0.15
#   암묵적 증상: Hand or finger pain, 발생 횟수: 3, 비율: 0.12
#   암묵적 증상: Neck pain, 발생 횟수: 3, 비율: 0.12
#   암묵적 증상: Wrist pain, 발생 횟수: 3, 비율: 0.12
#   암묵적 증상: Arm weakness, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Wrist swelling, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Hand or finger weakness, 발생 횟수: 1, 비율: 0.04
#
# 명시적 증상: Back cramps or spasms, 총 발생 횟수: 10
#   암묵적 증상: Back pain, 발생 횟수: 3, 비율: 0.30
#   암묵적 증상: Leg pain, 발생 횟수: 2, 비율: 0.20
#   암묵적 증상: Low back pain, 발생 횟수: 2, 비율: 0.20
#   암묵적 증상: Hip pain, 발생 횟수: 2, 비율: 0.20
#   암묵적 증상: Side pain, 발생 횟수: 1, 비율: 0.10
#
# 명시적 증상: Symptoms of the face, 총 발생 횟수: 28
#   암묵적 증상: Abnormal appearing skin, 발생 횟수: 9, 비율: 0.32
#   암묵적 증상: Skin lesion, 발생 횟수: 5, 비율: 0.18
#   암묵적 증상: Skin growth, 발생 횟수: 4, 비율: 0.14
#   암묵적 증상: Itching of skin, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Lack of growth, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Skin rash, 발생 횟수: 2, 비율: 0.07
#   암묵적 증상: Skin moles, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Skin dryness, peeling, scaliness, or roughness, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Irregular appearing scalp, 발생 횟수: 1, 비율: 0.04
#   암묵적 증상: Acne or pimples, 발생 횟수: 1, 비율: 0.04
#
# 명시적 증상: Muscle cramps, contractures, or spasms, 총 발생 횟수: 10
#   암묵적 증상: Disturbance of memory, 발생 횟수: 3, 비율: 0.30
#   암묵적 증상: Depression, 발생 횟수: 2, 비율: 0.20
#   암묵적 증상: Abnormal involuntary movements, 발생 횟수: 1, 비율: 0.10
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 1, 비율: 0.10
#   암묵적 증상: Sweating, 발생 횟수: 1, 비율: 0.10
#   암묵적 증상: Hemoptysis, 발생 횟수: 1, 비율: 0.10
#   암묵적 증상: Dizziness, 발생 횟수: 1, 비율: 0.10
#
# 명시적 증상: Unusual color or odor to urine, 총 발생 횟수: 3
#   암묵적 증상: Fatigue, 발생 횟수: 1, 비율: 0.33
#   암묵적 증상: Shortness of breath, 발생 횟수: 1, 비율: 0.33
#   암묵적 증상: Symptoms of the kidneys, 발생 횟수: 1, 비율: 0.33
#
# 명시적 증상: Hand or finger cramps or spasms, 총 발생 횟수: 1
#   암묵적 증상: Lymphedema, 발생 횟수: 1, 비율: 1.00
#
# 명시적 증상: Bowlegged or knock-kneed, 총 발생 횟수: 3
#   암묵적 증상: Skin rash, 발생 횟수: 1, 비율: 0.33
#   암묵적 증상: Itching of skin, 발생 횟수: 1, 비율: 0.33
#   암묵적 증상: Vomiting, 발생 횟수: 1, 비율: 0.33
#
# 명시적 증상: Feeling cold, 총 발생 횟수: 1
#   암묵적 증상: Fatigue, 발생 횟수: 1, 비율: 1.00
#
# 명시적 증상: Hip stiffness or tightness, 총 발생 횟수: 3
#   암묵적 증상: Difficulty in swallowing, 발생 횟수: 2, 비율: 0.67
#   암묵적 증상: Cough, 발생 횟수: 1, 비율: 0.33
#
# 명시적 증상: Back mass or lump, 총 발생 횟수: 1
#   암묵적 증상: Sharp chest pain, 발생 횟수: 1, 비율: 1.00
#
# 명시적 증상: Back stiffness or tightness, 총 발생 횟수: 6
#   암묵적 증상: Back pain, 발생 횟수: 2, 비율: 0.33
#   암묵적 증상: Leg pain, 발생 횟수: 1, 비율: 0.17
#   암묵적 증상: Low back pain, 발생 횟수: 1, 비율: 0.17
#   암묵적 증상: Neck pain, 발생 횟수: 1, 비율: 0.17
#   암묵적 증상: Side pain, 발생 횟수: 1, 비율: 0.17
#
# 명시적 증상: Muscle stiffness or tightness, 총 발생 횟수: 18
#   암묵적 증상: Headache, 발생 횟수: 5, 비율: 0.28
#   암묵적 증상: Diminished vision, 발생 횟수: 3, 비율: 0.17
#   암묵적 증상: Focal weakness, 발생 횟수: 2, 비율: 0.11
#   암묵적 증상: Dizziness, 발생 횟수: 2, 비율: 0.11
#   암묵적 증상: Neck pain, 발생 횟수: 2, 비율: 0.11
#   암묵적 증상: Arm pain, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Vomiting, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Nausea, 발생 횟수: 1, 비율: 0.06
#   암묵적 증상: Difficulty speaking, 발생 횟수: 1, 비율: 0.06
#
# 명시적 증상: Nose deformity, 총 발생 횟수: 3
#   암묵적 증상: Acne or pimples, 발생 횟수: 2, 비율: 0.67
#   암묵적 증상: Skin moles, 발생 횟수: 1, 비율: 0.33
#
# 명시적 증상: Pus in urine, 총 발생 횟수: 4
#   암묵적 증상: Depressive or psychotic symptoms, 발생 횟수: 1, 비율: 0.25
#   암묵적 증상: Depression, 발생 횟수: 1, 비율: 0.25
#   암묵적 증상: Low self-esteem, 발생 횟수: 1, 비율: 0.25
#   암묵적 증상: Disturbance of memory, 발생 횟수: 1, 비율: 0.25
#
# 명시적 증상: Pus in sputum, 총 발생 횟수: 0

# %%
all_symptoms = []
for _, row in train_df.iterrows():
    explicit_symptoms = row['goal']['explicit_inform_slots'].keys()
    all_symptoms.extend(explicit_symptoms)

unique_symptoms1 = pd.Series(all_symptoms).unique()
unique_count = len(unique_symptoms)
unique_count
# Out:
# 264

# %%
all_symptoms = []
for _, row in train_df.iterrows():
    explicit_symptoms = row['goal']['implicit_inform_slots'].keys()
    all_symptoms.extend(explicit_symptoms)

unique_symptoms2 = pd.Series(all_symptoms).unique()
unique_count = len(unique_symptoms)
unique_count
# Out:
# 264

# %%
set1 = set(unique_symptoms1)
set2 = set(unique_symptoms2)
duplicates = set1.intersection(set2)
print(duplicates)
# Out:
# {'Penis pain', 'Elbow weakness', 'Painful urination', 'Leg pain', 'Back weakness', 'Skin lesion', 'Skin irritation', 'Foot or toe lump or mass', 'Irregular heartbeat', 'Vomiting', 'Temper problems', 'Knee pain', 'Symptoms of eye', 'Sneezing', 'Allergic reaction', 'Skin moles', 'Hostile behavior', 'Itching of skin', 'Difficulty speaking', 'Feeling ill', 'Muscle stiffness or tightness', 'Sweating', 'Shoulder swelling', 'Pus in sputum', 'Skin dryness, peeling, scaliness, or roughness', 'Kidney mass', 'Pain during pregnancy', 'Difficulty breathing', 'Depression', 'Increased heart rate', 'Excessive appetite', 'Sinus congestion', 'Facial pain', 'Abnormal movement of eyelid', 'Irritable infant', 'Infrequent menstruation', 'Eye strain', 'Painful sinuses', 'Back pain', 'Foot or toe swelling', 'Scanty menstrual flow', 'Skin rash', 'Foot or toe pain', 'Pain in eye', 'Muscle weakness', 'Foreign body sensation in eye', 'Hand or finger swelling', 'Unusual color or odor to urine', 'Mass on eyelid', 'Emotional symptoms', 'Bleeding gums', 'Fever', 'Low back pain', 'Neck cramps or spasms', 'Leg weakness', 'Wrist lump or mass', 'Throat swelling', 'Bleeding or discharge from nipple', 'Blindness', 'Symptoms of prostate', 'Ankle stiffness or tightness', 'Restlessness', 'Polyuria', 'Knee swelling', 'Skin pain', 'Groin mass', 'Feeling hot and cold', 'Symptoms of the face', 'Problems with movement', 'Side pain', 'Lump or mass of breast', 'Excessive growth', 'Eye burns or stings', 'Nose deformity', 'Lip swelling', 'Dizziness', 'Leg swelling', 'Hurts to breath', 'Focal weakness', 'Seizures', 'Absence of menstruation', 'Swelling of scrotum', 'Eye redness', 'Symptoms of the kidneys', 'Heavy menstrual flow', 'Congestion in chest', 'Lymphedema', 'Swollen abdomen', 'Fainting', 'Vaginal discharge', 'Hip pain', 'Ankle swelling', 'Eyelid lesion or rash', 'Neck swelling', 'Groin pain', 'Skin on leg or foot looks infected', 'Frequent urination', 'Shoulder pain', 'Pus in urine', 'Burning abdominal pain', 'Delusions or hallucinations', 'Premature ejaculation', 'Pain in testicles', 'Ankle pain', 'Excessive urination at night', 'Double vision', 'Hip stiffness or tightness', 'Skin growth', 'Hand or finger stiffness or tightness', 'Difficulty eating', 'Hemoptysis', 'Rib pain', 'Impotence', 'Abnormal involuntary movements', 'Poor circulation', 'Drainage in throat', 'Disturbance of smell or taste', 'Muscle swelling', 'Decreased heart rate', 'Mass on vulva', 'Hand or finger weakness', 'Thirst', 'Abnormal size or shape of ear', 'Irregular appearing scalp', 'Sharp chest pain', 'Wrist stiffness or tightness', 'Arm swelling', 'Plugged feeling in ear', 'Loss of sex drive', 'Mass in scrotum', 'Bleeding from eye', 'Mouth ulcer', 'Swollen or red tonsils', 'Elbow cramps or spasms', 'Frontal headache', 'Arm weakness', 'Disturbance of memory', 'Drug abuse', 'Shoulder stiffness or tightness', 'Decreased appetite', 'Fluid in ear', 'Back stiffness or tightness', 'Leg cramps or spasms', 'Lack of growth', 'Symptoms of bladder', 'Low back weakness', 'Chest tightness', 'Warts', 'Unpredictable menstruation', 'Foot or toe stiffness or tightness', 'Arm stiffness or tightness', 'Neck pain', 'Coryza', 'Vomiting blood', 'Pain or soreness of breast', 'Redness in ear', 'Lower body pain', 'Wrist weakness', 'Diaper rash', 'Muscle cramps, contractures, or spasms', 'Diminished vision', 'Cramps and spasms', 'Fluid retention', 'Intermenstrual bleeding', 'Skin on arm or hand looks infected', 'Hand or finger cramps or spasms', 'Bladder mass', 'Ear pain', 'Sore throat', 'Abnormal appearing skin', 'Spotting or bleeding during pregnancy', 'Neck stiffness or tightness', 'Stiffness all over', 'Hot flashes', 'Abusing alcohol', 'Loss of sensation', 'Nightmares', 'Palpitations', 'Weakness', 'Chills', 'Skin swelling', 'Swollen eye', 'Paresthesia', 'Itchy eyelid', 'Apnea', 'Painful menstruation', 'Elbow pain', 'Diarrhea', 'Bowlegged or knock-kneed', 'Vaginal pain', 'Joint stiffness or tightness', 'Nausea', 'Swollen ...

# %%
implicit_symptoms_counts = []

for _, row in train_df.iterrows():
    implicit_symptoms = row['goal']['implicit_inform_slots'].keys()
    implicit_symptoms_counts.append(len(implicit_symptoms))

print(max(implicit_symptoms_counts))
# 5개 이하인 'implicit_symptoms'를 가진 객체의 수 계산
count_5_or_less = sum(1 for count in implicit_symptoms_counts if count <= 5)

# 전체 객체 수
total_count = len(implicit_symptoms_counts)

# 5개 이하인 객체의 비율 계산
percentage_5_or_less = (count_5_or_less / total_count) * 100

percentage_5_or_less
# Out:
# 11
# 93.50416666666666
